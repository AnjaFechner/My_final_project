# %% [markdown]
# ### 7.0. Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
#NLP
from textblob import TextBlob
#Random Forest model -> subervised learning
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
import math 
#Visualization of Random Forest
from sklearn.datasets import load_boston
from sklearn.ensemble import RandomForestRegressor
from sklearn import tree
from dtreeviz.trees import dtreeviz # will be used for tree visualization

# %% [markdown]
# ### 7.1. Reade the File (books and movie)

# %%
df = pd.read_excel(r'C:\Users\AnjaF\Desktop\My_final_project\files\Step_6_join_bestseller_books_with_films\bestseller_books_movies_by_hand.xlsx')

# %%
df.head()
# Out:
#    Unnamed: 0          Author        Name       Genre  Year  Rating  Reviews  \
# 0           0  David Baldacci    Zero Day     fiction  2011     4.5   7657.0
# 1           1      Reza Aslan      Zealot  nonfiction  2013     4.4   6352.0
# 2           2     Amy Poehler  Yes Please  nonfiction  2014     4.3   4487.0
# 3           3    Nora Roberts    Year One     fiction  2017     4.6   9358.0
# 4           4     Sue Grafton           X     fiction  2015     4.4   6071.0
#
#    Price  Book_into_Movie
# 0  14.67                0
# 1   7.89                0
# 2  22.25                0
# 3   8.83                0
# 4   7.04                0

# %%
df = df.drop_duplicates()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 588 entries, 0 to 587
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       588 non-null    int64
#  1   Author           588 non-null    object
#  2   Name             588 non-null    object
#  3   Genre            588 non-null    object
#  4   Year             588 non-null    int64
#  5   Rating           588 non-null    float64
#  6   Reviews          588 non-null    float64
#  7   Price            588 non-null    float64
#  8   Book_into_Movie  588 non-null    int64
# dtypes: float64(3), int64(3), object(3)
# memory usage: 45.9+ KB

# %%
df["Book_into_Movie"].value_counts()
# Out:
# 0    526
# 1     62
# Name: Book_into_Movie, dtype: int64

# %%
df = df.drop(columns=["Unnamed: 0"])

# %%
# reset index-> because of drop duplicates
df.reset_index(inplace = True)

# %% [markdown]
# ### 7.2. Create a new column as AVG (Rating/Reviews)

# %%
df["Average"] = df["Rating"]/df["Reviews"]

# %% [markdown]
# ### 7.3. EDA

# %%
# show the differetn features in plots to check correlation and distributions

cols_cat = list(df.select_dtypes(include=['object']).columns)

for col in cols_cat:
    print("Frequency analysis of column: ",col)
    my_data = df[col].value_counts().reset_index()
    ax = sns.barplot(x=col, y="index", data = my_data).set_title(col.upper())
    plt.figure()
    print
# Out:
# Frequency analysis of column:  Author
# Frequency analysis of column:  Name
# Frequency analysis of column:  Genre

# %%
df["Book_into_Movie"].value_counts().plot(kind="bar")
plt.figure();

# %%
plt.figure(figsize=(16, 6))
mask = np.triu(np.ones_like(df.corr(), dtype=np.bool))
heatmap = sns.heatmap(df.corr(), mask=mask, vmin=-1, vmax=1, annot=True, cmap='BrBG')

# %%
num_cols = df.select_dtypes(include=["int64", "float64"]).columns

for column in num_cols:
    print(column, '-->', df['Book_into_Movie'].corr(df[column]))
# Out:
# index --> -0.13163420268544573
# Year --> -0.03039243072792773
# Rating --> -0.11160916087424004
# Reviews --> 0.24202251150994517
# Price --> -0.013913172349316485
# Book_into_Movie --> 1.0
# Average --> -0.0296232158763123

# %% [markdown]
# ### 7.4. Change the colum Genre in fiction = 1 and non-fiction = 0

# %%
def cleanGenre(x):
    if x == "fiction":
        return 1
    elif x == "nonfiction":
        return 0
    else:
        return 'unknown'
df['Genre'] = list(map(cleanGenre, df['Genre']))

# %%
# check the result
df["Genre"].value_counts()
# Out:
# 1    378
# 0    210
# Name: Genre, dtype: int64

# %% [markdown]
# ### 7.5. Apply the NLP on the book title (unfortunatly no critics/reviews available)

# %%
def NLP(text):
    try:
        return TextBlob(text).sentiment
    except:
        return None

# %%
df['Polarity'] = df['Name'].apply(NLP).apply(lambda x: x[0])
df['Subjectivity'] = df['Name'].apply(NLP).apply(lambda x: x[1])

# %%
# check the results
df.head()
# Out:
#    index          Author        Name  Genre  Year  Rating  Reviews  Price  \
# 0      0  David Baldacci    Zero Day      1  2011     4.5   7657.0  14.67
# 1      1      Reza Aslan      Zealot      0  2013     4.4   6352.0   7.89
# 2      2     Amy Poehler  Yes Please      0  2014     4.3   4487.0  22.25
# 3      3    Nora Roberts    Year One      1  2017     4.6   9358.0   8.83
# 4      4     Sue Grafton           X      1  2015     4.4   6071.0   7.04
#
#    Book_into_Movie   Average  Polarity  Subjectivity
# 0                0  0.000588       0.0           0.0
# 1                0  0.000693       0.0           0.0
# 2                0  0.000958       0.0           0.0
# 3                0  0.000492       0.0           0.0
# 4                0  0.000725       0.0           0.0

# %% [markdown]
# ### 7.6. Apply Random Forest model

# %%
# between column Average and columns Rating and Reviews exist not correlation, 
# although Average is the result from Rating/Reviews
# -> the first apply of the random forest shows that the column Average is not useful -> the float-values are too large

# %% [markdown]
# - first apply

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 588 entries, 0 to 587
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   index            588 non-null    int64
#  1   Author           588 non-null    object
#  2   Name             588 non-null    object
#  3   Genre            588 non-null    int64
#  4   Year             588 non-null    int64
#  5   Rating           588 non-null    float64
#  6   Reviews          588 non-null    float64
#  7   Price            588 non-null    float64
#  8   Book_into_Movie  588 non-null    int64
#  9   Average          587 non-null    float64
#  10  Polarity         588 non-null    float64
#  11  Subjectivity     588 non-null    float64
# dtypes: float64(6), int64(4), object(2)
# memory usage: 55.2+ KB

# %% [markdown]
# -> safe the dataset to improve the model

# %%
df.to_excel("dataset_random_forest_model.xlsx", index=False)

# %% [markdown]
# - *Split the data in "Names" of the book*
# - *"Author" of the books
# - *the independent variables X*
# - *the target variable y (=Book_into_Movie)*

# %%
Name = df.Name
Author = df.Author
y= df.Book_into_Movie
X= df.drop(columns=["index", "Author", "Name", "Book_into_Movie", "Average"])

# %% [markdown]
# - *Scaling the Data*

# %%
# use an other Scaler is a possibility to improve the model
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# - *define Training-dataset and Test-dataset*

# %%
# my dataset consist of 580 rows the books which are movies ->corresponds to 10 percent on the whole set
# at first: test size at first 10 %
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.1, random_state=40)

# %%
regressor = RandomForestRegressor(n_estimators=10, max_depth=3)
model= regressor.fit(X_train,y_train)  
predictions  = model.predict(X_test)
print('Prediction Random Forest:',predictions)
# Out:
# Prediction Random Forest: [0.49283459 0.04426426 0.06473539 0.04426426 0.25017831 0.06113949
#  0.54094922 0.63066121 0.10829834 0.06473539 0.04426426 0.05567254
#  0.41778908 0.13423532 0.04426426 0.04426426 0.10503997 0.04426426
#  0.125204   0.05329557 0.14754808 0.04426426 0.04426426 0.60715083
#  0.05329557 0.05278747 0.125204   0.05278747 0.06473539 0.55175992
#  0.05278747 0.05329557 0.04426426 0.05567254 0.04426426 0.04426426
#  0.04426426 0.57257315 0.05329557 0.04426426 0.06473539 0.06473539
#  0.10503997 0.29355558 0.04426426 0.04426426 0.10554808 0.4354048
#  0.69275523 0.18899436 0.05278747 0.06473539 0.10577345 0.09651677
#  0.06181878 0.04426426 0.06113949 0.06473539 0.5089457 ]

# %% [markdown]
# - compare the values

# %%
y_values = pd.DataFrame({"real_values": y_test, "pred_values": predictions})
y_values
# Out:
#      real_values  pred_values
# 382            0     0.492835
# 324            0     0.044264
# 209            0     0.064735
# 579            0     0.044264
# 310            0     0.250178
# 12             0     0.061139
# 161            1     0.540949
# 16             1     0.630661
# 332            0     0.108298
# 51             0     0.064735
# 282            0     0.044264
# 133            0     0.055673
# 534            0     0.417789
# 295            0     0.134235
# 26             0     0.044264
# 395            0     0.044264
# 106            0     0.105040
# 576            0     0.044264
# 341            0     0.125204
# 439            0     0.053296
# 154            1     0.147548
# 42             0     0.044264
# 418            0     0.044264
# 15             0     0.607151
# 181            0     0.053296
# 203            0     0.052787
# 447            0     0.125204
# 246            0     0.052787
# 431            0     0.064735
# 77             0     0.551760
# 411            0     0.052787
# 0              0     0.053296
# 516            0     0.044264
# 549            0     0.055673
# 568            0     0.044264
# 551            0     0.044264
# 259            0     0.044264
# 416            1     0.572573
# 479            0     0.053296
# 110            0     0.044264
# 483            0     0.064735
# 71             0     0.064735
# 283            0     0.105040
# 14             0     0.293556
# 137            0     0.044264
# 475            0     0.044264
# 489            0     0.105548
# 281            0     0.435405
# 554            0     0.692755
# 293            0     0.188994
# 185            0     0.052787
# 376            0     0.064735
# 358            0     0.105773
# 135            1     0.096517
# 120            0     0.061819
# 192            0     0.044264
# 370            0     0.061139
# 43             0     0.064735
# 150            0     0.508946

# %% [markdown]
# - *Visualization of Decision Tree*

# %%
plt.rcParams.update({'figure.figsize': (12.0, 8.0)})
plt.rcParams.update({'font.size': 14})

# %%
RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
                      max_depth=3, max_features='auto', max_leaf_nodes=None,
                      max_samples=None, min_impurity_decrease=0.0,
                      min_impurity_split=None, min_samples_leaf=1,
                      min_samples_split=2, min_weight_fraction_leaf=0.0,
                      n_estimators=100, n_jobs=None, oob_score=False,
                      random_state=None, verbose=0, warm_start=False)
# Out:
# RandomForestRegressor(max_depth=3)

# %%
plt.figure(figsize=(140,140))
_ = tree.plot_tree(model.estimators_[0], feature_names=X.columns, filled=True)

# %% [markdown]
# - *Evaluation*

# %%
r= r2_score(y_test, predictions)
print("The R² is: " + str(r))

mse = mean_squared_error(y_test, predictions)
print("The mean squared error is: " + str(mse))

rmse = math.sqrt(mse)
print("The root mean square error is: " + str(mse))

# the results shows a model that is not good
# Out:
# The R² is: 0.020496779510175367
# The mean squared error is: 0.0759741078805667
# The root mean square error is: 0.0759741078805667
