# %% [markdown]
# # Web scraping for list about book into movies
# ### 5.0. Libraries

# %%
import requests
import lxml.html as lh
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
from time import sleep
from random import uniform
from random import randint

# %% [markdown]
# ### 5.1. Web Scraping one page

# %%
# Website: https://www.goodreads.com/list/show/40351.Books_becoming_movies_2013_2015
url1 = "https://www.goodreads.com/list/show/40351.Books_becoming_movies_2013_2015"

# %%
response1 = requests.get(url1)
response1.status_code
# Out:
# 200

# %%
soup1 = BeautifulSoup(response1.content, "html.parser")

# %%
# find the css-selector for one book title
soup1.select("tr:nth-child(1) > td:nth-child(3) > a:nth-child(1) > span:nth-child(1)")
# Out:
# [<span aria-level="4" itemprop="name" role="heading">The Fault in Our Stars</span>]

# %%
# find the css-selector for all book title
soup1.select("td:nth-child(3) > a:nth-child(1) > span:nth-child(1)")
# Out:
# [<span aria-level="4" itemprop="name" role="heading">The Fault in Our Stars</span>,
#  <span aria-level="4" itemprop="name" role="heading">Divergent (Divergent, #1)</span>,
#  <span aria-level="4" itemprop="name" role="heading">The Maze Runner (The Maze Runner, #1)</span>,
#  <span aria-level="4" itemprop="name" role="heading">City of Bones (The Mortal Instruments, #1)</span>,
#  <span aria-level="4" itemprop="name" role="heading">Gone Girl</span>,
#  <span aria-level="4" itemprop="name" role="heading">The Book Thief</span>,
#  <span aria-level="4" itemprop="name" role="heading">If I Stay (If I Stay, #1)</span>,
#  <span aria-level="4" itemprop="name" role="heading">Eleanor &amp; Park</span>,
#  <span aria-level="4" itemprop="name" role="heading">Fifty Shades of Grey (Fifty Shades, #1)</span>,
#  <span aria-level="4" itemprop="name" role="heading">Fallen (Fallen, #1)</span>,
#  <span aria-level="4" itemprop="name" role="heading">Vampire Academy (Vampire Academy, #1)</span>,
#  <span aria-level="4" itemprop="name" role="heading">The Giver (The Giver, #1)</span>,
#  <span aria-level="4" itemprop="name" role="heading">Dark Places</span>,
#  <span aria-level="4" itemprop="name" role="heading">Miss Peregrine's Home for Peculiar Children (Miss Peregrine's Peculiar Children, #1)</span>,
#  <span aria-level="4" itemprop="name" role="heading">Ender's Game (Ender's Saga, #1)</span>,
#  <span aria-level="4" itemprop="name" role="heading">The DUFF: Designated Ugly Fat Friend (Hamilton High, #1)</span>,
#  <span aria-level="4" itemprop="name" role="heading">The Wolf of Wall Street (The Wolf of Wall Street, #1)</span>,
#  <span aria-level="4" itemprop="name" role="heading">Love, Rosie</span>,
#  <span aria-level="4" itemprop="name" role="heading">The Hobbit, or There and Back Again</span>,
#  <span aria-level="4" itemprop="name" role="heading">Serena</span>,
#  <span aria-level="4" itemprop="name" role="heading">Twelve Years a Slave</span>,
#  <span aria-level="4" itemprop="name" role="heading">Fated (Soul Seekers, #1)</span>,
#  <span aria-level="4" itemprop="name" role="heading">Paranormalcy (Paranormalcy, #1)</span>,
#  <span aria-level="4" itemprop="name" role="heading">The 5th Wave (The 5th Wave, #1)</span>,
#  <span aria-level="4" itemprop="name" role="heading">Heaven is for Real: A Little Boy's Astounding Story of His Trip to Heaven and Back</span>,
#  <span aria-level="4" itemprop="name" role="heading">The Monuments Men: Allied Heroes, Nazi Thieves, and the Greatest Treasure Hunt in History</span>,
#  <span aria-level="4" itemprop="name" role="heading">Alan Turing: The Enigma</span>,
#  <span aria-level="4" itemprop="name" role="heading">Reconstructing Amelia</span>,
#  <span aria-level="4" itemprop="name" role="heading">Infinity (Chronicles of Nick, #1)</span>,
#  <span aria-level="4" itemprop="name" role="heading">Unbroken: A World War II Story of Survival, Resilience and Redemption</span>,
#  <span aria-level="4" itemprop="name" role="heading">Insurgent (Divergent, #2)</span>,
#  <span aria-level="4" itemprop="name" role="heading">Before I Go to Sleep</span>,
#  <span aria-level="4" itemprop="name" role="heading">Horns</span>,
#  <span aria-level="4" itemprop="name" role="heading">Winter's Tale</span>,
#  <span aria-level="4" itemprop="name" role="heading">Odd Thomas (Odd Thomas, #1)</span>,
#  <span aria-level="4" itemprop="name" role="heading">The Alchemist</span>,
#  <span aria-level="4" itemprop="name" role="heading">A Walk in the Woods: Rediscovering America on the Appalachian Trail</span>,
#  <span aria-level="4" itemprop="name" role="heading">The Spectacular Now</span>,
#  <span aria-level="4" itemprop="name" role="heading">The Goldfinch</span>,
#  <span aria-level="4" itemprop="name" role="heading">This is Where I Leave You</span>,
#  <span aria-level="4" itemprop="name" role="heading">Inferno (Robert Langdon, #4)</span>,
#  <span aria-level="4" itemprop="name" role="heading">The Graveyard Book</span>,
#  <span aria-level="4" itemprop="name" role="heading">The Secret of the Nagas (Shiva Trilogy #2)</span>,
#  <span aria-level="4" itemprop="name" role="heading">Wicked Lovely (Wicked Lovely, #1)</span>,
#  <span aria-level="4" itemprop="name" role="heading">Sisterhood Everlasting (Sisterhood, #5)</span>,
#  <span aria-level="4" itemprop="name" role="heading">Revenge of the Witch (The Last Apprentice / Wardstone Chronicles, #1)</span>,
#  <span aria-level="4" itemprop="name" role="heading">Me Before You (Me Before You, #1)</span>,
#  <span aria-level="4" itemprop="name" role="heading">The Testing (The Testing, #1)</span>,
#  <span aria-level="4" itemprop="name" role="heading">A Long Way Down</span>,
#  <span aria-level="4" itemprop="name" role="heading">The Immortals of Meluha (Shiva Trilogy, #1)</span>,
#  <span aria-level="4" itemprop="name" role="heading">The Young World (The Young World, #1)</span>,
#  <span aria-level="4" itemprop="name" role="heading">Under the Banner of Heaven: A Story of Violent Faith</span>,
#  <span aria-level="4" itemprop="name" role="heading">The Last Apprentice: Seventh Son: Book 1 and Book 2</span>,
#  <span aria-level="4" itemprop="name" role="heading">American Sniper: The Autobiography of the Most Lethal Sniper in U.S. Military History</span>,
#  <span aria-level="4" itemprop="name" role="heading">Tiger Eyes</span>,
#  <span aria-level="4" itemprop="name" role="heading">Paranoia</span>,
#  <span aria-level="4" itemprop="name" role="heading">Brooklyn</span>,
#  <span aria-level="4" itemprop="name" role="heading">Hector and the Search for Happiness</span>,
#  <span aria-level="4" itemprop="name" role="heading">Secret Daughter</span>,
#  <span aria-level="4" itemprop="name" role="heading">The Creeping</span>,
#  <span aria-level="4" itemprop="name" role="heading">King of Heists: The Sensational Bank Robbery of 1878 That Shocked America</span>,
#  <span aria-level="4" itemprop="name" role="heading">Madame Bovary</span>,
#  <span aria-level="4" itemprop="name" role="heading">The Oath of the Vayuputras (Shiva Trilogy, #3)</span>,
#  <span aria-level="4" itemprop="name" role="heading">Testament of Youth</span>,
#  <span aria-level="4" itemprop="name" role="heading">The Hundred-Foot Journey</span>,
#  <span aria-level="4" itemprop="name" role="heading">The Longest Ride</span>,
#  <span aria-level="4" itemprop="name" role="heading">Every Secret Thing</span>,
#  <span aria-level="4" itemprop="name" role="heading">Into the Woods</span>,
#  <span aria-level="4" itemprop="name" role="heading">Kill the Messenger: How the CIA's Crack-Cocaine Controversy Destroyed Journalist Gary Webb</span>,
#  <span aria-level="4" itemprop="name" role="heading">Get Her Off the Pitch!  How sport took over my life</span>,
#  <span aria-level="4" itemprop="name" role="heading">An Object of Beauty</span>,
#  <span aria-level="4" itemprop="name" role="heading">Z for Zachariah</span>,
#  <span aria-level="4" itemprop="name" role="heading">The Double</span>,
#  <span aria-level="4" itemprop="name" role="heading">A Monster Calls</span>,
#  <span aria-level="4" itemprop="name" role="heading">June Bug</span>,
#  <span aria-level="4" itemprop="name" role="heading">The Two Faces of January</span>,
#  <span aria-level="4" itemprop="name" role="heading">The Pilgrimage</span>,
#  <span aria-level="4" itemprop="name" role="heading">A Most Wanted Man</span>,
#  <span aria-level="4" itemprop="name" role="heading">Veronika Decides to Die</span>,
#  <span aria-level="4" itemprop="name" role="heading">Brida</span>,
#  <span aria-level="4" itemprop="name" role="heading">Cold in July</span>,
#  <span aria-level="4" itemprop="name" role="heading">Paper Towns</span>,
#  <span aria-level="4" itemprop="name" role="heading">The Devotion of Suspect X (Detective Galileo, #1)</span>,
#  <span aria-level="4" itemprop="name" role="heading">The Company You Keep</span>,
#  <span aria-level="4" itemprop="name" role="heading">The Host</span>,
#  <span aria-level="4" itemprop="name" role="heading">Birdsong: A Novel of Love and War</span>,
#  <span aria-level="4" itemprop="name" role="heading">A Book of Common Prayer</span>,
#  <span aria-level="4" itemprop="name" role="heading">Six Years</span>,
#  <span aria-level="4" itemprop="name" role="heading">Patient Zero (Joe Ledger, #1)</span>,
#  <span aria-level="4" itemprop="name" role="heading">Fear of Flying</span>]

# %%
# find the css-selector for the authors
soup1.select("td:nth-child(3) > span:nth-child(4) > div:nth-child(1) > a:nth-child(1) > span:nth-child(1)")[0].text
# Out:
# 'Veronica Roth'

# %%
book_lst1 = soup1.select("td:nth-child(3) > a:nth-child(1) > span:nth-child(1)")
author_lst1 = soup1.select("td:nth-child(3) > span:nth-child(4) > div:nth-child(1) > a:nth-child(1) > span:nth-child(1)")
len(book_lst1), len(author_lst1)
# Out:
# (90, 89)

# %%
from tqdm.notebook import tqdm
Book1 = []
# Yes = 1
Book_into_Movie1 = []

len_book1 = len(book_lst1)

for i in tqdm(range(len_book1)):
    Book1.append(soup1.select("td:nth-child(3) > a:nth-child(1) > span:nth-child(1)")[i].text)
    Book_into_Movie1.append("1")
# Out:
#   0%|          | 0/90 [00:00<?, ?it/s]

# %%
Book1
# Out:
# ['The Fault in Our Stars',
#  'Divergent (Divergent, #1)',
#  'The Maze Runner (The Maze Runner, #1)',
#  'City of Bones (The Mortal Instruments, #1)',
#  'Gone Girl',
#  'The Book Thief',
#  'If I Stay (If I Stay, #1)',
#  'Eleanor & Park',
#  'Fifty Shades of Grey (Fifty Shades, #1)',
#  'Fallen (Fallen, #1)',
#  'Vampire Academy (Vampire Academy, #1)',
#  'The Giver (The Giver, #1)',
#  'Dark Places',
#  "Miss Peregrine's Home for Peculiar Children (Miss Peregrine's Peculiar Children, #1)",
#  "Ender's Game (Ender's Saga, #1)",
#  'The DUFF: Designated Ugly Fat Friend (Hamilton High, #1)',
#  'The Wolf of Wall Street (The Wolf of Wall Street, #1)',
#  'Love, Rosie',
#  'The Hobbit, or There and Back Again',
#  'Serena',
#  'Twelve Years a Slave',
#  'Fated (Soul Seekers, #1)',
#  'Paranormalcy (Paranormalcy, #1)',
#  'The 5th Wave (The 5th Wave, #1)',
#  "Heaven is for Real: A Little Boy's Astounding Story of His Trip to Heaven and Back",
#  'The Monuments Men: Allied Heroes, Nazi Thieves, and the Greatest Treasure Hunt in History',
#  'Alan Turing: The Enigma',
#  'Reconstructing Amelia',
#  'Infinity (Chronicles of Nick, #1)',
#  'Unbroken: A World War II Story of Survival, Resilience and Redemption',
#  'Insurgent (Divergent, #2)',
#  'Before I Go to Sleep',
#  'Horns',
#  "Winter's Tale",
#  'Odd Thomas (Odd Thomas, #1)',
#  'The Alchemist',
#  'A Walk in the Woods: Rediscovering America on the Appalachian Trail',
#  'The Spectacular Now',
#  'The Goldfinch',
#  'This is Where I Leave You',
#  'Inferno (Robert Langdon, #4)',
#  'The Graveyard Book',
#  'The Secret of the Nagas (Shiva Trilogy #2)',
#  'Wicked Lovely (Wicked Lovely, #1)',
#  'Sisterhood Everlasting (Sisterhood, #5)',
#  'Revenge of the Witch (The Last Apprentice / Wardstone Chronicles, #1)',
#  'Me Before You (Me Before You, #1)',
#  'The Testing (The Testing, #1)',
#  'A Long Way Down',
#  'The Immortals of Meluha (Shiva Trilogy, #1)',
#  'The Young World (The Young World, #1)',
#  'Under the Banner of Heaven: A Story of Violent Faith',
#  'The Last Apprentice: Seventh Son: Book 1 and Book 2',
#  'American Sniper: The Autobiography of the Most Lethal Sniper in U.S. Military History',
#  'Tiger Eyes',
#  'Paranoia',
#  'Brooklyn',
#  'Hector and the Search for Happiness',
#  'Secret Daughter',
#  'The Creeping',
#  'King of Heists: The Sensational Bank Robbery of 1878 That Shocked America',
#  'Madame Bovary',
#  'The Oath of the Vayuputras (Shiva Trilogy, #3)',
#  'Testament of Youth',
#  'The Hundred-Foot Journey',
#  'The Longest Ride',
#  'Every Secret Thing',
#  'Into the Woods',
#  "Kill the Messenger: How the CIA's Crack-Cocaine Controversy Destroyed Journalist Gary Webb",
#  'Get Her Off the Pitch!  How sport took over my life',
#  'An Object of Beauty',
#  'Z for Zachariah',
#  'The Double',
#  'A Monster Calls',
#  'June Bug',
#  'The Two Faces of January',
#  'The Pilgrimage',
#  'A Most Wanted Man',
#  'Veronika Decides to Die',
#  'Brida',
#  'Cold in July',
#  'Paper Towns',
#  'The Devotion of Suspect X (Detective Galileo, #1)',
#  'The Company You Keep',
#  'The Host',
#  'Birdsong: A Novel of Love and War',
#  'A Book of Common Prayer',
#  'Six Years',
#  'Patient Zero (Joe Ledger, #1)',
#  'Fear of Flying']

# %% [markdown]
# - transform list into DF and save the list as file

# %%
book1 = pd.DataFrame({"Name": Book1, "Book_into_Movie": Book_into_Movie1})

# %%
book1
# Out:
#                                           Name Book_into_Movie
# 0                       The Fault in Our Stars               1
# 1                    Divergent (Divergent, #1)               1
# 2        The Maze Runner (The Maze Runner, #1)               1
# 3   City of Bones (The Mortal Instruments, #1)               1
# 4                                    Gone Girl               1
# ..                                         ...             ...
# 85           Birdsong: A Novel of Love and War               1
# 86                     A Book of Common Prayer               1
# 87                                   Six Years               1
# 88               Patient Zero (Joe Ledger, #1)               1
# 89                              Fear of Flying               1
#
# [90 rows x 2 columns]

# %%
book1.to_excel("Book_into_movie_1.xlsx")

# %% [markdown]
# ### 5.2. Web Scraping next one pages

# %%
url2= "https://www.goodreads.com/list/show/720.Books_that_are_being_made_into_movies_2009"

# %%
response2 = requests.get(url2)
response2.status_code
# Out:
# 200

# %%
soup2 = BeautifulSoup(response2.content, "html.parser")
soup2
# Out:
# <!DOCTYPE html>
#
# <html class="desktop withSiteHeaderTopFullImage">
# <head>
# <title>Books that are being made into movies 2009 (27 books)</title>
# <meta content="27 books based on 67 votes: Harry Potter and the Half-Blood Prince by J.K. Rowling, Twilight by Stephenie Meyer, The Hobbit, or There and Back Again by J..." name="description"/>
# <meta content="telephone=no" name="format-detection"/>
# <link href="https://www.goodreads.com/list/show/720.Books_that_are_being_made_into_movies_2009" rel="canonical"/>
# <script type="text/javascript"> var ue_t0=window.ue_t0||+new Date();
#  </script>
# <script type="text/javascript">
#     var ue_mid = "A1PQBFHBHS6YH1";
#     var ue_sn = "www.goodreads.com";
#     var ue_furl = "fls-na.amazon.com";
#     var ue_sid = "960-1498102-4362846";
#     var ue_id = "W94X1BQ64XSTSQDCZAVK";
#
#     (function(e){var c=e;var a=c.ue||{};a.main_scope="mainscopecsm";a.q=[];a.t0=c.ue_t0||+new Date();a.d=g;function g(h){return +new Date()-(h?0:a.t0)}function d(h){return function(){a.q.push({n:h,a:arguments,t:a.d()})}}function b(m,l,h,j,i){var k={m:m,f:l,l:h,c:""+j,err:i,fromOnError:1,args:arguments};c.ueLogError(k);return false}b.skipTrace=1;e.onerror=b;function f(){c.uex("ld")}if(e.addEventListener){e.addEventListener("load",f,false)}else{if(e.attachEvent){e.attachEvent("onload",f)}}a.tag=d("tag");a.log=d("log");a.reset=d("rst");c.ue_csm=c;c.ue=a;c.ueLogError=d("err");c.ues=d("ues");c.uet=d("uet");c.uex=d("uex");c.uet("ue")})(window);(function(e,d){var a=e.ue||{};function c(g){if(!g){return}var f=d.head||d.getElementsByTagName("head")[0]||d.documentElement,h=d.createElement("script");h.async="async";h.src=g;f.insertBefore(h,f.firstChild)}function b(){var k=e.ue_cdn||"z-ecx.images-amazon.com",g=e.ue_cdns||"images-na.ssl-images-amazon.com",j="/images/G/01/csminstrumentation/",h=e.ue_file||"ue-full-11e51f253e8ad9d145f4ed644b40f692._V1_.js",f,i;if(h.indexOf("NSTRUMENTATION_FIL")>=0){return}if("ue_https" in e){f=e.ue_https}else{f=e.location&&e.location.protocol=="https:"?1:0}i=f?"https://":"http://";i+=f?g:k;i+=j;i+=h;c(i)}if(!e.ue_inline){if(a.loadUEFull){a.loadUEFull()}else{b()}}a.uels=c;e.ue=a})(window,document);
#
#     if (window.ue && window.ue.tag) { window.ue.tag('list:show:signed_out', ue.main_scope);window.ue.tag('list:show:signed_out:desktop', ue.main_scope); }
#   </script>
# <script type="text/javascript">
#         if (window.Mobvious === undefined) {
#           window.Mobvious = {};
#         }
#         window.Mobvious.device_type = 'desktop';
#         </script>
# <script src="https://s.gr-assets.com/assets/webfontloader-f5925439393a000d48096973793890d8.js"></script>
# <script>
# //<![CDATA[
#
#   WebFont.load({
#     classes: false,
#     custom: {
#       families: ["Lato:n4,n7,i4", "Merriweather:n4,n7,i4"],
#       urls: ["https://s.gr-assets.com/assets/gr/fonts-e256f84093cc13b27f5b82343398031a.css"]
#     }
#   });
#
# //]]>
# </script>
# <link href="https://s.gr-assets.com/assets/goodreads-e690cbe2cab714907b0ce46bce7b91dc.css" media="all" rel="stylesheet">
# <style media="screen" type="text/css">
#     .bigTabs {
#       margin-bottom: 10px;
#     }
#
#     .list_read{
#       background-color: #D7D2C4;
#       float: left;
#     }
#   </style>
# <link href="https://s.gr-assets.com/assets/common_images-670d97636259cafc355c94fc43e871d7.css" media="screen" rel="stylesheet"/>
# <script src="https://s.gr-assets.com/assets/desktop/libraries-41a429a5834e6352d597e2cf0b06486f.js"></script>
# <script src="https://s.gr-assets.com/assets/application-e1f7a59d8a3ee82c2db20200ea66a37f.js"></script>
# <script>
#   //<![CDATA[
#     var gptAdSlots = gptAdSlots || [];
#     var googletag = googletag || {};
#     googletag.cmd = googletag.cmd || [];
#     (function() {
#       var gads = document.createElement("script");
#       gads.async = true;
#       gads.type = "text/javascript";
#       var useSSL = "https:" == document.location.protocol;
#       gads.src = (useSSL ? "https:" : "http:") +
#       "//securepubads.g.doubleclick.net/tag/js/gpt.js";
#       var node = document.getElementsByTagName("script")[0];
#       node.parentNode.insertBefore(gads, node);
#     })();
#     // page settings
#   //]]>
# </script>
# <script>
#   //<![CDATA[
#     googletag.cmd.push(function() {
#       googletag.pubads().setTargeting("sid", "osid.4c2a2e012869238247dc3ba98f7c0ef9");
#     googletag.pubads().setTargeting("grsession", "osid.4c2a2e012869238247dc3ba98f7c0ef9");
#     googletag.pubads().setTargeting("surface", "desktop");
#     googletag.pubads().setTargeting("signedin", "false");
#     googletag.pubads().setTargeting("gr_author", "false");
#     googletag.pubads().setTargeting("author", []);
#     googletag.pubads().setTargeting("shelf", ["film","movie","movies"]);
#     googletag.pubads().setTargeting("tags", ["1423","1471","1372"]);
#     googletag.pubads().setTargeting("gtargeting", "1");
#     googletag.pubads().setTargeting("resource", "List_720");
#       googletag.pubads().enableAsyncRendering();
#       googletag.pubads().enableSingleRequest();
#       googletag.pubads().collapseEmptyDivs(true);
#       googletag.pubads().disableInitialLoad();
#       googletag.enableServices();
#     });
#   //]]>
# </script>
# <script>
#   //<![CDATA[
#     ! function(a9, a, p, s, t, A, g) {
#       if (a[a9]) return;
#
#       function q(c, r) {
#         a[a9]._Q.push([c, r])
#       }
#       a[a9] = {
#       init: function() {
#         q("i", arguments)
#       },
#       fetchBids: function() {
#         q("f", arguments)
#       },
#       setDisplayBids: function() {},
#         _Q: []
#       };
#       A = p.createElement(s);
#       A.async = !0;
#       A.src = t;
#       g = p.getElementsByTagName(s)[0];
#       g.parentNode.insertBefore(A, g)
#     }("apstag", window, document, "script", "//c.amazon-adsystem.com/aax2/apstag.js");
#
#     apstag.init({
#       pubID: '3211', adServer: 'googletag', bidTimeout: 4e3, params: { aps_privacy: '1YN' }
#     });
#   //]]>
# </script>
# <meta content="authenticity_token" name="csrf-param">
# <meta content="PL4qABfRXJF5PmGHKvEWcPb7Yqvi2hlsYLcWmdmOjgGBsTFvqKc9USlghTqUpQ6BUNq3dDUcKqW/ikM00zLWNg==" name="csrf-token">
# <meta content="W94X1BQ64XSTSQDCZAVK" name="request-id"/>
# <script defer="defer" src="https://s.gr-assets.com/assets/react_client_side/external_dependencies-2e2b90fafc.js"></script>
# <script defer="defer" src="https://s.gr-assets.com/assets/react_client_side/site_header-b38d149ccc.js"></script>
# <script defer="defer" src="https://s.gr-assets.com/assets/react_client_side/custom_react_ujs-b1220d5e0a4820e90b905c302fc5cb52.js"></script>
# <script>
#   //<![CDATA[
#     $grfb.init.done(function() {
#       if (this.auth.status === "not_authorized") {
#         // logged into Facebook user but not a GR app user; show FB button
#         $j("#generalRegPrompt").hide();
#       } else {
#         $j("#facebookRegPrompt").hide();
#       }
#       $j("#connectPrompt").show();
#     });
#   //]]>
# </script>
# <link href="/opensearch.xml" rel="search" title="Goodreads" type="application/opensearchdescription+xml"/>
# <script>
# //<![CDATA[
#
#   var GoodreadsAnalytics = GoodreadsAnalytics || {};
#   var _gaq = _gaq || [];
#
#   GoodreadsAnalytics.push = function () {
#     _gaq.push.apply(_gaq, arguments);
#   }
#
#   GoodreadsAnalytics.push(['_setAccount', 'UA-968618-1']);
#   GoodreadsAnalytics.push(['_setCustomVar',
#     1,                        // Slot 1
#     'User Status',            // Custom variable name
#     'signed_out',  // Custom variable value: signed_out, signed_in,
#                               //   signed_in_facebook_connected, or
#                               //   goodreads_member_previously_signed_in
#     2                         // Visit-level scope, which means slot 1 will be
#                               //   free when the visit ends.
#   ]);
#   GoodreadsAnalytics.push(['_setCustomVar',
#     2,                        // Slot 2
#     'Device Type',            // Custom variable name
#     'desktop',         // Custom variable value: desktop, mobile, or
#                               //   tablet
#     2                         // Visit-level scope, which means slot 2 will be
#                               //   free when the visit ends.
#   ]);
#   GoodreadsAnalytics.push(['_trackPageview']);
#
#   (function () {
#     var ga = document.createElement('script');
#     ga.type = 'text/javascript';
#     ga.async = true;
#     ga.src = ('https:' == document.location.protocol ? 'https://' : 'http://') + 'stats.g.doubleclick.net/dc.js';
#     var s = document.getElementsByTagName('script')[0];
#     s.parentNode.insertBefore(ga, s);
#   })();
#
# //]]>
# </script>
# <meta content="27 books based on 67 votes: Harry Potter and the Half-Blood Prince by J.K. Rowling, Twilight by Stephenie Meyer, The Hobbit, or There and Back Again by J..." name="description"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="@goodreads" name="twitter:site"/>
# <meta content="Books that are being made into movies 2009 (27 books)" name="twitter:title"/>
# <meta content="27 books based on 67 votes: Harry Potter and the Half-Blood Prince by J.K. Rowling, Twilight by Stephenie Meyer, The Hobbit, or There and Back Again by J..." name="twitter:description"/>
# <meta content="cEf8XOH0pulh1aYQeZ1gkXHsQ3dMPSyIGGYqmF53690=" name="verify-v1"/>
# <meta content="PfFjeZ9OK1RrUrKlmAPn_iZJ_vgHaZO1YQ-QlG2VsJs" name="google-site-verification">
# <meta content="app-id=355833469" name="apple-itunes-app"/>
# </meta></meta></meta></link></head>
# <body class="">
# <div data-react-class="ReactComponents.StoresInitializer" data-react-props="{}"><noscript data-react-checksum="-1436151527" data-reactid=".vl3uzg8b1i"></noscript></div>
# <div class="content">
# <script>
#   //<![CDATA[
#     var initializeGrfb = function() {
#       $grfb.initialize({
#         appId: "2415071772"
#       });
#     };
#     if (typeof $grfb !== "undefined") {
#       initializeGrfb();
#     } else {
#       window.addEventListener("DOMContentLoaded", function() {
#         if (typeof $grfb !== "undefined") {
#           initializeGrfb();
#         }
#       });
#     }
#   //]]>
# </script>
# <script>
#   //<![CDATA[
#     function loadScript(url, callback) {
#       var script = document.createElement("script");
#       script.type = "text/javascript";
#
#       if (script.readyState) {  //Internet Explorer
#           script.onreadystatechange = function() {
#             if (script.readyState == "loaded" ||
#                     script.readyState == "complete") {
#               script.onreadystatechange = null;
#               callback();
#             }
#           };
#       } else {  //Other browsers
#         script.onload = function() {
#           callback();
#         };
#       }
#
#       script.src = url;
#       document.getElementsByTagName("head")[0].appendChild(script);
#     }
#
#     function initAppleId() {
#       AppleID.auth.init({
#         clientId : 'com.goodreads.app',
#         scope : 'name email',
#         redirectURI: 'https://www.goodreads.com/apple_users/sign_in_with_apple_web',
#         state: 'apple_oauth_state_6f1604a4-1097-40ed-ab7a-15c316286305'
#       });
#     }
#
#     var initializeSiwa = function() {
#       var APPLE_SIGN_IN_JS_URL =  "https://appleid.cdn-apple.com/appleauth/static/jsapi/appleid/1/en_US/appleid.auth.js"
#       loadScript(APPLE_SIGN_IN_JS_URL, initAppleId);
#     };
#     if (typeof AppleID !== "undefined") {
#       initAppleId();
#     } else {
#       initializeSiwa();
#     }
#   //]]>
# </script>
# <div class="siteHeader">
# <div data-react-class="ReactComponents.HeaderStoreConnector" data-react-props='{"myBooksUrl":"/review/list?ref=nav_mybooks","browseUrl":"/book?ref=nav_brws","recommendationsUrl":"/recommendations?ref=nav_brws_recs","choiceAwardsUrl":"/choiceawards?ref=nav_brws_gca","genresIndexUrl":"/genres?ref=nav_brws_genres","giveawayUrl":"/giveaway?ref=nav_brws_giveaways","exploreUrl":"/book?ref=nav_brws_explore","homeUrl":"/?ref=nav_home","listUrl":"/list?ref=nav_brws_lists","newsUrl":"/news?ref=nav_brws_news","communityUrl":"/group?ref=nav_comm","groupsUrl":"/group?ref=nav_comm_groups","quotesUrl":"/quotes?ref=nav_comm_quotes","featuredAskAuthorUrl":"/ask_the_author?ref=nav_comm_askauthor","discussionsUrl":"/topic?ref=nav_comm_discuss","autocompleteUrl":"/book/auto_complete","defaultLogoActionUrl":"/","topFullImage":{"clickthroughUrl":"https://www.goodreads.com/blog/show/2050?ref=sr2021_eb","altText":"Goodreads Summer Reading 2021","backgroundColor":"#FFD767","xs":{"1x":"https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/siteheaderbannerimages/1619806865i/43.jpg","2x":"https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/siteheaderbannerimages/1619806872i/44.jpg"},"md":{"1x":"https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/siteheaderbannerimages/1619806854i/41.jpg","2x":"https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/siteheaderbannerimages/1619806860i/42.jpg"}},"logo":{"imageUrl":"https://images.gr-assets.com/doodles/1619806753i/30.svg","clickthroughUrl":"/","altText":"Goodreads Summer Reading 2021"},"searchPath":"/search","newReleasesUrl":"/book/popular_by_date/2021/5?ref=nav_brws_newrels","signInUrl":"/user/sign_in","signUpUrl":"/user/sign_up","signInWithReturnUrl":true,"deployServices":[],"defaultLogoAltText":"Goodreads Home","mobviousDeviceType":"desktop"}'><header data-react-checksum="2124733033" data-reactid=".wuo5sb5cfs"><div class="siteHeader__topFullImageContainer" data-reactid=".wuo5sb5cfs.0" style="background-color:#FFD767;"><a class="siteHeader__topFullImageLink" data-reactid=".wuo5sb5cfs.0.0" href="https://www.goodreads.com/blog/show/2050?ref=sr2021_eb"><picture data-reactid=".wuo5sb5cfs.0.0.0"><source data-reactid=".wuo5sb5cfs.0.0.0.0" media="(min-width: 768px)" srcset="https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/siteheaderbannerimages/1619806854i/41.jpg 1x, https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/siteheaderbannerimages/1619806860i/42.jpg 2x"/><img alt="Goodreads Summer Reading 2021" class="siteHeader__topFullImage" data-reactid=".wuo5sb5cfs.0.0.0.1" src="https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/siteheaderbannerimages/1619806865i/43.jpg" srcset="https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/siteheaderbannerimages/1619806872i/44.jpg 2x"/></picture></a></div><div class="siteHeader__topLine gr-box gr-box--withShadow" data-reactid=".wuo5sb5cfs.1"><div class="siteHeader__contents" data-reactid=".wuo5sb5cfs.1.0"><div class="siteHeader__topLevelItem siteHeader__topLevelItem--searchIcon" data-reactid=".wuo5sb5cfs.1.0.0"><button aria-label="Toggle search" class="siteHeader__searchIcon gr-iconButton" data-reactid=".wuo5sb5cfs.1.0.0.0" data-ux-click="true" type="button"></button></div><a class="siteHeader__logo siteHeader__logo--doodle" data-reactid=".wuo5sb5cfs.1.0.1" href="/"><picture data-reactid=".wuo5sb5cfs.1.0.1.0"><img alt="Goodreads Summer Reading 2021" data-reactid=".wuo5sb5cfs.1.0.1.0.0" src="https://images.gr-assets.com/doodles/1619806753i/30.svg"/></picture></a><nav class="siteHeader__primaryNavInline" data-reactid=".wuo5sb5cfs.1.0.2"><ul class="siteHeader__menuList" data-reactid=".wuo5sb5cfs.1.0.2.0" role="menu"><li class="siteHeader__topLevelItem siteHeader__topLevelItem--home" data-reactid=".wuo5sb5cfs.1.0.2.0.0"><a class="siteHeader__topLevelLink" data-reactid=".wuo5sb5cfs.1.0.2.0.0.0" href="/?ref=nav_home">Home</a></li><li class="siteHeader__topLevelItem" data-reactid=".wuo5sb5c ...
# </div>
# <div class="siteHeaderBottomSpacer"></div>
# <div class="mainContentContainer">
# <div class="mainContent">
# <div id="premiumAdTop">
# <div data-react-class="ReactComponents.GoogleBannerAd" data-react-props='{"adId":"","className":"googleBannerAd--pushdown"}'></div>
# </div>
# <div class="mainContentFloat">
# <div id="flashContainer">
# </div>
# <div id="connectPrompt" style="display:none;">
# <div class="connectPromptHolder">
# <div class="vcenteredLineOfBlocks" style="margin:15px auto 0;">
# <div class="regPromptText">
# <div class="title">
# Discover new books on Goodreads
# </div>
# <div class="subtext">
# Meet your next favorite book
# </div>
# </div>
# <div id="facebookRegPrompt">
# <a class="fbjsLogin fbButton connectPromptButton" data-tracking-id="fb_connect_prompt_quote_reg_prompt" href="/user/new">
# <img alt="Facebook" src="https://s.gr-assets.com/assets/facebook/fb-icon-8d74377d3ff4a368f05860c35d8025b2.png"/>
# Sign in with Facebook
# </a>
# <div class="connectPromptAlternates">
# <a href="/user/sign_up?connect_prompt=true">Sign in <br/> options</a>
# </div>
# </div>
# <div id="generalRegPrompt">
# <div class="connectPromptButton">
# <a class="button orange" href="/user/sign_up?connect_prompt=true">Join Goodreads</a>
# </div>
# </div>
# </div>
# <div class="clear"></div>
# </div>
# </div>
# <div class="leftContainer">
# <div class="pageHeader">
# <a href="/list">Listopia</a>
# </div>
# <br class="clear"/>
# <h1 class="gr-h1 gr-h1--serif">Books that are being made into movies 2009
#   </h1>
# <div class="mediumText" style="padding-bottom: 10px">
#       Books we're heard or know will be made into movies in the near future.
#     </div>
# <div id="score_explanation" style="display:none">
# <h1>Score</h1>
# <p>
#     A book’s total score is based on multiple factors, including the number of
#     people who have voted for it and how highly those voters ranked the book.
#     </p>
# </div>
# <div class="tabs bigTabs">
# <div class="right">
# <a class="selectedTab js-dhtmlTab" data-tab-name="all_votes" data-tab-set="256290311" href="/list/show/720.Books_that_are_being_made_into_movies_2009?tab=all_votes" id="all_votesLink">All Votes</a>
# <a class="tab js-dhtmlTab" data-tab-name="Add_Books_To_This_List" data-tab-set="256290311" href="/list/show/720.Books_that_are_being_made_into_movies_2009?tab=Add_Books_To_This_List" id="Add_Books_To_This_ListLink">Add Books To This List</a>
# </div>
# <div class="clear"> </div></div><script charset="utf-8" type="text/javascript">
# //<![CDATA[
#
#   current_tabs[256290311] = 'all_votes';
#
#   Event.observe(window, 'load', function(e) {
#     // Switch to an anchored tab if specified in the URL
#     if (location.href.include('#')) {
#       var tabID = location.href.split('#')[1];
#       if (tabID != '' && $(tabID)) {
#         changeTab(tabID)
#       }
#     }
#   })
# //]]>
# </script>
# <script charset="utf-8" type="text/javascript">
# //<![CDATA[
#
#   function submitShelfLink(unique_id, book_id, shelf_id, shelf_name, submit_form, exclusive) {
#     var checkbox_id = 'shelf_name_' + unique_id + '_' + shelf_id;
#     var element = document.getElementById(checkbox_id)
#
#     var checked = element.checked
#     if (checked && exclusive) {
#       // can't uncheck a radio by clicking it!
#       return
#     }
#     if(document.getElementById("savingMessage")){
#       Element.show('savingMessage')
#     }
#     var element_id = 'shelfInDropdownName_' + unique_id + '_' + shelf_id;
#     Element.update(element_id, "saving...");
#     if (submit_form) {
#       Element.hide('shelfDropdown_' + unique_id)
#       var form = document.getElementById('addBookForm' + book_id)
#       if (form) {
#         form.shelf.value = shelf_name
#         form.onsubmit()
#       }
#     }
#     else {
#       var action = checked ? 'remove' : ''
#       element.checked = !element.checked
#       new Ajax.Request('/shelf/add_to_shelf', {asynchronous:true, evalScripts:true, onSuccess:function(request){shelfSubmitted(request, book_id, checkbox_id, element_id, unique_id, shelf_name)}, parameters:'book_id=' + book_id + '&name=' + shelf_name + '&a=' + action + '&authenticity_token=' + encodeURIComponent('VnFaZytjQQ91CpimHd0p5hsS85VYRMVSwpRcKLjYB2jrfkEIlBUgzyVUfBujiTEXvTMmSo+C9psdqQmFsmRfXw==')})
#     }
#   }
#
#   function shelfSubmitted(request, book_id, checkbox_id, element_id, unique_id, shelf_name) {
#     Element.update('shelfListfalse_' + book_id, request.responseText)
#     afterShelfSave(checkbox_id, element_id, unique_id, shelf_name.escapeHTML())
#   }
#
#   function refreshGroupBox(group_id, book_id) {
#     new Ajax.Updater('addGroupBooks' + book_id + '', '/group/add_book_box', {asynchronous:true, evalScripts:true, onSuccess:function(request){refreshGroupBoxComplete(request, book_id);}, parameters:'id=' + group_id + '&book_id=' + book_id + '&refresh=true' + '&authenticity_token=' + encodeURIComponent('Y2z2nja7HQx2/kXoWw1ShITh14TyYKjMwULjoF0x4wTeY+3xic18zCagoVXlWUp1IsACWyWmmwUef7YNV427Mw==')})
#   }
# //]]>
# </script>
# <div id="all_votes">
# <table class="tableList js-dataTooltip">
# <!-- Add query string params -->
# <tr itemscope="" itemtype="http://schema.org/Book">
# <td class="number" valign="top">1</td>
# <td valign="top" width="5%">
# <div class="u-anchorTarget" id="1"></div>
# <div class="js-tooltipTrigger tooltipTrigger" data-resource-id="1" data-resource-type="Book">
# <a href="/book/show/1.Harry_Potter_and_the_Half_Blood_Prince" title="Harry Potter and the Half-Blood Prince">
# <img alt="Harry Potter and the Half-B..." class="bookCover" itemprop="image" src="https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1587697303i/1._SX50_.jpg"/>
# </a> </div>
# </td>
# <td valign="top" width="100%">
# <a class="bookTitle" href="/book/show/1.Harry_Potter_and_the_Half_Blood_Prince" itemprop="url">
# <span aria-level="4" itemprop="name" role="heading">Harry Potter and the Half-Blood Prince (Harry Potter, #6)</span>
# </a> <br>
# <span class="by">by</span>
# <span itemprop="author" itemscope="" itemtype="http://schema.org/Person">
# <div class="authorName__container">
# <a class="authorName" href="https://www.goodreads.com/author/show/1077326.J_K_Rowling" itemprop="url"><span itemprop="name">J.K. Rowling</span></a>
# </div>
# </span>
# <br/>
# <div>
# <span class="greyText smallText uitext">
# <span class="minirating"><span class="stars staticStars notranslate"><span class="staticStar p10" size="12x12"></span><span class="staticStar p10" size="12x12"></span><span class="staticStar p10" size="12x12"></span><span class="staticStar p10" size="12x12"></span><span class="staticStar p6" size="12x12"></span></span> 4.57 avg rating — 2,599,725 ratings</span>
# </span>
# </div>
# <div style="margin-top: 5px">
# <span class="smallText uitext">
# <a href="#" onclick="Lightbox.showBoxByID('score_explanation', 300); return false;">score: 2,170</a>,
#               <span class="greyText">and</span>
# <a href="#" id="loading_link_813664" onclick="new Ajax.Request('/list/list_book/25922', {asynchronous:true, evalScripts:true, onFailure:function(request){Element.hide('loading_anim_813664');$('loading_link_813664').innerHTML = '&lt;span class=&quot;error&quot;&gt;ERROR&lt;/span&gt;try again';$('loading_link_813664').show();;Element.hide('loading_anim_813664');}, onLoading:function(request){;Element.show('loading_anim_813664');Element.hide('loading_link_813664')}, onSuccess:function(request){Element.hide('loading_anim_813664');Element.show('loading_link_813664');}, parameters:'authenticity_token=' + encodeURIComponent('dqAD5c6jfmfWpRud8Rm9oQYr5kVMfjQyNfII2aiArtrLrxiKcdUfp4b7/yBPTaVQoAozmpu4B/vqz110ojz27Q==')}); return false;">22 people voted</a><img alt="Loading trans" class="loading" id="loading_anim_813664" src="https://s.gr-assets.com/assets/loading-trans-ced157046184c3bc7c180ffbfc6825a4.gif" style="display:none"/>
#
#
#             </span>
# </div>
# </br></td>
# <td width="130px">
# <div class="wtrButtonContainer wtrSignedOut" id="1_book_1">
# <div class="wtrUp wtrLeft">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="ay/slR6rxTVDKcThXSi0lqpEfseF/pVRztT7WMCu9u7WIPf6od2k9RN3IFzjfKxnDGWrGFI4ppgR6a71yhKu2Q=="/>
# <input id="book_id" name="book_id" type="hidden" value="1"/>
# <input id="name" name="name" type="hidden" value="to-read"/>
# <input id="unique_id" name="unique_id" type="hidden" value="1_book_1"/>
# <input id="wtr_new" name="wtr_new" type="hidden" value="true"/>
# <input id="from_choice" name="from_choice" type="hidden" value="false"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input class="wtrLeftUpRef" id="ref" name="ref" type="hidden" value=""/>
# <input class="wtrExisting" id="existing_review" name="existing_review" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# <button class="wtrToRead" type="submit">
# <span class="progressTrigger">Want to Read</span>
# <span class="progressIndicator">saving…</span>
# </button>
# </form>
# </div>
# <div class="wtrRight wtrUp">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" class="hiddenShelfForm" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="jBxMLirZBYXZAHGfeYzDDNH8cdvHBfqEjILYA81kqowxE1dBla9kRYlelSLH2Nv9d92kBBDDyU1Tv42ux9jyuw=="/>
# <input id="unique_id" name="unique_id" type="hidden" value="1_book_1"/>
# <input id="book_id" name="book_id" type="hidden" value="1"/>
# <input id="a" name="a" type="hidden"/>
# <input id="name" name="name" type="hidden"/>
# <input id="from_choice" name="from_choice" type="hidden" value="false"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# </form>
# <button class="wtrShelfButton"></button>
# <div class="wtrShelfMenu">
# <ul class="wtrExclusiveShelves">
# <li><button class="wtrExclusiveShelf" name="name" type="submit" value="to-read">
# <span class="progressTrigger">Want to Read</span>
# <img alt="saving…" class="progressIndicator" src="https://s.gr-assets.com/assets/loading-trans-ced157046184c3bc7c180ffbfc6825a4.gif"/>
# </button>
# </li>
# <li><button class="wtrExclusiveShelf" name="name" type="submit" value="currently-reading">
# <span class="progressTrigger">Currently Reading</span>
# <img alt="saving…" class="progressIndicator" src="https://s.gr-assets.com/assets/loading-trans-ced157046184c3bc7c180ffbfc6825a4.gif"/>
# </button>
# </li>
# <li><button class="wtrExclusiveShelf" name="name" type="submit" value="read">
# <span class="progressTrigger">Read</span>
# <img alt="saving…" class="progressIndicator" src="https://s.gr-assets.com/assets/loading-trans-ced157046184c3bc7c180ffbfc6825a4.gif"/>
# </button>
# </li>
# </ul>
# </div>
# </div>
# <div class="ratingStars wtrRating">
# <div class="starsErrorTooltip hidden">
# Error rating book. Refresh and try again.
# </div>
# <div class="myRating uitext greyText">Rate this book</div>
# <div class="clearRating uitext">Clear rating</div>
# <div class="stars" data-rating="0" data-resource-id="1" data-submit-url="/review/rate/1?stars_click=true&amp;wtr_button_id=1_book_1" data-user-id="0"><a class="star off" href="#" ref="" title="did not like it">1 of 5 stars</a><a class="star off" href="#" ref="" title="it was ok">2 of 5 stars</a><a class="star off" href="#" ref="" title="liked it">3 of 5 stars</a><a class="star off" href="#" ref="" title="really liked it">4 of 5 stars</a><a class="star off" href="#" ref="" title="it was amazing">5 of 5 stars</a></div>
# </div>
# </div>
# </td>
# </tr>
# <!-- Add query string params -->
# <tr itemscope="" itemtype="http://schema.org/Book">
# <td class="number" valign="top">2</td>
# <td valign="top" width="5%">
# <div class="u-anchorTarget" id="41865"></div>
# <div class="js-tooltipTrigger tooltipTrigger" data-resource-id="41865" data-resource-type="Book">
# <a href="/book/show/41865.Twilight" title="Twilight">
# <img alt="Twilight (Twilight, #1)" class="bookCover" itemprop="image" src="https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1361039443i/41865._SY75_.jpg"/>
# </a> </div>
# </td>
# <td valign="top" width="100%">
# <a class="bookTitle" href="/book/show/41865.Twilight" itemprop="url">
# <span aria-level="4" itemprop="name" role="heading">Twilight (Twilight, #1)</span>
# </a> <br/>
# <span class="by">by</span>
# <span itemprop="author" itemscope="" itemtype="http://schema.org/Person">
# <div class="authorName__container">
# <a class="authorName" href="https://www.goodreads.com/author/show/941441.Stephenie_Meyer" itemprop="url"><span itemprop="name">Stephenie Meyer</span></a>
# </div>
# </span>
# <br/>
# <div>
# <span class="greyText smallText uitext">
# <span class="minirating"><span class="stars staticStars notranslate"><span class="staticStar p10" size="12x12"></span><span class="staticStar p10" size="12x12"></span><span class="staticStar p10" size="12x12"></span><span class="staticStar p6" size="12x12"></span><span class="staticStar p0" size="12x12"></span></span> 3.61 avg rating — 5,249,486 ratings</span>
# </span>
# </div>
# <div style="margin-top: 5px">
# <span class="smallText uitext">
# <a href="#" onclick="Lightbox.showBoxByID('score_explanation', 300); return false;">score: 1,868</a>,
#               <span class="greyText">and</span>
# <a href="#" id="loading_link_887871" onclick="new Ajax.Request('/list/list_book/25934', {asynchronous:true, evalScripts:true, onFailure:function(request){Element.hide('loading_anim_887871');$('loading_link_887871').innerHTML = '&lt;span class=&quot;error&quot;&gt;ERROR&lt;/span&gt;try again';$('loading_link_887871').show();;Element.hide('loading_anim_887871');}, onLoading:function(request){;Element.show('loading_anim_887871');Element.hide('loading_link_887871')}, onSuccess:function(request){Element.hide('loading_anim_887871');Element.show('loading_link_887871');}, parameters:'authenticity_token=' + encodeURIComponent('G5SPr4ZroKTOeMF/RflPTgfjuMUjg86owPtflgHp5+mmm5TAOR3BZJ4mJcL7rVe/ocJtGvRF/WEfxgo7C1W/3g==')}); return false;">19 people voted</a><img alt="Loading trans" class="loading" id="loading_anim_887871" src="https://s.gr-assets.com/assets/loading-trans-ced157046184c3bc7c180ffbfc6825a4.gif" style="display:none"/>
#
#
#             </span>
# </div>
# </td>
# <td width="130px">
# <div class="wtrButtonContainer wtrSignedOut" id="2_book_41865">
# <div class="wtrUp wtrLeft">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="Wb0jEyq3bcz+wHZjRa5nUumsqtkpFiykBGr88OiXe2nksjh8lcEMDK6ekt77+n+jT41/Bv7QH23bV6ld4isjXg=="/>
# <input id="book_id" name="book_id" type="hidden" value="41865"/>
# <input id="name" name="name" type="hidden" value="to-read"/>
# <input id="unique_id" name="unique_id" type="hidden" value="2_book_41865"/>
# <input id="wtr_new" name="wtr_new" type="hidden" value="true"/>
# <input id="from_choice" name="from_choice" type="hidden" value="false"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input class="wtrLeftUpRef" id="ref" name="ref" type="hidden" value=""/>
# <input class="wtrExisting" id="existing_review" name="existing_review" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# <button class="wtrToRead" type="submit">
# <span class="progressTrigger">Want to Read</span>
# <span class="progressIndicator">saving…</span>
# </button>
# </form>
# </div>
# <div class="wtrRight wtrUp">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" class="hiddenShelfForm" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="ye/blwF6lJp2cqlj4QQIn5dX/EZWv5EbpbRoNPpSu9d04MD4vgz1WiYsTd5fUBBuMXYpmYF5otJ6iT2Z8O7j4A=="/>
# <input id="unique_id" name="unique_id" type="hidden" value="2_book_41865"/>
# <input id="book_id" name="book_id" type="hidden" value="41865"/>
# <input id="a" name="a" type="hidden"/>
# <input id="name" name="name" type="hidden"/>
# <input id="from_choice" name="from_choice" type="hidden" value="false"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# </form>
# <button class="wtrShelfButton"></button>
# </div>
# <div class="ratingStars wtrRating">
# <div class="starsErrorTooltip hidden">
# Error rating book. Refresh and try again.
# </div>
# <div class="myRating uitext greyText">Rate this book</div>
# <div class="clearRating uitext">Clear rating</div>
# <div class="stars" data-rating="0" data-resource-id="41865" data-submit-url="/review/rate/41865?stars_click=true&amp;wtr_button_id=2_book_41865" data-user-id="0"><a class="star off" href="#" ref="" title="did not like it">1 of 5 stars</a><a class="star off" href="#" ref="" title="it was ok">2 of 5 stars</a><a class="star off" href="#" ref="" title="liked it">3 of 5 stars</a><a class="star off" href="#" ref="" title="really liked it">4 of 5 stars</a><a class="star off" href="#" ref="" title="it was amazing">5 of 5 stars</a></div>
# </div>
# </div>
# </td>
# </tr>
# <!-- Add query string params -->
# <tr itemscope="" itemtype="http://schema.org/Book">
# <td class="number" valign="top">3</td>
# <td valign="top" width="5%">
# <div class="u-anchorTarget" id="5907"></div>
# <div class="js-tooltipTrigger tooltipTrigger" data-resource-id="5907" data-resource-type="Book">
# <a href="/book/show/5907.The_Hobbit_or_There_and_Back_Again" title="The Hobbit, or There and Back Again">
# <img alt="The Hobbit, or There and Ba..." class="bookCover" itemprop="image" src="https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1546071216i/5907._SY75_.jpg"/>
# </a> </div>
# </td>
# <td valign="top" width="100%">
# <a class="bookTitle" href="/book/show/5907.The_Hobbit_or_There_and_Back_Again" itemprop="url">
# <span aria-level="4" itemprop="name" role="heading">The Hobbit, or There and Back Again</span>
# </a> <br/>
# <span class="by">by</span>
# <span itemprop="author" itemscope="" itemtype="http://schema.org/Person">
# <div class="authorName__container">
# <a class="authorName" href="https://www.goodreads.com/author/show/656983.J_R_R_Tolkien" itemprop="url"><span itemprop="name">J.R.R. Tolkien</span></a>
# </div>
# </span>
# <br/>
# <div>
# <span class="greyText smallText uitext">
# <span class="minirating"><span class="stars staticStars notranslate"><span class="staticStar p10" size="12x12"></span><span class="staticStar p10" size="12x12"></span><span class="staticStar p10" size="12x12"></span><span class="staticStar p10" size="12x12"></span><span class="staticStar p3" size="12x12"></span></span> 4.28 avg rating — 3,069,217 ratings</span>
# </span>
# </div>
# <div style="margin-top: 5px">
# <span class="smallText uitext">
# <a href="#" onclick="Lightbox.showBoxByID('score_explanation', 300); return false;">score: 1,488</a>,
#               <span class="greyText">and</span>
# <a href="#" id="loading_link_514894" onclick="new Ajax.Request('/list/list_book/25919', {asynchronous:true, evalScripts:true, onFailure:function(request){Element.hide('loading_anim_514894');$('loading_link_514894').innerHTML = '&lt;span class=&quot;error&quot;&gt;ERROR&lt;/span&gt;try again';$('loading_link_514894').show();;Element.hide('loading_anim_514894');}, onLoading:function(request){;Element.show('loading_anim_514894');Element.hide('loading_link_514894')}, onSuccess:function(request){Element.hide('loading_anim_514894');Element.show('loading_link_514894');}, parameters:'authenticity_token=' + encodeURIComponent('ppo03bmpk+HHUIDAwxyGGeji5vDU1uqTx2YxLeIYQCAblS+yBt/yIZcOZH19SJ7oTsMzLwMQ2VoYW2SA6KQYFw==')}); return false;">15 people voted</a><img alt="Loading trans" class="loading" id="loading_anim_514894" src="https://s.gr-assets.com/assets/loading-trans-ced157046184c3bc7c180ffbfc6825a4.gif" style="display:none"/>
#
#
#             </span>
# </div>
# </td>
# <td width="130px">
# <div class="wtrButtonContainer wtrSignedOut" id="3_book_5907">
# <div class="wtrUp wtrLeft">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="nLzaomUkLWoDF0+z8zL3Jvg2nK0UK4gjqlOeGsKAWD4hs8HN2lJMqlNJqw5NZu/XXhdJcsPtu+p1bsu3yDwACQ=="/>
# <input id="book_id" name="book_id" type="hidden" value="5907"/>
# <input id="name" name="name" type="hidden" value="to-read"/>
# <input id="unique_id" name="unique_id" type="hidden" value="3_book_5907"/>
# <input id="wtr_new" name="wtr_new" type="hidden" value="true"/>
# <input id="from_choice" name="from_choice" type="hidden" value="false"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input class="wtrLeftUpRef" id="ref" name="ref" type="hidden" value=""/>
# <input class="wtrExisting" id="existing_review" name="existing_review" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# <button class="wtrToRead" type="submit">
# <span class="progressTrigger">Want to Read</span>
# <span class="progressIndicator">saving…</span>
# </button>
# </form>
# </div>
# <div class="wtrRight wtrUp">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" class="hiddenShelfForm" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="yrYM/YW/9ub1OHpIVD+aIgmd7dO/jA3l6F2Tj2+r9Vp3uReSOsmXJqVmnvXqa4LTr7w4DGhKPiw3YMYiZRetbQ=="/>
# <input id="unique_id" name="unique_id" type="hidden" value="3_book_5907"/>
# <input id="book_id" name="book_id" type="hidden" value="5907"/>
# <input id="a" name="a" type="hidden"/>
# <input id="name" name="name" type="hidden"/>
# <input id="from_choice" name="from_choice" type="hidden" value="false"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# </form>
# <button class="wtrShelfButton"></button>
# </div>
# <div class="ratingStars wtrRating">
# <div class="starsErrorTooltip hidden">
# Error rating book. Refresh and try again.
# </div>
# <div class="myRating uitext greyText">Rate this book</div>
# <div class="clearRating uitext">Clear rating</div>
# <div class="stars" data-rating="0" data-resource-id="5907" data-submit-url="/review/rate/5907?stars_click=true&amp;wtr_button_id=3_book_5907" data-user-id="0"><a class="star off" href="#" ref="" title="did not like it">1 of 5 stars</a><a class="star off" href="#" ref="" title="it was ok">2 of 5 stars</a><a class="star off" href="#" ref="" title="liked it">3 of 5 stars</a><a class="star off" href="#" ref="" title="really liked it">4 of 5 stars</a><a class="star off" href="#" ref="" title="it was amazing">5 of 5 stars</a></div>
# </div>
# </div>
# </td>
# </tr>
# <!-- Add query string params -->
# <tr itemscope="" itemtype="http://schema.org/Book">
# <td class="number" valign="top">4</td>
# <td valign="top" width="5%">
# <div class="u-anchorTarget" id="472331"></div>
# <div class="js-tooltipTrigger tooltipTrigger" data-resource-id="472331" data-resource-type="Book">
# <a href="/book/show/472331.Watchmen" title="Watchmen">
# <img alt="Watchmen" class="bookCover" itemprop="image" src="https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1442239711i/472331._SY75_.jpg"/>
# </a> </div>
# </td>
# <td valign="top" width="100%">
# <a class="bookTitle" href="/book/show/472331.Watchmen" itemprop="url">
# <span aria-level="4" itemprop="name" role="heading">Watchmen</span>
# </a> <br/>
# <span class="by">by</span>
# <span itemprop="author" itemscope="" itemtype="http://schema.org/Person">
# <div class="authorName__container">
# <a class="authorName" href="https://www.goodreads.com/author/show/3961.Alan_Moore" itemprop="url"><span itemprop="name">Alan Moore</span></a> <span class="greyText">(Goodreads Author)</span>
# </div>
# </span>
# <br/>
# <div>
# <span class="greyText smallText uitext">
# <span class="minirating"><span class="stars staticStars notranslate"><span class="staticStar p10" size="12x12"></span><span class="staticStar p10" size="12x12"></span><span class="staticStar p10" size="12x12"></span><span class="staticStar p10" size="12x12"></span><span class="staticStar p3" size="12x12"></span></span> 4.37 avg rating — 501,638 ratings</span>
# </span>
# </div>
# <div style="margin-top: 5px">
# <span class="smallText uitext">
# <a href="#" onclick="Lightbox.showBoxByID('score_explanation', 300); return false;">score: 1,191</a>,
#               <span class="greyText">and</span>
# <a href="#" id="loading_link_579884" onclick="new Ajax.Request('/list/list_book/25920', {asynchronous:true, evalScripts:true, onFailure:function(request){Element.hide('loading_anim_579884');$('loading_link_579884').innerHTML = '&lt;span class=&quot;error&quot;&gt;ERROR&lt;/span&gt;try again';$('loading_link_579884').show();;Element.hide('loading_anim_579884');}, onLoading:function(request){;Element.show('loading_anim_579884');Element.hide('loading_link_579884')}, onSuccess:function(request){Element.hide('loading_anim_579884');Element.show('loading_link_579884');}, parameters:'authenticity_token=' + encodeURIComponent('0l2x1d8skd4gf9urcVogFWuc0QYuKD7Cws3vvT3WMctvUqq6YFrwHnAhPxbPDjjkzb0E2fnuDQsd8LoQN2pp/A==')}); return false;">12 people voted</a><img alt="Loading trans" class="loading" id="loading_anim_579884" src="https://s.gr-assets.com/assets/loading-trans-ced157046184c3bc7c180ffbfc6825a4.gif" style="display:none"/>
#
#
#             </span>
# </div>
# </td>
# <td width="130px">
# <div class="wtrButtonContainer wtrSignedOut" id="4_book_472331">
# <div class="wtrUp wtrLeft">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="Enys0NIaOiPrljZKF7SJuiu07S3a2IKw3/Mntc4PBaqvc7e/bWxb47vI0vep4JFLjZU48g0esXkAznIYxLNdnQ=="/>
# <input id="book_id" name="book_id" type="hidden" value="472331"/>
# <input id="name" name="name" type="hidden" value="to-read"/>
# <input id="unique_id" name="unique_id" type="hidden" value="4_book_472331"/>
# <input id="wtr_new" name="wtr_new" type="hidden" value="true"/>
# <input id="from_choice" name="from_choice" type="hidden" value="false"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input class="wtrLeftUpRef" id="ref" name="ref" type="hidden" value=""/>
# <input class="wtrExisting" id="existing_review" name="existing_review" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# <button class="wtrToRead" type="submit">
# <span class="progressTrigger">Want to Read</span>
# <span class="progressIndicator">saving…</span>
# </button>
# </form>
# </div>
# <div class="wtrRight wtrUp">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" class="hiddenShelfForm" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="ulRkBACsjSYoqWvFQ6Upo+qN1VaVMxWdEiWl6Pp7gTIHW39rv9rs5nj3j3j98TFSTKwAiUL1JlTNGPBF8MfZBQ=="/>
# <input id="unique_id" name="unique_id" type="hidden" value="4_book_472331"/>
# <input id="book_id" name="book_id" type="hidden" value="472331"/>
# <input id="a" name="a" type="hidden"/>
# <input id="name" name="name" type="hidden"/>
# <input id="from_choice" name="from_choice" type="hidden" value="false"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# </form>
# <button class="wtrShelfButton"></button>
# </div>
# <div class="ratingStars wtrRating">
# <div class="starsErrorTooltip hidden">
# Error rating book. Refresh and try again.
# </div>
# <div class="myRating uitext greyText">Rate this book</div>
# <div class="clearRating uitext">Clear rating</div>
# <div class="stars" data-rating="0" data-resource-id="472331" data-submit-url="/review/rate/472331?stars_click=true&amp;wtr_button_id=4_book_472331" data-user-id="0"><a class="star off" href="#" ref="" title="did not like it">1 of 5 stars</a><a class="star off" href="#" ref="" title="it was ok">2 of 5 stars</a><a class="star off" href="#" ref="" title="liked it">3 of 5 stars</a><a class="star off" href="#" ref="" title="really liked it">4 of 5 stars</a><a class="star off" href="#" ref="" title="it was amazing">5 of 5 stars</a></div>
# </div>
# </div>
# </td>
# </tr>
# <!-- Add query string params -->
# <tr itemscope="" itemtype="http://schema.org/Book">
# <td class="number" valign="top">5</td>
# <td valign="top" width="5%">
# <div class="u-anchorTarget" id="28187"></div>
# <div class="js-tooltipTrigger tooltipTrigger" data-resource-id="28187" data-resource-type="Book">
# <a href="/book/show/28187.The_Lightning_Thief" title="The Lightning Thief">
# <img alt="The Lightning Thief (Percy ..." class="bookCover" itemprop="image" src="https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1400602609i/28187._SY75_.jpg"/>
# </a> </div>
# </td>
# <td valign="top" width="100%">
# <a class="bookTitle" href="/book/show/28187.The_Lightning_Thief" itemprop="url">
# <span aria-level="4" itemprop="name" role="heading">The Lightning Thief (Percy Jackson and the Olympians, #1)</span>
# </a> <br/>
# <span class="by">by</span>
# <span itemprop="author" itemscope="" itemtype="http://schema.org/Person">
# <div class="authorName__container">
# <a class="authorName" href="https://www.goodreads.com/author/show/15872.Rick_Riordan" itemprop="url"><span itemprop="name">Rick Riordan</span></a> <span class="greyText">(Goodreads Author)</span>
# </div>
# </span>
# <br/>
# <div>
# <span class="greyText smallText uitext">
# <span class="minirating"><span class="stars staticStars notranslate"><span class="staticStar p10" size="12x12"></span><span class="staticStar p10" size="12x12"></span><span class="staticStar p10" size="12x12"></span><span class="staticStar p10" size="12x12"></span><span class="staticStar p3" size="12x12"></span></span> 4.26 avg rating — 2,153,029 ratings</span>
# </span>
# </div>
# <div style="margin-top: 5px">
# <span class="smallText uitext">
# <a href="#" onclick="Lightbox.showBoxByID('score_explanation', 300); return false;">score: 1,089</a>,
#               <span class="greyText">and</span>
# <a href="#" id="loading_link_95047" onclick="new Ajax.Request('/list/list_book/32918', {asynchronous:true, evalScripts:true, onFailure:function(request){Element.hide('loading_anim_95047');$('loading_link_95047').innerHTML = '&lt;span class=&quot;error&quot;&gt;ERROR&lt;/span&gt;try again';$('loading_link_95047').show();;Element.hide('loading_anim_95047');}, onLoading:function(request){;Element.show('loading_anim_95047');Element.hide('loading_link_95047')}, onSuccess:function(request){Element.hide('loading_anim_95047');Element.show('loading_link_95047');}, parameters:'authenticity_token=' + encodeURIComponent('HxLLnmx/a7JOG1NKtoAmxmwZBqYxVbju84Hw5fFlWyKiHdDx0wkKch5Ft/cI1D43yjjTeeaTiycsvKVI+9kDFQ==')}); return false;">11 people voted</a><img alt="Loading trans" class="loading" id="loading_anim_95047" src="https://s.gr-assets.com/assets/loading-trans-ced157046184c3bc7c180ffbfc6825a4.gif" style="display:none"/>
#
#
#             </span>
# </div>
# </td>
# <td width="130px">
# <div class="wtrButtonContainer wtrSignedOut" id="5_book_28187">
# <div class="wtrUp wtrLeft">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="UQ11ai2GW+b7GuH9SdQPGCs9IF7UZ+2u0cHVYkB8BvbsAm4FkvA6JqtEBUD3gBfpjRz1gQOh3mcO/IDPSsBewQ=="/>
# <input id="book_id" name="book_id" type="hidden" value="28187"/>
# <input id="name" name="name" type="hidden" value="to-read"/>
# <input id="unique_id" name="unique_id" type="hidden" value="5_book_28187"/>
# <input id="wtr_new" name="wtr_new" type="hidden" value="true"/>
# <input id="from_choice" name="from_choice" type="hidden" value="false"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input class="wtrLeftUpRef" id="ref" name="ref" type="hidden" value=""/>
# <input class="wtrExisting" id="existing_review" name="existing_review" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# <button class="wtrToRead" type="submit">
# <span class="progressTrigger">Want to Read</span>
# <span class="progressIndicator">saving…</span>
# </button>
# </form>
# </div>
# <div class="wtrRight wtrUp">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" class="hiddenShelfForm" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="TemFCyJtkUtoZol3Mj2VOc4u/AhCl3D+5P0UfNehUGXw5p5knRvwizg4bcqMaY3IaA8p15VRQzc7wEHR3R0IUg=="/>
# <input id="unique_id" name="unique_id" type="hidden" value="5_book_28187"/>
# <input id="book_id" name="book_id" type="hidden" value="28187"/>
# <input id="a" name="a" type="hidden"/>
# <input id="name" name="name" type="hidden"/>
# <input id="from_choice" name="from_choice" type="hidden" value="false"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# </form>
# <button class="wtrShelfButton"></button>
# </div>
# <div class="ratingStars wtrRating">
# <div class="starsErrorTooltip hidden">
# Error rating book. Refresh and try again.
# </div>
# ...
# <div class="u-marginBottomXSmall">
# <div class="image">
# <a href="/blog/show/2068-pieces-of-mind-30-great-new-essay-collections"><img alt="Pieces of Mind: 30 Great New Essay Collections" src="https://images.gr-assets.com/blogs/1619024420p8/2068.jpg" width="100%"/></a>
# </div>
# <a class="bigText title" href="/blog/show/2068-pieces-of-mind-30-great-new-essay-collections">Pieces of Mind: 30 Great New Essay Collections</a>
# <div class="links">
# <div class="left">
# </div>
# <div class="action right">
# <a class="actionLinkLite" href="/blog/show/2068-pieces-of-mind-30-great-new-essay-collections">Read »</a>
# </div>
# </div>
# <div class="clear"></div>
# </div>
# <a class="actionLink right" href="/news">More articles…</a>
# <div class="clear"></div></div></div><div class="bigBoxBottom"></div></div> </div>
# </div>
# <ul class="listHeaderLinks stacked">
# <li>
# <a class="actionLinkLite" href="/list/new">Create New List</a>
# </li>
# <li>
# <a class="actionLinkLite" href="/list">All Lists</a>
# </li>
# <li>
# <a class="actionLinkLite" href="/list/created">Lists I Created</a>
# </li>
# <li>
# <a class="actionLinkLite" href="https://www.goodreads.com/user/new?remember=true&amp;return_url=%2Flist%2Fshow%2F720.Books_that_are_being_made_into_movies_2009">Lists I've Voted On</a>
# </li>
# <li>
# <a class="actionLinkLite" href="https://www.goodreads.com/user/new?remember=true&amp;return_url=%2Flist%2Fshow%2F720.Books_that_are_being_made_into_movies_2009">Lists I've Liked</a>
# </li>
# </ul>
# <p class="mediumText">
#       Anyone can add books to this list.
#   </p>
# <p>
# </p>
# <div data-react-class="ReactComponents.GoogleBannerAd" data-react-props='{"adId":"","className":"googleBannerAd--mediumRectangle"}'></div>
# <div data-react-class="ReactComponents.GoogleFeaturedContentModule" data-react-props='{"adId":"","trackingOptions":{"enableTracking":true,"adId":""},"isMobile":false,"isInline":false,"hasBottomBorder":false}'></div>
# <div class="clearFloats bigBox"><div class="h2Container gradientHeaderContainer"><h2 class="brownBackground"><div class="extraHeader"><span id="saving_notice" style="display:none">Saving <img alt="Loading trans" src="https://s.gr-assets.com/assets/loading-trans-ced157046184c3bc7c180ffbfc6825a4.gif"/></span></div><a href="/list/show/720.Books_that_are_being_made_into_movies_2009">My Votes</a></h2></div><div class="bigBoxBody"><div class="bigBoxContent containerWithHeaderContent">
# <a class="actionLink" href="https://www.goodreads.com/user/new?remember=true&amp;return_url=%2Flist%2Fshow%2F720.Books_that_are_being_made_into_movies_2009">vote now</a>
# <div class="clear"></div></div></div><div class="bigBoxBottom"></div></div>
# <br class="clear"/><br/>
# <div class="clearFloats bigBox"><div class="h2Container gradientHeaderContainer"><h2 class="brownBackground"><a href="/list/invite/720.Books_that_are_being_made_into_movies_2009">Friends Votes</a></h2></div><div class="bigBoxBody"><div class="bigBoxContent containerWithHeaderContent">
# <a class="actionLink" href="https://www.goodreads.com/user/new?remember=true&amp;return_url=%2Flist%2Fshow%2F720.Books_that_are_being_made_into_movies_2009">get your friends to vote</a>
# <div class="clear"></div></div></div><div class="bigBoxBottom"></div></div>
# <div data-react-class="ReactComponents.GoogleBannerAd" data-react-props='{"adId":"","className":"googleBannerAd--mediumRectangle"}'></div>
# </div>
# <div id="chooseExplanation" style="display:none">
# <h2>How to Vote</h2>
# <p>
#     To vote on existing books from the list, beside each book there is a link <span class="gr-button gr-button--small">vote for this book</span>  clicking it will add that book to your votes.
#   </p>
# <p>
#       To vote on books not in the list or books you couldn't find in the list, you can click on the tab <span class="bigTabs"><span class="tab">add books to this list</span></span> and then choose from your books, or simply search.
#     </p>
# </div>
# <div class="initiallyHidden" id="flagList720">
# <div class="modalBox">
# <h2>
# Flag this
# list
# </h2>
# <div class="flaggableText">
# </div>
# <h3>
# Why are you flagging this
# list?
# </h3>
# <form accept-charset="UTF-8" action="/flagged/create" method="post"><input name="utf8" type="hidden" value="✓"><input name="authenticity_token" type="hidden" value="pOsnWcXGHe+AOytd6kLiXOPc+8L5PteCHqYmUkHUUY8Z5Dw2erB8L9Blz+BUFvqtRf0uHS745EvBm3P/S2gJuA=="/>
# <input id="return_url" name="return_url" type="hidden" value="/"/>
# <input id="resource_id" name="resource_id" type="hidden" value="720"/>
# <input id="resource_type" name="resource_type" type="hidden" value="List"/>
# <input id="extra" name="extra" type="hidden" value=""/>
# <div class="formWithLabels">
# <label class="flaggable_reasons">
# <input checked="checked" id="reason_inappropriate" name="reason" type="radio" value="inappropriate"/>
# Inappropriate
# </label>
# <label class="flaggableReasonsDescription">
# The list (including its title or description) facilitates illegal activity, or contains hate speech or ad hominem attacks on a fellow Goodreads member or author.
# </label>
# <label class="flaggable_reasons">
# <input id="reason_spam_or_self-promotional" name="reason" type="radio" value="spam_or_self-promotional"/>
# Spam or Self-Promotional
# </label>
# <label class="flaggableReasonsDescription">
# The list is spam or self-promotional.
# </label>
# <label class="flaggable_reasons">
# <input id="reason_incorrect_book" name="reason" type="radio" value="incorrect_book"/>
# Incorrect Book
# </label>
# <label class="flaggableReasonsDescription">
# The list contains an incorrect book (please specify the title of the book).
# </label>
# <p>
# <label for="explanation">
# Details
# <span class="requiredIndicator">
# *
# </span>
# </label>
# </p>
# <textarea cols="45" id="explanation" name="explanation" placeholder="Please tell us more information about why you are flagging this." rows="5">
# </textarea>
# <p>
# <input class="button" data-confirm="We take abuse seriously on goodreads. Only flag lists that clearly need our attention. Are you sure you want to flag this list?" name="commit" type="submit" value="Flag this"/>
# or
# <a href="#" onclick="Lightbox.hideBox(); return false;">Cancel</a>
# </p>
# </div>
# </input></form>
#
# For more information, read
# <a class="actionLinkLite" href="/about/terms" rel="noopener noreferrer" target="_blank">our terms of service</a>.
# </div>
# </div>
# </div>
# <div class="clear"></div>
# </div>
# <div class="clear"></div>
# </div>
# <div data-react-class="ReactComponents.GooglePageSkin" data-react-props='{"adId":"","trackingOptions":{"enableTracking":true,"adId":""}}'></div>
# <div class="clear"></div>
# <footer class="responsiveSiteFooter">
# <div class="responsiveSiteFooter__contents gr-container-fluid">
# <div class="gr-row">
# <div class="gr-col gr-col-md-8 gr-col-lg-6">
# <div class="gr-row">
# <div class="gr-col-md-3 gr-col-lg-4">
# <h3 class="responsiveSiteFooter__heading">Company</h3>
# <ul class="responsiveSiteFooter__linkList">
# <li class="responsiveSiteFooter__linkListItem">
# <a class="responsiveSiteFooter__link" href="/about/us">About us</a>
# </li>
# <li class="responsiveSiteFooter__linkListItem">
# <a class="responsiveSiteFooter__link" href="/jobs">Careers</a>
# </li>
# <li class="responsiveSiteFooter__linkListItem">
# <a class="responsiveSiteFooter__link" href="/about/terms">Terms</a>
# </li>
# <li class="responsiveSiteFooter__linkListItem">
# <a class="responsiveSiteFooter__link" href="/about/privacy">Privacy</a>
# </li>
# <li class="responsiveSiteFooter__linkListItem">
# <a class="responsiveSiteFooter__link" href="https://help.goodreads.com/s/article/Goodreads-Interest-Based-Ads-Notice">Interest Based Ads</a>
# </li>
# <li class="responsiveSiteFooter__linkListItem">
# <a class="responsiveSiteFooter__link" href="/adprefs">Ad Preferences</a>
# </li>
# <li class="responsiveSiteFooter__linkListItem">
# <a class="responsiveSiteFooter__link" href="/help?action_type=help_web_footer">Help</a>
# </li>
# </ul>
# </div>
# <div class="gr-col-md-4 gr-col-lg-4">
# <h3 class="responsiveSiteFooter__heading">Work with us</h3>
# <ul class="responsiveSiteFooter__linkList">
# <li class="responsiveSiteFooter__linkListItem">
# <a class="responsiveSiteFooter__link" href="/author/program">Authors</a>
# </li>
# <li class="responsiveSiteFooter__linkListItem">
# <a class="responsiveSiteFooter__link" href="/advertisers">Advertise</a>
# </li>
# <li class="responsiveSiteFooter__linkListItem">
# <a class="responsiveSiteFooter__link" href="/news?content_type=author_blogs">Authors &amp; ads blog</a>
# </li>
# <li class="responsiveSiteFooter__linkListItem">
# <a class="responsiveSiteFooter__link" href="/api">API</a>
# </li>
# </ul>
# </div>
# <div class="gr-col-md-5 gr-col-lg-4">
# <h3 class="responsiveSiteFooter__heading">Connect</h3>
# <div class="responsiveSiteFooter__socialLinkWrapper">
# <a class="responsiveSiteFooter__socialLink" href="https://www.facebook.com/Goodreads/"><img alt="Goodreads on Facebook" src="https://s.gr-assets.com/assets/site_footer/footer_facebook-ea4ab848f8e86c5f5c98311bc9495a1b.svg"/>
# </a><a class="responsiveSiteFooter__socialLink" href="https://twitter.com/goodreads"><img alt="Goodreads on Twitter" src="https://s.gr-assets.com/assets/site_footer/footer_twitter-126b3ee80481a763f7fccb06ca03053c.svg"/>
# </a></div>
# <div class="responsiveSiteFooter__socialLinkWrapper">
# <a class="responsiveSiteFooter__socialLink" href="https://www.instagram.com/goodreads/"><img alt="Goodreads on Instagram" src="https://s.gr-assets.com/assets/site_footer/footer_instagram-d59e3887020f12bcdb12e6c539579d85.svg"/>
# </a><a class="responsiveSiteFooter__socialLink" href="https://www.linkedin.com/company/goodreads-com/"><img alt="Goodreads on LinkedIn" src="https://s.gr-assets.com/assets/site_footer/footer_linkedin-5b820f4703eff965672594ef4d10e33c.svg"/>
# </a></div>
# </div>
# </div>
# </div>
# <div class="gr-col gr-col-md-4 gr-col-lg-6 responsiveSiteFooter__appLinksColumn">
# <div class="responsiveSiteFooter__appLinksColumnContents">
# <div class="responsiveSiteFooter__appLinksColumnBadges">
# <a href="https://itunes.apple.com/app/apple-store/id355833469?pt=325668&amp;ct=mw_footer&amp;mt=8"><img alt="Download app for iOS" src="https://s.gr-assets.com/assets/app/badge-ios-desktop-homepage-6ac7ae16eabce57f6c855361656a7540.svg"/>
# </a><a href="https://play.google.com/store/apps/details?id=com.goodreads&amp;utm_source=mw_footer&amp;pcampaignid=MKT-Other-global-all-co-prtnr-py-PartBadge-Mar2515-1"><img alt="Download app for Android" src="https://s.gr-assets.com/assets/app/badge-android-desktop-home-0f517cbae4d56c88a128d27a7bea1118.png" srcset="https://s.gr-assets.com/assets/app/badge-android-desktop-home-2x-e31514e1fb4dddecf9293aa526a64cfe.png 2x"/>
# </a></div>
# <ul class="responsiveSiteFooter__linkList">
# <li class="responsiveSiteFooter__linkListItem">
# ©
# 2021
# Goodreads, Inc.
# </li>
# <li class="responsiveSiteFooter__linkListItem">
# <a class="responsiveSiteFooter__link" href="/toggle_mobile">Mobile version
# </a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </footer>
# <script>
# //<![CDATA[
# if (typeof window.uet == 'function') { window.uet('be'); }
# //]]>
# </script>
# </div>
# <!--
# This partial loads on almost every page view.  The associated React component makes
# a call to SignInPromptController#get to determine if the user should see the sign in interstial.
# This is determined by how many signed out pagehits the user has executed an how recently they have
# last seen the insterstitial.  If the controller responds indicating the popup should appear, the
# React component will render its content.
# -->
# <div data-react-class="ReactComponents.LoginInterstitial" data-react-props='{"allowFacebookSignIn":true,"allowAmazonSignIn":true,"overrideSignedOutPageCount":false,"path":{"signInUrl":"/user/sign_in","signUpUrl":"/user/sign_up","privacyUrl":"/about/privacy","termsUrl":"/about/terms","thirdPartyRedirectUrl":"/user/new?connect_prompt=true"}}'><noscript data-react-checksum="-1241640643" data-reactid=".1p4a8plske6"></noscript></div>
# <div id="overlay" onclick="Lightbox.hideBox()" style="display:none"></div>
# <div id="box" style="display:none">
# <div class="xBackground js-closeModalIcon" id="close" onclick="Lightbox.hideBox()" title="Close this window"></div>
# <div id="boxContents"></div>
# <div id="boxContentsLeftovers" style="display:none"></div>
# <div class="clear"></div>
# </div>
# <div id="fbSigninNotification" style="display:none;">
# <p>Welcome back. Just a moment while we sign you in to your Goodreads account.</p>
# <img alt="Login animation" src="https://s.gr-assets.com/assets/facebook/login_animation-085464711e6c1ed5ba287a2f40ba3343.gif"/>
# </div>
# <script>
#   //<![CDATA[
#     qcdata = {} || qcdata;
#       (function(){
#         var elem = document.createElement('script');
#         elem.src = (document.location.protocol == "https:" ? "https://secure" : "http://pixel") + ".quantserve.com/aquant.js?a=p-0dUe_kJAjvkoY";
#         elem.async = true;
#         elem.type = "text/javascript";
#         var scpt = document.getElementsByTagName('script')[0];
#         scpt.parentNode.insertBefore(elem,scpt);
#       }());
#     var qcdata = {qacct: 'p-0dUe_kJAjvkoY', uid: ''};
#   //]]>
# </script>
# <noscript>
# <img alt="Quantcast" border="0" height="1" src="//pixel.quantserve.com/pixel/p-0dUe_kJAjvkoY.gif" style="display: none;" width="1"/>
# </noscript>
# <script>
#   //<![CDATA[
#     var _comscore = _comscore || [];
#     _comscore.push({ c1: "2", c2: "6035830", c3: "", c4: "", c5: "", c6: "", c15: ""});
#     (function() {
#     var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#     s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#     el.parentNode.insertBefore(s, el);
#     })();
#   //]]>
# </script>
# <noscript>
# <img alt="" height="0" src="https://sb.scorecardresearch.com/p?c1=2&amp;amp;c2=6035830&amp;amp;c3=&amp;amp;c4=&amp;amp;c5=&amp;amp;c6=&amp;amp;c15=&amp;amp;cv=2.0&amp;amp;cj=1" style="display: none" width="0">
# </img></noscript>
# <script>
#   //<![CDATA[
#     window.addEventListener("DOMContentLoaded", function() {
#       ReactStores.GoogleAdsStore.initializeWith({"targeting":{"sid":"osid.4c2a2e012869238247dc3ba98f7c0ef9","grsession":"osid.4c2a2e012869238247dc3ba98f7c0ef9","surface":"desktop","signedin":"false","gr_author":"false","author":[],"shelf":["film","movie","movies"],"tags":["1423","1471","1372"],"gtargeting":"1","resource":"List_720"},"ads":{},"nativeAds":{}});  ReactStores.NotificationsStore.updateWith({});
#       ReactStores.CurrentUserStore.initializeWith({"currentUser":null});
#       ReactStores.FavoriteGenresStore.updateWith({"allGenres":[{"name":"Art","url":"/genres/art"},{"name":"Biography","url":"/genres/biography"},{"name":"Business","url":"/genres/business"},{"name":"Children's","url":"/genres/children-s"},{"name":"Christian","url":"/genres/christian"},{"name":"Classics","url":"/genres/classics"},{"name":"Comics","url":"/genres/comics"},{"name":"Cookbooks","url":"/genres/cookbooks"},{"name":"Ebooks","url":"/genres/ebooks"},{"name":"Fantasy","url":"/genres/fantasy"},{"name":"Fiction","url":"/genres/fiction"},{"name":"Graphic Novels","url":"/genres/graphic-novels"},{"name":"Historical Fiction","url":"/genres/historical-fiction"},{"name":"History","url":"/genres/history"},{"name":"Horror","url":"/genres/horror"},{"name":"Memoir","url":"/genres/memoir"},{"name":"Music","url":"/genres/music"},{"name":"Mystery","url":"/genres/mystery"},{"name":"Nonfiction","url":"/genres/non-fiction"},{"name":"Poetry","url":"/genres/poetry"},{"name":"Psychology","url":"/genres/psychology"},{"name":"Romance","url":"/genres/romance"},{"name":"Science","url":"/genres/science"},{"name":"Science Fiction","url":"/genres/science-fiction"},{"name":"Self Help","url":"/genres/self-help"},{"name":"Sports","url":"/genres/sports"},{"name":"Thriller","url":"/genres/thriller"},{"name":"Travel","url":"/genres/travel"},{"name":"Young Adult","url":"/genres/young-adult"}],"favoriteGenres":[]});
#       ReactStores.TabsStore.updateWith({"communitySpotlight":"groups"});
#
#     });
#   //]]>
# </script>
# </body>
# </html>
# <!-- This is a random-length HTML comment: ... -->

# %%
# find the css-selector for one book title
soup2.select("td:nth-child(3) > a:nth-child(1) > span:nth-child(1)")
# Out:
# [<span aria-level="4" itemprop="name" role="heading">Harry Potter and the Half-Blood Prince (Harry Potter, #6)</span>,
#  <span aria-level="4" itemprop="name" role="heading">Twilight (Twilight, #1)</span>,
#  <span aria-level="4" itemprop="name" role="heading">The Hobbit, or There and Back Again</span>,
#  <span aria-level="4" itemprop="name" role="heading">Watchmen</span>,
#  <span aria-level="4" itemprop="name" role="heading">The Lightning Thief (Percy Jackson and the Olympians, #1)</span>,
#  <span aria-level="4" itemprop="name" role="heading">Inkheart (Inkworld, #1)</span>,
#  <span aria-level="4" itemprop="name" role="heading">The Lovely Bones</span>,
#  <span aria-level="4" itemprop="name" role="heading">The Tale of Despereaux</span>,
#  <span aria-level="4" itemprop="name" role="heading">Angels &amp; Demons (Robert Langdon, #1)</span>,
#  <span aria-level="4" itemprop="name" role="heading">Uglies (Uglies, #1)</span>,
#  <span aria-level="4" itemprop="name" role="heading">New Moon (Twilight, #2)</span>,
#  <span aria-level="4" itemprop="name" role="heading">The Secret Magdalene</span>,
#  <span aria-level="4" itemprop="name" role="heading">A Great and Terrible Beauty (Gemma Doyle, #1)</span>,
#  <span aria-level="4" itemprop="name" role="heading">The City of Ember (Book of Ember, #1)</span>,
#  <span aria-level="4" itemprop="name" role="heading">Coraline</span>,
#  <span aria-level="4" itemprop="name" role="heading">The Hunger Games (The Hunger Games, #1)</span>,
#  <span aria-level="4" itemprop="name" role="heading">My Sister's Keeper</span>,
#  <span aria-level="4" itemprop="name" role="heading">The Road</span>,
#  <span aria-level="4" itemprop="name" role="heading">Where the Wild Things Are</span>,
#  <span aria-level="4" itemprop="name" role="heading">The Angel Experiment (Maximum Ride, #1)</span>,
#  <span aria-level="4" itemprop="name" role="heading">The Time Traveler's Wife</span>,
#  <span aria-level="4" itemprop="name" role="heading">The Secret Life of Bees</span>,
#  <span aria-level="4" itemprop="name" role="heading">Revolutionary Road</span>,
#  <span aria-level="4" itemprop="name" role="heading">Mrs. Frisby and the Rats of NIMH (Rats of NIMH, #1)</span>,
#  <span aria-level="4" itemprop="name" role="heading">The Savage Tales of Solomon Kane</span>,
#  <span aria-level="4" itemprop="name" role="heading">In the Country of Last Things</span>,
#  <span aria-level="4" itemprop="name" role="heading">Choke</span>]

# %%
# find the css-selector for the authors
soup2.select("td:nth-child(3) > span:nth-child(4) > div:nth-child(1) > a:nth-child(1) > span:nth-child(1)")
# Out:
# [<span itemprop="name">Stephenie Meyer</span>,
#  <span itemprop="name">J.R.R. Tolkien</span>,
#  <span itemprop="name">Alan Moore</span>,
#  <span itemprop="name">Rick Riordan</span>,
#  <span itemprop="name">Cornelia Funke</span>,
#  <span itemprop="name">Alice Sebold</span>,
#  <span itemprop="name">Kate DiCamillo</span>,
#  <span itemprop="name">Dan Brown</span>,
#  <span itemprop="name">Scott Westerfeld</span>,
#  <span itemprop="name">Stephenie Meyer</span>,
#  <span itemprop="name">Ki Longfellow</span>,
#  <span itemprop="name">Libba Bray</span>,
#  <span itemprop="name">Jeanne DuPrau</span>,
#  <span itemprop="name">Neil Gaiman</span>,
#  <span itemprop="name">Suzanne Collins</span>,
#  <span itemprop="name">Jodi Picoult</span>,
#  <span itemprop="name">Cormac McCarthy</span>,
#  <span itemprop="name">Maurice Sendak</span>,
#  <span itemprop="name">James Patterson</span>,
#  <span itemprop="name">Audrey Niffenegger</span>,
#  <span itemprop="name">Sue Monk Kidd</span>,
#  <span itemprop="name">Richard Yates</span>,
#  <span itemprop="name">Robert C. O'Brien</span>,
#  <span itemprop="name">Robert E. Howard</span>,
#  <span itemprop="name">Paul Auster</span>,
#  <span itemprop="name">Chuck Palahniuk</span>]

# %%
book_lst2 = soup2.select("td:nth-child(3) > a:nth-child(1) > span:nth-child(1)")
author_lst2 = soup2.select("td:nth-child(3) > span:nth-child(4) > div:nth-child(1) > a:nth-child(1) > span:nth-child(1)")
len(book_lst2), len(author_lst2)
# Out:
# (27, 26)

# %%
from tqdm.notebook import tqdm
Book2 = []
# Yes = 1
Book_into_Movie2 = []

len_book2 = len(book_lst2)

for i in tqdm(range(len_book2)):
    Book2.append(soup2.select("td:nth-child(3) > a:nth-child(1) > span:nth-child(1)")[i].get_text())
    Book_into_Movie2.append("1")
# Out:
#   0%|          | 0/27 [00:00<?, ?it/s]

# %%
Book2
# Out:
# ['Harry Potter and the Half-Blood Prince (Harry Potter, #6)',
#  'Twilight (Twilight, #1)',
#  'The Hobbit, or There and Back Again',
#  'Watchmen',
#  'The Lightning Thief (Percy Jackson and the Olympians, #1)',
#  'Inkheart (Inkworld, #1)',
#  'The Lovely Bones',
#  'The Tale of Despereaux',
#  'Angels & Demons (Robert Langdon, #1)',
#  'Uglies (Uglies, #1)',
#  'New Moon (Twilight, #2)',
#  'The Secret Magdalene',
#  'A Great and Terrible Beauty (Gemma Doyle, #1)',
#  'The City of Ember (Book of Ember, #1)',
#  'Coraline',
#  'The Hunger Games (The Hunger Games, #1)',
#  "My Sister's Keeper",
#  'The Road',
#  'Where the Wild Things Are',
#  'The Angel Experiment (Maximum Ride, #1)',
#  "The Time Traveler's Wife",
#  'The Secret Life of Bees',
#  'Revolutionary Road',
#  'Mrs. Frisby and the Rats of NIMH (Rats of NIMH, #1)',
#  'The Savage Tales of Solomon Kane',
#  'In the Country of Last Things',
#  'Choke']

# %%
book2 = pd.DataFrame({"Name": Book2, "Book_into_Movie": Book_into_Movie2})

# %%
book2.to_excel("Book_into_movie_2.xlsx")

# %% [markdown]
# ### 5.3. Web Scraping multiple pages

# %%
url3 = "https://www.goodreads.com/list/show/252.Books_Made_into_Movies?page=1"

# %%
response3 = requests.get(url3)
response3.status_code
# Out:
# 200

# %%
soup3 = BeautifulSoup(response3.content, "html.parser")
soup3
# Out:
# <!DOCTYPE html>
#
# <html class="desktop withSiteHeaderTopFullImage">
# <head>
# <title>Books Made into Movies (824 books)</title>
# <meta content="824 books based on 368 votes: The Lord of the Rings by J.R.R. Tolkien, The Lion, the Witch and the Wardrobe by C.S. Lewis, Harry Potter Series Box Set by..." name="description"/>
# <meta content="telephone=no" name="format-detection"/>
# <link href="https://www.goodreads.com/list/show/252.Books_Made_into_Movies" rel="canonical"/>
# <script type="text/javascript"> var ue_t0=window.ue_t0||+new Date();
#  </script>
# <script type="text/javascript">
#     var ue_mid = "A1PQBFHBHS6YH1";
#     var ue_sn = "www.goodreads.com";
#     var ue_furl = "fls-na.amazon.com";
#     var ue_sid = "013-4394152-3099147";
#     var ue_id = "1YFMASFMK7MFYNQE2Y2M";
#
#     (function(e){var c=e;var a=c.ue||{};a.main_scope="mainscopecsm";a.q=[];a.t0=c.ue_t0||+new Date();a.d=g;function g(h){return +new Date()-(h?0:a.t0)}function d(h){return function(){a.q.push({n:h,a:arguments,t:a.d()})}}function b(m,l,h,j,i){var k={m:m,f:l,l:h,c:""+j,err:i,fromOnError:1,args:arguments};c.ueLogError(k);return false}b.skipTrace=1;e.onerror=b;function f(){c.uex("ld")}if(e.addEventListener){e.addEventListener("load",f,false)}else{if(e.attachEvent){e.attachEvent("onload",f)}}a.tag=d("tag");a.log=d("log");a.reset=d("rst");c.ue_csm=c;c.ue=a;c.ueLogError=d("err");c.ues=d("ues");c.uet=d("uet");c.uex=d("uex");c.uet("ue")})(window);(function(e,d){var a=e.ue||{};function c(g){if(!g){return}var f=d.head||d.getElementsByTagName("head")[0]||d.documentElement,h=d.createElement("script");h.async="async";h.src=g;f.insertBefore(h,f.firstChild)}function b(){var k=e.ue_cdn||"z-ecx.images-amazon.com",g=e.ue_cdns||"images-na.ssl-images-amazon.com",j="/images/G/01/csminstrumentation/",h=e.ue_file||"ue-full-11e51f253e8ad9d145f4ed644b40f692._V1_.js",f,i;if(h.indexOf("NSTRUMENTATION_FIL")>=0){return}if("ue_https" in e){f=e.ue_https}else{f=e.location&&e.location.protocol=="https:"?1:0}i=f?"https://":"http://";i+=f?g:k;i+=j;i+=h;c(i)}if(!e.ue_inline){if(a.loadUEFull){a.loadUEFull()}else{b()}}a.uels=c;e.ue=a})(window,document);
#
#     if (window.ue && window.ue.tag) { window.ue.tag('list:show:signed_out', ue.main_scope);window.ue.tag('list:show:signed_out:desktop', ue.main_scope); }
#   </script>
# <script type="text/javascript">
#         if (window.Mobvious === undefined) {
#           window.Mobvious = {};
#         }
#         window.Mobvious.device_type = 'desktop';
#         </script>
# <script src="https://s.gr-assets.com/assets/webfontloader-f5925439393a000d48096973793890d8.js"></script>
# <script>
# //<![CDATA[
#
#   WebFont.load({
#     classes: false,
#     custom: {
#       families: ["Lato:n4,n7,i4", "Merriweather:n4,n7,i4"],
#       urls: ["https://s.gr-assets.com/assets/gr/fonts-e256f84093cc13b27f5b82343398031a.css"]
#     }
#   });
#
# //]]>
# </script>
# <link href="https://s.gr-assets.com/assets/goodreads-e690cbe2cab714907b0ce46bce7b91dc.css" media="all" rel="stylesheet">
# <style media="screen" type="text/css">
#     .bigTabs {
#       margin-bottom: 10px;
#     }
#
#     .list_read{
#       background-color: #D7D2C4;
#       float: left;
#     }
#   </style>
# <link href="https://s.gr-assets.com/assets/common_images-670d97636259cafc355c94fc43e871d7.css" media="screen" rel="stylesheet"/>
# <script src="https://s.gr-assets.com/assets/desktop/libraries-41a429a5834e6352d597e2cf0b06486f.js"></script>
# <script src="https://s.gr-assets.com/assets/application-e1f7a59d8a3ee82c2db20200ea66a37f.js"></script>
# <script>
#   //<![CDATA[
#     var gptAdSlots = gptAdSlots || [];
#     var googletag = googletag || {};
#     googletag.cmd = googletag.cmd || [];
#     (function() {
#       var gads = document.createElement("script");
#       gads.async = true;
#       gads.type = "text/javascript";
#       var useSSL = "https:" == document.location.protocol;
#       gads.src = (useSSL ? "https:" : "http:") +
#       "//securepubads.g.doubleclick.net/tag/js/gpt.js";
#       var node = document.getElementsByTagName("script")[0];
#       node.parentNode.insertBefore(gads, node);
#     })();
#     // page settings
#   //]]>
# </script>
# <script>
#   //<![CDATA[
#     googletag.cmd.push(function() {
#       googletag.pubads().setTargeting("sid", "osid.8690af1847e5967fef790e12756d1da8");
#     googletag.pubads().setTargeting("grsession", "osid.8690af1847e5967fef790e12756d1da8");
#     googletag.pubads().setTargeting("surface", "desktop");
#     googletag.pubads().setTargeting("signedin", "false");
#     googletag.pubads().setTargeting("gr_author", "false");
#     googletag.pubads().setTargeting("author", []);
#     googletag.pubads().setTargeting("shelf", ["adaptation","booktofilm","booktomovie","books","movie","movies"]);
#     googletag.pubads().setTargeting("tags", ["31785","17670","4401","2386","1471","1372"]);
#     googletag.pubads().setTargeting("gtargeting", "1");
#     googletag.pubads().setTargeting("resource", "List_252");
#       googletag.pubads().enableAsyncRendering();
#       googletag.pubads().enableSingleRequest();
#       googletag.pubads().collapseEmptyDivs(true);
#       googletag.pubads().disableInitialLoad();
#       googletag.enableServices();
#     });
#   //]]>
# </script>
# <script>
#   //<![CDATA[
#     ! function(a9, a, p, s, t, A, g) {
#       if (a[a9]) return;
#
#       function q(c, r) {
#         a[a9]._Q.push([c, r])
#       }
#       a[a9] = {
#       init: function() {
#         q("i", arguments)
#       },
#       fetchBids: function() {
#         q("f", arguments)
#       },
#       setDisplayBids: function() {},
#         _Q: []
#       };
#       A = p.createElement(s);
#       A.async = !0;
#       A.src = t;
#       g = p.getElementsByTagName(s)[0];
#       g.parentNode.insertBefore(A, g)
#     }("apstag", window, document, "script", "//c.amazon-adsystem.com/aax2/apstag.js");
#
#     apstag.init({
#       pubID: '3211', adServer: 'googletag', bidTimeout: 4e3, params: { aps_privacy: '1YN' }
#     });
#   //]]>
# </script>
# <meta content="authenticity_token" name="csrf-param">
# <meta content="8LW2fkG2N/Sk7BQyygshn4cUNl/imxRlxwZK+biHdjjPd/813NRjJ+1F9jRoH5jk7yW1HAFjqwvHO8zXEmnpGw==" name="csrf-token">
# <meta content="1YFMASFMK7MFYNQE2Y2M" name="request-id"/>
# <script defer="defer" src="https://s.gr-assets.com/assets/react_client_side/external_dependencies-2e2b90fafc.js"></script>
# <script defer="defer" src="https://s.gr-assets.com/assets/react_client_side/site_header-b38d149ccc.js"></script>
# <script defer="defer" src="https://s.gr-assets.com/assets/react_client_side/custom_react_ujs-b1220d5e0a4820e90b905c302fc5cb52.js"></script>
# <script>
#   //<![CDATA[
#     $grfb.init.done(function() {
#       if (this.auth.status === "not_authorized") {
#         // logged into Facebook user but not a GR app user; show FB button
#         $j("#generalRegPrompt").hide();
#       } else {
#         $j("#facebookRegPrompt").hide();
#       }
#       $j("#connectPrompt").show();
#     });
#   //]]>
# </script>
# <link href="/opensearch.xml" rel="search" title="Goodreads" type="application/opensearchdescription+xml"/>
# <script>
# //<![CDATA[
#
#   var GoodreadsAnalytics = GoodreadsAnalytics || {};
#   var _gaq = _gaq || [];
#
#   GoodreadsAnalytics.push = function () {
#     _gaq.push.apply(_gaq, arguments);
#   }
#
#   GoodreadsAnalytics.push(['_setAccount', 'UA-968618-1']);
#   GoodreadsAnalytics.push(['_setCustomVar',
#     1,                        // Slot 1
#     'User Status',            // Custom variable name
#     'signed_out',  // Custom variable value: signed_out, signed_in,
#                               //   signed_in_facebook_connected, or
#                               //   goodreads_member_previously_signed_in
#     2                         // Visit-level scope, which means slot 1 will be
#                               //   free when the visit ends.
#   ]);
#   GoodreadsAnalytics.push(['_setCustomVar',
#     2,                        // Slot 2
#     'Device Type',            // Custom variable name
#     'desktop',         // Custom variable value: desktop, mobile, or
#                               //   tablet
#     2                         // Visit-level scope, which means slot 2 will be
#                               //   free when the visit ends.
#   ]);
#   GoodreadsAnalytics.push(['_trackPageview']);
#
#   (function () {
#     var ga = document.createElement('script');
#     ga.type = 'text/javascript';
#     ga.async = true;
#     ga.src = ('https:' == document.location.protocol ? 'https://' : 'http://') + 'stats.g.doubleclick.net/dc.js';
#     var s = document.getElementsByTagName('script')[0];
#     s.parentNode.insertBefore(ga, s);
#   })();
#
# //]]>
# </script>
# <meta content="824 books based on 368 votes: The Lord of the Rings by J.R.R. Tolkien, The Lion, the Witch and the Wardrobe by C.S. Lewis, Harry Potter Series Box Set by..." name="description"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="@goodreads" name="twitter:site"/>
# <meta content="Books Made into Movies (824 books)" name="twitter:title"/>
# <meta content="824 books based on 368 votes: The Lord of the Rings by J.R.R. Tolkien, The Lion, the Witch and the Wardrobe by C.S. Lewis, Harry Potter Series Box Set by..." name="twitter:description"/>
# <meta content="cEf8XOH0pulh1aYQeZ1gkXHsQ3dMPSyIGGYqmF53690=" name="verify-v1"/>
# <meta content="PfFjeZ9OK1RrUrKlmAPn_iZJ_vgHaZO1YQ-QlG2VsJs" name="google-site-verification">
# <meta content="app-id=355833469" name="apple-itunes-app"/>
# </meta></meta></meta></link></head>
# <body class="">
# <div data-react-class="ReactComponents.StoresInitializer" data-react-props="{}"><noscript data-react-checksum="-1402138317" data-reactid=".ptfhe9id5g"></noscript></div>
# <div class="content">
# <script>
#   //<![CDATA[
#     var initializeGrfb = function() {
#       $grfb.initialize({
#         appId: "2415071772"
#       });
#     };
#     if (typeof $grfb !== "undefined") {
#       initializeGrfb();
#     } else {
#       window.addEventListener("DOMContentLoaded", function() {
#         if (typeof $grfb !== "undefined") {
#           initializeGrfb();
#         }
#       });
#     }
#   //]]>
# </script>
# <script>
#   //<![CDATA[
#     function loadScript(url, callback) {
#       var script = document.createElement("script");
#       script.type = "text/javascript";
#
#       if (script.readyState) {  //Internet Explorer
#           script.onreadystatechange = function() {
#             if (script.readyState == "loaded" ||
#                     script.readyState == "complete") {
#               script.onreadystatechange = null;
#               callback();
#             }
#           };
#       } else {  //Other browsers
#         script.onload = function() {
#           callback();
#         };
#       }
#
#       script.src = url;
#       document.getElementsByTagName("head")[0].appendChild(script);
#     }
#
#     function initAppleId() {
#       AppleID.auth.init({
#         clientId : 'com.goodreads.app',
#         scope : 'name email',
#         redirectURI: 'https://www.goodreads.com/apple_users/sign_in_with_apple_web',
#         state: 'apple_oauth_state_b3f93adf-0a0e-4b09-9dd8-3d714e7b428c'
#       });
#     }
#
#     var initializeSiwa = function() {
#       var APPLE_SIGN_IN_JS_URL =  "https://appleid.cdn-apple.com/appleauth/static/jsapi/appleid/1/en_US/appleid.auth.js"
#       loadScript(APPLE_SIGN_IN_JS_URL, initAppleId);
#     };
#     if (typeof AppleID !== "undefined") {
#       initAppleId();
#     } else {
#       initializeSiwa();
#     }
#   //]]>
# </script>
# <div class="siteHeader">
# <div data-react-class="ReactComponents.HeaderStoreConnector" data-react-props='{"myBooksUrl":"/review/list?ref=nav_mybooks","browseUrl":"/book?ref=nav_brws","recommendationsUrl":"/recommendations?ref=nav_brws_recs","choiceAwardsUrl":"/choiceawards?ref=nav_brws_gca","genresIndexUrl":"/genres?ref=nav_brws_genres","giveawayUrl":"/giveaway?ref=nav_brws_giveaways","exploreUrl":"/book?ref=nav_brws_explore","homeUrl":"/?ref=nav_home","listUrl":"/list?ref=nav_brws_lists","newsUrl":"/news?ref=nav_brws_news","communityUrl":"/group?ref=nav_comm","groupsUrl":"/group?ref=nav_comm_groups","quotesUrl":"/quotes?ref=nav_comm_quotes","featuredAskAuthorUrl":"/ask_the_author?ref=nav_comm_askauthor","discussionsUrl":"/topic?ref=nav_comm_discuss","autocompleteUrl":"/book/auto_complete","defaultLogoActionUrl":"/","topFullImage":{"clickthroughUrl":"https://www.goodreads.com/blog/show/2050?ref=sr2021_eb","altText":"Goodreads Summer Reading 2021","backgroundColor":"#FFD767","xs":{"1x":"https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/siteheaderbannerimages/1619806865i/43.jpg","2x":"https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/siteheaderbannerimages/1619806872i/44.jpg"},"md":{"1x":"https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/siteheaderbannerimages/1619806854i/41.jpg","2x":"https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/siteheaderbannerimages/1619806860i/42.jpg"}},"logo":{"imageUrl":"https://images.gr-assets.com/doodles/1619806753i/30.svg","clickthroughUrl":"/","altText":"Goodreads Summer Reading 2021"},"searchPath":"/search","newReleasesUrl":"/book/popular_by_date/2021/5?ref=nav_brws_newrels","signInUrl":"/user/sign_in","signUpUrl":"/user/sign_up","signInWithReturnUrl":true,"deployServices":[],"defaultLogoAltText":"Goodreads Home","mobviousDeviceType":"desktop"}'><header data-react-checksum="-1254028995" data-reactid=".1p2jhyecy9e"><div class="siteHeader__topFullImageContainer" data-reactid=".1p2jhyecy9e.0" style="background-color:#FFD767;"><a class="siteHeader__topFullImageLink" data-reactid=".1p2jhyecy9e.0.0" href="https://www.goodreads.com/blog/show/2050?ref=sr2021_eb"><picture data-reactid=".1p2jhyecy9e.0.0.0"><source data-reactid=".1p2jhyecy9e.0.0.0.0" media="(min-width: 768px)" srcset="https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/siteheaderbannerimages/1619806854i/41.jpg 1x, https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/siteheaderbannerimages/1619806860i/42.jpg 2x"/><img alt="Goodreads Summer Reading 2021" class="siteHeader__topFullImage" data-reactid=".1p2jhyecy9e.0.0.0.1" src="https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/siteheaderbannerimages/1619806865i/43.jpg" srcset="https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/siteheaderbannerimages/1619806872i/44.jpg 2x"/></picture></a></div><div class="siteHeader__topLine gr-box gr-box--withShadow" data-reactid=".1p2jhyecy9e.1"><div class="siteHeader__contents" data-reactid=".1p2jhyecy9e.1.0"><div class="siteHeader__topLevelItem siteHeader__topLevelItem--searchIcon" data-reactid=".1p2jhyecy9e.1.0.0"><button aria-label="Toggle search" class="siteHeader__searchIcon gr-iconButton" data-reactid=".1p2jhyecy9e.1.0.0.0" data-ux-click="true" type="button"></button></div><a class="siteHeader__logo siteHeader__logo--doodle" data-reactid=".1p2jhyecy9e.1.0.1" href="/"><picture data-reactid=".1p2jhyecy9e.1.0.1.0"><img alt="Goodreads Summer Reading 2021" data-reactid=".1p2jhyecy9e.1.0.1.0.0" src="https://images.gr-assets.com/doodles/1619806753i/30.svg"/></picture></a><nav class="siteHeader__primaryNavInline" data-reactid=".1p2jhyecy9e.1.0.2"><ul class="siteHeader__menuList" data-reactid=".1p2jhyecy9e.1.0.2.0" role="menu"><li class="siteHeader__topLevelItem siteHeader__topLevelItem--home" data-reactid=".1p2jhyecy9e.1.0.2.0.0"><a class="siteHeader__topLevelLink" data-reactid=".1p2jhyecy9e.1.0.2.0.0.0" href="/?ref=nav_home">Home</a></li><li class="siteHeader__topLevelItem" data- ...
# </div>
# <div class="siteHeaderBottomSpacer"></div>
# <div class="mainContentContainer">
# <div class="mainContent">
# <div id="premiumAdTop">
# <div data-react-class="ReactComponents.GoogleBannerAd" data-react-props='{"adId":"","className":"googleBannerAd--pushdown"}'></div>
# </div>
# <div class="mainContentFloat">
# <div id="flashContainer">
# </div>
# <div id="connectPrompt" style="display:none;">
# <div class="connectPromptHolder">
# <div class="vcenteredLineOfBlocks" style="margin:15px auto 0;">
# <div class="regPromptText">
# <div class="title">
# Discover new books on Goodreads
# </div>
# <div class="subtext">
# Meet your next favorite book
# </div>
# </div>
# <div id="facebookRegPrompt">
# <a class="fbjsLogin fbButton connectPromptButton" data-tracking-id="fb_connect_prompt_quote_reg_prompt" href="/user/new">
# <img alt="Facebook" src="https://s.gr-assets.com/assets/facebook/fb-icon-8d74377d3ff4a368f05860c35d8025b2.png"/>
# Sign in with Facebook
# </a>
# <div class="connectPromptAlternates">
# <a href="/user/sign_up?connect_prompt=true">Sign in <br/> options</a>
# </div>
# </div>
# <div id="generalRegPrompt">
# <div class="connectPromptButton">
# <a class="button orange" href="/user/sign_up?connect_prompt=true">Join Goodreads</a>
# </div>
# </div>
# </div>
# <div class="clear"></div>
# </div>
# </div>
# <div class="leftContainer">
# <div class="pageHeader">
# <a href="/list">Listopia</a>
# </div>
# <br class="clear"/>
# <h1 class="gr-h1 gr-h1--serif">Books Made into Movies
#   </h1>
# <div class="mediumText" style="padding-bottom: 10px">
#       Your favorite books that have been made into movies... whether you liked the movie adaptation or not.
#     </div>
# <div id="score_explanation" style="display:none">
# <h1>Score</h1>
# <p>
#     A book’s total score is based on multiple factors, including the number of
#     people who have voted for it and how highly those voters ranked the book.
#     </p>
# </div>
# <div class="tabs bigTabs">
# <div class="right">
# <a class="selectedTab js-dhtmlTab" data-tab-name="all_votes" data-tab-set="615409322" href="/list/show/252.Books_Made_into_Movies?tab=all_votes" id="all_votesLink">All Votes</a>
# <a class="tab js-dhtmlTab" data-tab-name="Add_Books_To_This_List" data-tab-set="615409322" href="/list/show/252.Books_Made_into_Movies?tab=Add_Books_To_This_List" id="Add_Books_To_This_ListLink">Add Books To This List</a>
# </div>
# <div class="clear"> </div></div><script charset="utf-8" type="text/javascript">
# //<![CDATA[
#
#   current_tabs[615409322] = 'all_votes';
#
#   Event.observe(window, 'load', function(e) {
#     // Switch to an anchored tab if specified in the URL
#     if (location.href.include('#')) {
#       var tabID = location.href.split('#')[1];
#       if (tabID != '' && $(tabID)) {
#         changeTab(tabID)
#       }
#     }
#   })
# //]]>
# </script>
# <script charset="utf-8" type="text/javascript">
# //<![CDATA[
#
#   function submitShelfLink(unique_id, book_id, shelf_id, shelf_name, submit_form, exclusive) {
#     var checkbox_id = 'shelf_name_' + unique_id + '_' + shelf_id;
#     var element = document.getElementById(checkbox_id)
#
#     var checked = element.checked
#     if (checked && exclusive) {
#       // can't uncheck a radio by clicking it!
#       return
#     }
#     if(document.getElementById("savingMessage")){
#       Element.show('savingMessage')
#     }
#     var element_id = 'shelfInDropdownName_' + unique_id + '_' + shelf_id;
#     Element.update(element_id, "saving...");
#     if (submit_form) {
#       Element.hide('shelfDropdown_' + unique_id)
#       var form = document.getElementById('addBookForm' + book_id)
#       if (form) {
#         form.shelf.value = shelf_name
#         form.onsubmit()
#       }
#     }
#     else {
#       var action = checked ? 'remove' : ''
#       element.checked = !element.checked
#       new Ajax.Request('/shelf/add_to_shelf', {asynchronous:true, evalScripts:true, onSuccess:function(request){shelfSubmitted(request, book_id, checkbox_id, element_id, unique_id, shelf_name)}, parameters:'book_id=' + book_id + '&name=' + shelf_name + '&a=' + action + '&authenticity_token=' + encodeURIComponent('tFRbN40EuGtOWG8C4X5PkJe9RhlcsZeYjX3o4UhPzcmLlhJ8EGbsuAfxjQRDavbr/4zFWr9JKPaNQG7P4qFS6g==')})
#     }
#   }
#
#   function shelfSubmitted(request, book_id, checkbox_id, element_id, unique_id, shelf_name) {
#     Element.update('shelfListfalse_' + book_id, request.responseText)
#     afterShelfSave(checkbox_id, element_id, unique_id, shelf_name.escapeHTML())
#   }
#
#   function refreshGroupBox(group_id, book_id) {
#     new Ajax.Updater('addGroupBooks' + book_id + '', '/group/add_book_box', {asynchronous:true, evalScripts:true, onSuccess:function(request){refreshGroupBoxComplete(request, book_id);}, parameters:'id=' + group_id + '&book_id=' + book_id + '&refresh=true' + '&authenticity_token=' + encodeURIComponent('JwN6xps4WR6h/vpcn3+KC57UCpAtqQ2vkZYF6t2xg8gYwTONBloNzehXGFo9azNw9uWJ085RssGRq4PEd18c6w==')})
#   }
# //]]>
# </script>
# <div id="all_votes">
# <table class="tableList js-dataTooltip">
# <!-- Add query string params -->
# <tr itemscope="" itemtype="http://schema.org/Book">
# <td class="number" valign="top">1</td>
# <td valign="top" width="5%">
# <div class="u-anchorTarget" id="33"></div>
# <div class="js-tooltipTrigger tooltipTrigger" data-resource-id="33" data-resource-type="Book">
# <a href="/book/show/33.The_Lord_of_the_Rings" title="The Lord of the Rings">
# <img alt="The Lord of the Rings" class="bookCover" itemprop="image" src="https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1566425108i/33._SX50_.jpg"/>
# </a> </div>
# </td>
# <td valign="top" width="100%">
# <a class="bookTitle" href="/book/show/33.The_Lord_of_the_Rings" itemprop="url">
# <span aria-level="4" itemprop="name" role="heading">The Lord of the Rings</span>
# </a> <br>
# <span class="by">by</span>
# <span itemprop="author" itemscope="" itemtype="http://schema.org/Person">
# <div class="authorName__container">
# <a class="authorName" href="https://www.goodreads.com/author/show/656983.J_R_R_Tolkien" itemprop="url"><span itemprop="name">J.R.R. Tolkien</span></a>
# </div>
# </span>
# <br/>
# <div>
# <span class="greyText smallText uitext">
# <span class="minirating"><span class="stars staticStars notranslate"><span class="staticStar p10" size="12x12"></span><span class="staticStar p10" size="12x12"></span><span class="staticStar p10" size="12x12"></span><span class="staticStar p10" size="12x12"></span><span class="staticStar p6" size="12x12"></span></span> 4.50 avg rating — 593,138 ratings</span>
# </span>
# </div>
# <div style="margin-top: 5px">
# <span class="smallText uitext">
# <a href="#" onclick="Lightbox.showBoxByID('score_explanation', 300); return false;">score: 9,074</a>,
#               <span class="greyText">and</span>
# <a href="#" id="loading_link_542693" onclick="new Ajax.Request('/list/list_book/5871', {asynchronous:true, evalScripts:true, onFailure:function(request){Element.hide('loading_anim_542693');$('loading_link_542693').innerHTML = '&lt;span class=&quot;error&quot;&gt;ERROR&lt;/span&gt;try again';$('loading_link_542693').show();;Element.hide('loading_anim_542693');}, onLoading:function(request){;Element.show('loading_anim_542693');Element.hide('loading_link_542693')}, onSuccess:function(request){Element.hide('loading_anim_542693');Element.show('loading_link_542693');}, parameters:'authenticity_token=' + encodeURIComponent('98qUglOq45P/ZmIfa9F9qPGW6ItXATEi+nRBZ9D8EdjICN3Jzsi3QLbPgBnJxcTTmadryLT5jkz6ScdJehKO+w==')}); return false;">92 people voted</a><img alt="Loading trans" class="loading" id="loading_anim_542693" src="https://s.gr-assets.com/assets/loading-trans-ced157046184c3bc7c180ffbfc6825a4.gif" style="display:none"/>
#
#
#             </span>
# </div>
# </br></td>
# <td width="130px">
# <div class="wtrButtonContainer wtrSignedOut" id="1_book_33">
# <div class="wtrUp wtrLeft">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="I6DTzF2MoSHEfSkV8tCpdY1zUsKhi7v5k+7QflkJ2G4cYpqHwO718o3UyxNQxBAO5ULRgUJzBJeT01ZQ8+dHTQ=="/>
# <input id="book_id" name="book_id" type="hidden" value="33"/>
# <input id="name" name="name" type="hidden" value="to-read"/>
# <input id="unique_id" name="unique_id" type="hidden" value="1_book_33"/>
# <input id="wtr_new" name="wtr_new" type="hidden" value="true"/>
# <input id="from_choice" name="from_choice" type="hidden" value="false"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input class="wtrLeftUpRef" id="ref" name="ref" type="hidden" value=""/>
# <input class="wtrExisting" id="existing_review" name="existing_review" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# <button class="wtrToRead" type="submit">
# <span class="progressTrigger">Want to Read</span>
# <span class="progressIndicator">saving…</span>
# </button>
# </form>
# </div>
# <div class="wtrRight wtrUp">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" class="hiddenShelfForm" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="cbC8KrBsyiQ5plZ8f9ok4PcjDHiKvvWJpWjVdrCzNgNOcvVhLQ6e93APtHrdzp2bnxKPO2lGSuelVVNYGl2pIA=="/>
# <input id="unique_id" name="unique_id" type="hidden" value="1_book_33"/>
# <input id="book_id" name="book_id" type="hidden" value="33"/>
# <input id="a" name="a" type="hidden"/>
# <input id="name" name="name" type="hidden"/>
# <input id="from_choice" name="from_choice" type="hidden" value="false"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# </form>
# <button class="wtrShelfButton"></button>
# <div class="wtrShelfMenu">
# <ul class="wtrExclusiveShelves">
# <li><button class="wtrExclusiveShelf" name="name" type="submit" value="to-read">
# <span class="progressTrigger">Want to Read</span>
# <img alt="saving…" class="progressIndicator" src="https://s.gr-assets.com/assets/loading-trans-ced157046184c3bc7c180ffbfc6825a4.gif"/>
# </button>
# </li>
# <li><button class="wtrExclusiveShelf" name="name" type="submit" value="currently-reading">
# <span class="progressTrigger">Currently Reading</span>
# <img alt="saving…" class="progressIndicator" src="https://s.gr-assets.com/assets/loading-trans-ced157046184c3bc7c180ffbfc6825a4.gif"/>
# </button>
# </li>
# <li><button class="wtrExclusiveShelf" name="name" type="submit" value="read">
# <span class="progressTrigger">Read</span>
# <img alt="saving…" class="progressIndicator" src="https://s.gr-assets.com/assets/loading-trans-ced157046184c3bc7c180ffbfc6825a4.gif"/>
# </button>
# </li>
# </ul>
# </div>
# </div>
# <div class="ratingStars wtrRating">
# <div class="starsErrorTooltip hidden">
# Error rating book. Refresh and try again.
# </div>
# <div class="myRating uitext greyText">Rate this book</div>
# <div class="clearRating uitext">Clear rating</div>
# <div class="stars" data-rating="0" data-resource-id="33" data-submit-url="/review/rate/33?stars_click=true&amp;wtr_button_id=1_book_33" data-user-id="0"><a class="star off" href="#" ref="" title="did not like it">1 of 5 stars</a><a class="star off" href="#" ref="" title="it was ok">2 of 5 stars</a><a class="star off" href="#" ref="" title="liked it">3 of 5 stars</a><a class="star off" href="#" ref="" title="really liked it">4 of 5 stars</a><a class="star off" href="#" ref="" title="it was amazing">5 of 5 stars</a></div>
# </div>
# </div>
# </td>
# </tr>
# <!-- Add query string params -->
# <tr itemscope="" itemtype="http://schema.org/Book">
# <td class="number" valign="top">2</td>
# <td valign="top" width="5%">
# <div class="u-anchorTarget" id="100915"></div>
# <div class="js-tooltipTrigger tooltipTrigger" data-resource-id="100915" data-resource-type="Book">
# <a href="/book/show/100915.The_Lion_the_Witch_and_the_Wardrobe" title="The Lion, the Witch and the Wardrobe">
# <img alt="The Lion, the Witch and the..." class="bookCover" itemprop="image" src="https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1353029077i/100915._SY75_.jpg"/>
# </a> </div>
# </td>
# <td valign="top" width="100%">
# <a class="bookTitle" href="/book/show/100915.The_Lion_the_Witch_and_the_Wardrobe" itemprop="url">
# <span aria-level="4" itemprop="name" role="heading">The Lion, the Witch and the Wardrobe (Chronicles of Narnia, #1)</span>
# </a> <br/>
# <span class="by">by</span>
# <span itemprop="author" itemscope="" itemtype="http://schema.org/Person">
# <div class="authorName__container">
# <a class="authorName" href="https://www.goodreads.com/author/show/1069006.C_S_Lewis" itemprop="url"><span itemprop="name">C.S. Lewis</span></a>
# </div>
# </span>
# <br/>
# <div>
# <span class="greyText smallText uitext">
# <span class="minirating"><span class="stars staticStars notranslate"><span class="staticStar p10" size="12x12"></span><span class="staticStar p10" size="12x12"></span><span class="staticStar p10" size="12x12"></span><span class="staticStar p10" size="12x12"></span><span class="staticStar p3" size="12x12"></span></span> 4.22 avg rating — 2,259,453 ratings</span>
# </span>
# </div>
# <div style="margin-top: 5px">
# <span class="smallText uitext">
# <a href="#" onclick="Lightbox.showBoxByID('score_explanation', 300); return false;">score: 7,440</a>,
#               <span class="greyText">and</span>
# <a href="#" id="loading_link_46789" onclick="new Ajax.Request('/list/list_book/9793988', {asynchronous:true, evalScripts:true, onFailure:function(request){Element.hide('loading_anim_46789');$('loading_link_46789').innerHTML = '&lt;span class=&quot;error&quot;&gt;ERROR&lt;/span&gt;try again';$('loading_link_46789').show();;Element.hide('loading_anim_46789');}, onLoading:function(request){;Element.show('loading_anim_46789');Element.hide('loading_link_46789')}, onSuccess:function(request){Element.hide('loading_anim_46789');Element.show('loading_link_46789');}, parameters:'authenticity_token=' + encodeURIComponent('gF1tS1z1dCHzMkfB1rjxkk6FDNYA3hC2GBdx/pIgEo6/nyQAwZcg8rqbpcd0rEjpJrSPleMmr9gYKvfQOM6NrQ==')}); return false;">77 people voted</a><img alt="Loading trans" class="loading" id="loading_anim_46789" src="https://s.gr-assets.com/assets/loading-trans-ced157046184c3bc7c180ffbfc6825a4.gif" style="display:none"/>
#
#
#             </span>
# </div>
# </td>
# <td width="130px">
# <div class="wtrButtonContainer wtrSignedOut" id="2_book_100915">
# <div class="wtrUp wtrLeft">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="VX5XyUESkYwzTIygYlg5GXv8X/f3uPJwSgEP/R+t9ENqvB6C3HDFX3rlbqbATIBiE83ctBRATR5KPInTtUNrYA=="/>
# <input id="book_id" name="book_id" type="hidden" value="100915"/>
# <input id="name" name="name" type="hidden" value="to-read"/>
# <input id="unique_id" name="unique_id" type="hidden" value="2_book_100915"/>
# <input id="wtr_new" name="wtr_new" type="hidden" value="true"/>
# <input id="from_choice" name="from_choice" type="hidden" value="false"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input class="wtrLeftUpRef" id="ref" name="ref" type="hidden" value=""/>
# <input class="wtrExisting" id="existing_review" name="existing_review" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# <button class="wtrToRead" type="submit">
# <span class="progressTrigger">Want to Read</span>
# <span class="progressIndicator">saving…</span>
# </button>
# </form>
# </div>
# <div class="wtrRight wtrUp">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" class="hiddenShelfForm" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="v8HUXZTuM9wqyC9r3r22iZD7r4CxbER7KE0ugEGNYH2AA50WCYxnD2NhzW18qQ/y+Mosw1KU+xUocKiu62P/Xg=="/>
# <input id="unique_id" name="unique_id" type="hidden" value="2_book_100915"/>
# <input id="book_id" name="book_id" type="hidden" value="100915"/>
# <input id="a" name="a" type="hidden"/>
# <input id="name" name="name" type="hidden"/>
# <input id="from_choice" name="from_choice" type="hidden" value="false"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# </form>
# <button class="wtrShelfButton"></button>
# </div>
# <div class="ratingStars wtrRating">
# <div class="starsErrorTooltip hidden">
# Error rating book. Refresh and try again.
# </div>
# <div class="myRating uitext greyText">Rate this book</div>
# <div class="clearRating uitext">Clear rating</div>
# <div class="stars" data-rating="0" data-resource-id="100915" data-submit-url="/review/rate/100915?stars_click=true&amp;wtr_button_id=2_book_100915" data-user-id="0"><a class="star off" href="#" ref="" title="did not like it">1 of 5 stars</a><a class="star off" href="#" ref="" title="it was ok">2 of 5 stars</a><a class="star off" href="#" ref="" title="liked it">3 of 5 stars</a><a class="star off" href="#" ref="" title="really liked it">4 of 5 stars</a><a class="star off" href="#" ref="" title="it was amazing">5 of 5 stars</a></div>
# </div>
# </div>
# </td>
# </tr>
# <!-- Add query string params -->
# <tr itemscope="" itemtype="http://schema.org/Book">
# <td class="number" valign="top">3</td>
# <td valign="top" width="5%">
# <div class="u-anchorTarget" id="862041"></div>
# <div class="js-tooltipTrigger tooltipTrigger" data-resource-id="862041" data-resource-type="Book">
# <a href="/book/show/862041.Harry_Potter_Series_Box_Set" title="Harry Potter Series Box Set">
# <img alt="Harry Potter Series Box Set..." class="bookCover" itemprop="image" src="https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1534298934i/862041._SX50_.jpg"/>
# </a> </div>
# </td>
# <td valign="top" width="100%">
# <a class="bookTitle" href="/book/show/862041.Harry_Potter_Series_Box_Set" itemprop="url">
# <span aria-level="4" itemprop="name" role="heading">Harry Potter Series Box Set (Harry Potter, #1-7)</span>
# </a> <br/>
# <span class="by">by</span>
# <span itemprop="author" itemscope="" itemtype="http://schema.org/Person">
# <div class="authorName__container">
# <a class="authorName" href="https://www.goodreads.com/author/show/1077326.J_K_Rowling" itemprop="url"><span itemprop="name">J.K. Rowling</span></a>
# </div>
# </span>
# <br/>
# <div>
# <span class="greyText smallText uitext">
# <span class="minirating"><span class="stars staticStars notranslate"><span class="staticStar p10" size="12x12"></span><span class="staticStar p10" size="12x12"></span><span class="staticStar p10" size="12x12"></span><span class="staticStar p10" size="12x12"></span><span class="staticStar p6" size="12x12"></span></span> 4.72 avg rating — 261,547 ratings</span>
# </span>
# </div>
# <div style="margin-top: 5px">
# <span class="smallText uitext">
# <a href="#" onclick="Lightbox.showBoxByID('score_explanation', 300); return false;">score: 6,665</a>,
#               <span class="greyText">and</span>
# <a href="#" id="loading_link_358191" onclick="new Ajax.Request('/list/list_book/5873', {asynchronous:true, evalScripts:true, onFailure:function(request){Element.hide('loading_anim_358191');$('loading_link_358191').innerHTML = '&lt;span class=&quot;error&quot;&gt;ERROR&lt;/span&gt;try again';$('loading_link_358191').show();;Element.hide('loading_anim_358191');}, onLoading:function(request){;Element.show('loading_anim_358191');Element.hide('loading_link_358191')}, onSuccess:function(request){Element.hide('loading_anim_358191');Element.show('loading_link_358191');}, parameters:'authenticity_token=' + encodeURIComponent('rxEAFEYpPjwGh3DpK89LZWCAxF1+LwBgMj/NDfnarvyQ00lf20tq708uku+J2/IeCLFHHp3Xvw4yAksjUzQx3w==')}); return false;">69 people voted</a><img alt="Loading trans" class="loading" id="loading_anim_358191" src="https://s.gr-assets.com/assets/loading-trans-ced157046184c3bc7c180ffbfc6825a4.gif" style="display:none"/>
#
#
#             </span>
# </div>
# </td>
# <td width="130px">
# <div class="wtrButtonContainer wtrSignedOut" id="3_book_862041">
# <div class="wtrUp wtrLeft">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="xJD6EMN3tPKmIsiR5pG8qhb8VL6W4HXdfC5F3djVX6D7UrNbXhXgIe+LKpdEhQXRfs3X/XUYyrN8E8PzcjvAgw=="/>
# <input id="book_id" name="book_id" type="hidden" value="862041"/>
# <input id="name" name="name" type="hidden" value="to-read"/>
# <input id="unique_id" name="unique_id" type="hidden" value="3_book_862041"/>
# <input id="wtr_new" name="wtr_new" type="hidden" value="true"/>
# <input id="from_choice" name="from_choice" type="hidden" value="false"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input class="wtrLeftUpRef" id="ref" name="ref" type="hidden" value=""/>
# <input class="wtrExisting" id="existing_review" name="existing_review" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# <button class="wtrToRead" type="submit">
# <span class="progressTrigger">Want to Read</span>
# <span class="progressIndicator">saving…</span>
# </button>
# </form>
# </div>
# <div class="wtrRight wtrUp">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" class="hiddenShelfForm" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="kwe1CsyGiyfVUsxg45eABk08hRttk+165ZJoTW/Oy5+sxfxBUeTf9Jz7LmZBgzl9JQ0GWI5rUhTlr+5jxSBUvA=="/>
# <input id="unique_id" name="unique_id" type="hidden" value="3_book_862041"/>
# <input id="book_id" name="book_id" type="hidden" value="862041"/>
# <input id="a" name="a" type="hidden"/>
# <input id="name" name="name" type="hidden"/>
# <input id="from_choice" name="from_choice" type="hidden" value="false"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# </form>
# <button class="wtrShelfButton"></button>
# </div>
# <div class="ratingStars wtrRating">
# <div class="starsErrorTooltip hidden">
# Error rating book. Refresh and try again.
# </div>
# <div class="myRating uitext greyText">Rate this book</div>
# <div class="clearRating uitext">Clear rating</div>
# <div class="stars" data-rating="0" data-resource-id="862041" data-submit-url="/review/rate/862041?stars_click=true&amp;wtr_button_id=3_book_862041" data-user-id="0"><a class="star off" href="#" ref="" title="did not like it">1 of 5 stars</a><a class="star off" href="#" ref="" title="it was ok">2 of 5 stars</a><a class="star off" href="#" ref="" title="liked it">3 of 5 stars</a><a class="star off" href="#" ref="" title="really liked it">4 of 5 stars</a><a class="star off" href="#" ref="" title="it was amazing">5 of 5 stars</a></div>
# </div>
# </div>
# </td>
# </tr>
# <!-- Add query string params -->
# <tr itemscope="" itemtype="http://schema.org/Book">
# <td class="number" valign="top">4</td>
# <td valign="top" width="5%">
# <div class="u-anchorTarget" id="2657"></div>
# <div class="js-tooltipTrigger tooltipTrigger" data-resource-id="2657" data-resource-type="Book">
# <a href="/book/show/2657.To_Kill_a_Mockingbird" title="To Kill a Mockingbird">
# <img alt="To Kill a Mockingbird" class="bookCover" itemprop="image" src="https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1553383690i/2657._SY75_.jpg"/>
# </a> </div>
# </td>
# <td valign="top" width="100%">
# <a class="bookTitle" href="/book/show/2657.To_Kill_a_Mockingbird" itemprop="url">
# <span aria-level="4" itemprop="name" role="heading">To Kill a Mockingbird</span>
# </a> <br/>
# <span class="by">by</span>
# <span itemprop="author" itemscope="" itemtype="http://schema.org/Person">
# <div class="authorName__container">
# <a class="authorName" href="https://www.goodreads.com/author/show/1825.Harper_Lee" itemprop="url"><span itemprop="name">Harper Lee</span></a>
# </div>
# </span>
# <br/>
# <div>
# <span class="greyText smallText uitext">
# <span class="minirating"><span class="stars staticStars notranslate"><span class="staticStar p10" size="12x12"></span><span class="staticStar p10" size="12x12"></span><span class="staticStar p10" size="12x12"></span><span class="staticStar p10" size="12x12"></span><span class="staticStar p3" size="12x12"></span></span> 4.28 avg rating — 4,791,607 ratings</span>
# </span>
# </div>
# <div style="margin-top: 5px">
# <span class="smallText uitext">
# <a href="#" onclick="Lightbox.showBoxByID('score_explanation', 300); return false;">score: 6,376</a>,
#               <span class="greyText">and</span>
# <a href="#" id="loading_link_481313" onclick="new Ajax.Request('/list/list_book/5663', {asynchronous:true, evalScripts:true, onFailure:function(request){Element.hide('loading_anim_481313');$('loading_link_481313').innerHTML = '&lt;span class=&quot;error&quot;&gt;ERROR&lt;/span&gt;try again';$('loading_link_481313').show();;Element.hide('loading_anim_481313');}, onLoading:function(request){;Element.show('loading_anim_481313');Element.hide('loading_link_481313')}, onSuccess:function(request){Element.hide('loading_anim_481313');Element.show('loading_link_481313');}, parameters:'authenticity_token=' + encodeURIComponent('CBs076Qsg+fVcm5AqudFASDCmdRwRppJevjLj659skQ32X2kOU7XNJzbjEYI8/x6SPMal5O+JSd6xU2hBJMtZw==')}); return false;">67 people voted</a><img alt="Loading trans" class="loading" id="loading_anim_481313" src="https://s.gr-assets.com/assets/loading-trans-ced157046184c3bc7c180ffbfc6825a4.gif" style="display:none"/>
#
#
#             </span>
# </div>
# </td>
# <td width="130px">
# <div class="wtrButtonContainer wtrSignedOut" id="4_book_2657">
# <div class="wtrUp wtrLeft">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="8/amntr35ze4xny9KcSsFBcYVK4m0H6JFCywE8t6E7PMNO/VR5Wz5PFvnruL0BVvfynX7cUowecUETY9YZSMkA=="/>
# <input id="book_id" name="book_id" type="hidden" value="2657"/>
# <input id="name" name="name" type="hidden" value="to-read"/>
# <input id="unique_id" name="unique_id" type="hidden" value="4_book_2657"/>
# <input id="wtr_new" name="wtr_new" type="hidden" value="true"/>
# <input id="from_choice" name="from_choice" type="hidden" value="false"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input class="wtrLeftUpRef" id="ref" name="ref" type="hidden" value=""/>
# <input class="wtrExisting" id="existing_review" name="existing_review" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# <button class="wtrToRead" type="submit">
# <span class="progressTrigger">Want to Read</span>
# <span class="progressIndicator">saving…</span>
# </button>
# </form>
# </div>
# <div class="wtrRight wtrUp">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" class="hiddenShelfForm" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="tAhlW4jKzBHk0n5ssjMnq6Nqdr579VQOhOkaYM0BkWeLyiwQFaiYwq17nGoQJ57Qy1v1/ZgN62CE1JxOZ+8ORA=="/>
# <input id="unique_id" name="unique_id" type="hidden" value="4_book_2657"/>
# <input id="book_id" name="book_id" type="hidden" value="2657"/>
# <input id="a" name="a" type="hidden"/>
# <input id="name" name="name" type="hidden"/>
# <input id="from_choice" name="from_choice" type="hidden" value="false"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# </form>
# <button class="wtrShelfButton"></button>
# </div>
# <div class="ratingStars wtrRating">
# <div class="starsErrorTooltip hidden">
# Error rating book. Refresh and try again.
# </div>
# <div class="myRating uitext greyText">Rate this book</div>
# <div class="clearRating uitext">Clear rating</div>
# <div class="stars" data-rating="0" data-resource-id="2657" data-submit-url="/review/rate/2657?stars_click=true&amp;wtr_button_id=4_book_2657" data-user-id="0"><a class="star off" href="#" ref="" title="did not like it">1 of 5 stars</a><a class="star off" href="#" ref="" title="it was ok">2 of 5 stars</a><a class="star off" href="#" ref="" title="liked it">3 of 5 stars</a><a class="star off" href="#" ref="" title="really liked it">4 of 5 stars</a><a class="star off" href="#" ref="" title="it was amazing">5 of 5 stars</a></div>
# </div>
# </div>
# </td>
# </tr>
# <!-- Add query string params -->
# <tr itemscope="" itemtype="http://schema.org/Book">
# <td class="number" valign="top">5</td>
# <td valign="top" width="5%">
# <div class="u-anchorTarget" id="6310"></div>
# <div class="js-tooltipTrigger tooltipTrigger" data-resource-id="6310" data-resource-type="Book">
# <a href="/book/show/6310.Charlie_and_the_Chocolate_Factory" title="Charlie and the Chocolate Factory">
# <img alt="Charlie and the Chocolate F..." class="bookCover" itemprop="image" src="https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1309211401i/6310._SY75_.jpg"/>
# </a> </div>
# </td>
# <td valign="top" width="100%">
# <a class="bookTitle" href="/book/show/6310.Charlie_and_the_Chocolate_Factory" itemprop="url">
# <span aria-level="4" itemprop="name" role="heading">Charlie and the Chocolate Factory (Charlie Bucket, #1)</span>
# </a> <br/>
# <span class="by">by</span>
# <span itemprop="author" itemscope="" itemtype="http://schema.org/Person">
# <div class="authorName__container">
# <a class="authorName" href="https://www.goodreads.com/author/show/4273.Roald_Dahl" itemprop="url"><span itemprop="name">Roald Dahl</span></a>
# </div>
# </span>
# <br/>
# <div>
# <span class="greyText smallText uitext">
# <span class="minirating"><span class="stars staticStars notranslate"><span class="staticStar p10" size="12x12"></span><span class="staticStar p10" size="12x12"></span><span class="staticStar p10" size="12x12"></span><span class="staticStar p10" size="12x12"></span><span class="staticStar p3" size="12x12"></span></span> 4.14 avg rating — 709,293 ratings</span>
# </span>
# </div>
# <div style="margin-top: 5px">
# <span class="smallText uitext">
# <a href="#" onclick="Lightbox.showBoxByID('score_explanation', 300); return false;">score: 6,218</a>,
#               <span class="greyText">and</span>
# <a href="#" id="loading_link_570352" onclick="new Ajax.Request('/list/list_book/5667', {asynchronous:true, evalScripts:true, onFailure:function(request){Element.hide('loading_anim_570352');$('loading_link_570352').innerHTML = '&lt;span class=&quot;error&quot;&gt;ERROR&lt;/span&gt;try again';$('loading_link_570352').show();;Element.hide('loading_anim_570352');}, onLoading:function(request){;Element.show('loading_anim_570352');Element.hide('loading_link_570352')}, onSuccess:function(request){Element.hide('loading_anim_570352');Element.show('loading_link_570352');}, parameters:'authenticity_token=' + encodeURIComponent('eqFk2GS9FwyeCMxrlP+bIxv01lTXaZIdy009+rATJaRFYy2T+d9D39ehLm026yJYc8VVFzSRLXPLcLvUGv26hw==')}); return false;">65 people voted</a><img alt="Loading trans" class="loading" id="loading_anim_570352" src="https://s.gr-assets.com/assets/loading-trans-ced157046184c3bc7c180ffbfc6825a4.gif" style="display:none"/>
#
#
#             </span>
# </div>
# </td>
# <td width="130px">
# <div class="wtrButtonContainer wtrSignedOut" id="5_book_6310">
# <div class="wtrUp wtrLeft">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="xVUHm5bKr22XaCyYAMTiQzslhcMABO5qfhjUxB9l27j6l07QC6j7vt7Bzp6i0Fs4UxQGgOP8UQR+JVLqtYtEmw=="/>
# <input id="book_id" name="book_id" type="hidden" value="6310"/>
# <input id="name" name="name" type="hidden" value="to-read"/>
# <input id="unique_id" name="unique_id" type="hidden" value="5_book_6310"/>
# <input id="wtr_new" name="wtr_new" type="hidden" value="true"/>
# <input id="from_choice" name="from_choice" type="hidden" value="false"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input class="wtrLeftUpRef" id="ref" name="ref" type="hidden" value=""/>
# <input class="wtrExisting" id="existing_review" name="existing_review" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# <button class="wtrToRead" type="submit">
# <span class="progressTrigger">Want to Read</span>
# <span class="progressIndicator">saving…</span>
# </button>
# </form>
# </div>
# <div class="wtrRight wtrUp">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" class="hiddenShelfForm" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="b1UMGEcje2Sl+sEovnqdMNYObSFeJ9eKr7XB4wQtKt9Ql0VT2kEvt+xTIy4cbiRLvj/uYr3faOSviEfNrsO1/A=="/>
# <input id="unique_id" name="unique_id" type="hidden" value="5_book_6310"/>
# <input id="book_id" name="book_id" type="hidden" value="6310"/>
# <input id="a" name="a" type="hidden"/>
# <input id="name" name="name" type="hidden"/>
# <input id="from_choice" name="from_choice" type="hidden" value="false"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# </form>
# <button class="wtrShelfButton"></button>
# </div>
# <div class="ratingStars wtrRating">
# <div class="starsErrorTooltip hidden">
# Error rating book. Refresh and try again.
# </div>
# ...
# <div class="u-marginBottomXSmall">
# <div class="image">
# <a href="/blog/show/2068-pieces-of-mind-30-great-new-essay-collections"><img alt="Pieces of Mind: 30 Great New Essay Collections" src="https://images.gr-assets.com/blogs/1619024420p8/2068.jpg" width="100%"/></a>
# </div>
# <a class="bigText title" href="/blog/show/2068-pieces-of-mind-30-great-new-essay-collections">Pieces of Mind: 30 Great New Essay Collections</a>
# <div class="links">
# <div class="left">
# </div>
# <div class="action right">
# <a class="actionLinkLite" href="/blog/show/2068-pieces-of-mind-30-great-new-essay-collections">Read »</a>
# </div>
# </div>
# <div class="clear"></div>
# </div>
# <a class="actionLink right" href="/news">More articles…</a>
# <div class="clear"></div></div></div><div class="bigBoxBottom"></div></div> </div>
# </div>
# <ul class="listHeaderLinks stacked">
# <li>
# <a class="actionLinkLite" href="/list/new">Create New List</a>
# </li>
# <li>
# <a class="actionLinkLite" href="/list">All Lists</a>
# </li>
# <li>
# <a class="actionLinkLite" href="/list/created">Lists I Created</a>
# </li>
# <li>
# <a class="actionLinkLite" href="https://www.goodreads.com/user/new?remember=true&amp;return_url=%2Flist%2Fshow%2F252.Books_Made_into_Movies">Lists I've Voted On</a>
# </li>
# <li>
# <a class="actionLinkLite" href="https://www.goodreads.com/user/new?remember=true&amp;return_url=%2Flist%2Fshow%2F252.Books_Made_into_Movies">Lists I've Liked</a>
# </li>
# </ul>
# <p class="mediumText">
#       Anyone can add books to this list.
#   </p>
# <p>
# </p>
# <div data-react-class="ReactComponents.GoogleBannerAd" data-react-props='{"adId":"","className":"googleBannerAd--mediumRectangle"}'></div>
# <div data-react-class="ReactComponents.GoogleFeaturedContentModule" data-react-props='{"adId":"","trackingOptions":{"enableTracking":true,"adId":""},"isMobile":false,"isInline":false,"hasBottomBorder":false}'></div>
# <div class="clearFloats bigBox"><div class="h2Container gradientHeaderContainer"><h2 class="brownBackground"><div class="extraHeader"><span id="saving_notice" style="display:none">Saving <img alt="Loading trans" src="https://s.gr-assets.com/assets/loading-trans-ced157046184c3bc7c180ffbfc6825a4.gif"/></span></div><a href="/list/show/252.Books_Made_into_Movies">My Votes</a></h2></div><div class="bigBoxBody"><div class="bigBoxContent containerWithHeaderContent">
# <a class="actionLink" href="https://www.goodreads.com/user/new?remember=true&amp;return_url=%2Flist%2Fshow%2F252.Books_Made_into_Movies">vote now</a>
# <div class="clear"></div></div></div><div class="bigBoxBottom"></div></div>
# <br class="clear"/><br/>
# <div class="clearFloats bigBox"><div class="h2Container gradientHeaderContainer"><h2 class="brownBackground"><a href="/list/invite/252.Books_Made_into_Movies">Friends Votes</a></h2></div><div class="bigBoxBody"><div class="bigBoxContent containerWithHeaderContent">
# <a class="actionLink" href="https://www.goodreads.com/user/new?remember=true&amp;return_url=%2Flist%2Fshow%2F252.Books_Made_into_Movies">get your friends to vote</a>
# <div class="clear"></div></div></div><div class="bigBoxBottom"></div></div>
# <div data-react-class="ReactComponents.GoogleBannerAd" data-react-props='{"adId":"","className":"googleBannerAd--mediumRectangle"}'></div>
# </div>
# <div id="chooseExplanation" style="display:none">
# <h2>How to Vote</h2>
# <p>
#     To vote on existing books from the list, beside each book there is a link <span class="gr-button gr-button--small">vote for this book</span>  clicking it will add that book to your votes.
#   </p>
# <p>
#       To vote on books not in the list or books you couldn't find in the list, you can click on the tab <span class="bigTabs"><span class="tab">add books to this list</span></span> and then choose from your books, or simply search.
#     </p>
# </div>
# <div class="initiallyHidden" id="flagList252">
# <div class="modalBox">
# <h2>
# Flag this
# list
# </h2>
# <div class="flaggableText">
# </div>
# <h3>
# Why are you flagging this
# list?
# </h3>
# <form accept-charset="UTF-8" action="/flagged/create" method="post"><input name="utf8" type="hidden" value="✓"><input name="authenticity_token" type="hidden" value="hjynWo4j6AVauABEbVe66HZcWo2AucZLGhlld85buJG5/u4RE0G81hMR4kLPQwOTHm3ZzmNBeSUaJONZZLUnsg=="/>
# <input id="return_url" name="return_url" type="hidden" value="/"/>
# <input id="resource_id" name="resource_id" type="hidden" value="252"/>
# <input id="resource_type" name="resource_type" type="hidden" value="List"/>
# <input id="extra" name="extra" type="hidden" value=""/>
# <div class="formWithLabels">
# <label class="flaggable_reasons">
# <input checked="checked" id="reason_inappropriate" name="reason" type="radio" value="inappropriate"/>
# Inappropriate
# </label>
# <label class="flaggableReasonsDescription">
# The list (including its title or description) facilitates illegal activity, or contains hate speech or ad hominem attacks on a fellow Goodreads member or author.
# </label>
# <label class="flaggable_reasons">
# <input id="reason_spam_or_self-promotional" name="reason" type="radio" value="spam_or_self-promotional"/>
# Spam or Self-Promotional
# </label>
# <label class="flaggableReasonsDescription">
# The list is spam or self-promotional.
# </label>
# <label class="flaggable_reasons">
# <input id="reason_incorrect_book" name="reason" type="radio" value="incorrect_book"/>
# Incorrect Book
# </label>
# <label class="flaggableReasonsDescription">
# The list contains an incorrect book (please specify the title of the book).
# </label>
# <p>
# <label for="explanation">
# Details
# <span class="requiredIndicator">
# *
# </span>
# </label>
# </p>
# <textarea cols="45" id="explanation" name="explanation" placeholder="Please tell us more information about why you are flagging this." rows="5">
# </textarea>
# <p>
# <input class="button" data-confirm="We take abuse seriously on goodreads. Only flag lists that clearly need our attention. Are you sure you want to flag this list?" name="commit" type="submit" value="Flag this"/>
# or
# <a href="#" onclick="Lightbox.hideBox(); return false;">Cancel</a>
# </p>
# </div>
# </input></form>
#
# For more information, read
# <a class="actionLinkLite" href="/about/terms" rel="noopener noreferrer" target="_blank">our terms of service</a>.
# </div>
# </div>
# </div>
# <div class="clear"></div>
# </div>
# <div class="clear"></div>
# </div>
# <div data-react-class="ReactComponents.GooglePageSkin" data-react-props='{"adId":"","trackingOptions":{"enableTracking":true,"adId":""}}'></div>
# <div class="clear"></div>
# <footer class="responsiveSiteFooter">
# <div class="responsiveSiteFooter__contents gr-container-fluid">
# <div class="gr-row">
# <div class="gr-col gr-col-md-8 gr-col-lg-6">
# <div class="gr-row">
# <div class="gr-col-md-3 gr-col-lg-4">
# <h3 class="responsiveSiteFooter__heading">Company</h3>
# <ul class="responsiveSiteFooter__linkList">
# <li class="responsiveSiteFooter__linkListItem">
# <a class="responsiveSiteFooter__link" href="/about/us">About us</a>
# </li>
# <li class="responsiveSiteFooter__linkListItem">
# <a class="responsiveSiteFooter__link" href="/jobs">Careers</a>
# </li>
# <li class="responsiveSiteFooter__linkListItem">
# <a class="responsiveSiteFooter__link" href="/about/terms">Terms</a>
# </li>
# <li class="responsiveSiteFooter__linkListItem">
# <a class="responsiveSiteFooter__link" href="/about/privacy">Privacy</a>
# </li>
# <li class="responsiveSiteFooter__linkListItem">
# <a class="responsiveSiteFooter__link" href="https://help.goodreads.com/s/article/Goodreads-Interest-Based-Ads-Notice">Interest Based Ads</a>
# </li>
# <li class="responsiveSiteFooter__linkListItem">
# <a class="responsiveSiteFooter__link" href="/adprefs">Ad Preferences</a>
# </li>
# <li class="responsiveSiteFooter__linkListItem">
# <a class="responsiveSiteFooter__link" href="/help?action_type=help_web_footer">Help</a>
# </li>
# </ul>
# </div>
# <div class="gr-col-md-4 gr-col-lg-4">
# <h3 class="responsiveSiteFooter__heading">Work with us</h3>
# <ul class="responsiveSiteFooter__linkList">
# <li class="responsiveSiteFooter__linkListItem">
# <a class="responsiveSiteFooter__link" href="/author/program">Authors</a>
# </li>
# <li class="responsiveSiteFooter__linkListItem">
# <a class="responsiveSiteFooter__link" href="/advertisers">Advertise</a>
# </li>
# <li class="responsiveSiteFooter__linkListItem">
# <a class="responsiveSiteFooter__link" href="/news?content_type=author_blogs">Authors &amp; ads blog</a>
# </li>
# <li class="responsiveSiteFooter__linkListItem">
# <a class="responsiveSiteFooter__link" href="/api">API</a>
# </li>
# </ul>
# </div>
# <div class="gr-col-md-5 gr-col-lg-4">
# <h3 class="responsiveSiteFooter__heading">Connect</h3>
# <div class="responsiveSiteFooter__socialLinkWrapper">
# <a class="responsiveSiteFooter__socialLink" href="https://www.facebook.com/Goodreads/"><img alt="Goodreads on Facebook" src="https://s.gr-assets.com/assets/site_footer/footer_facebook-ea4ab848f8e86c5f5c98311bc9495a1b.svg"/>
# </a><a class="responsiveSiteFooter__socialLink" href="https://twitter.com/goodreads"><img alt="Goodreads on Twitter" src="https://s.gr-assets.com/assets/site_footer/footer_twitter-126b3ee80481a763f7fccb06ca03053c.svg"/>
# </a></div>
# <div class="responsiveSiteFooter__socialLinkWrapper">
# <a class="responsiveSiteFooter__socialLink" href="https://www.instagram.com/goodreads/"><img alt="Goodreads on Instagram" src="https://s.gr-assets.com/assets/site_footer/footer_instagram-d59e3887020f12bcdb12e6c539579d85.svg"/>
# </a><a class="responsiveSiteFooter__socialLink" href="https://www.linkedin.com/company/goodreads-com/"><img alt="Goodreads on LinkedIn" src="https://s.gr-assets.com/assets/site_footer/footer_linkedin-5b820f4703eff965672594ef4d10e33c.svg"/>
# </a></div>
# </div>
# </div>
# </div>
# <div class="gr-col gr-col-md-4 gr-col-lg-6 responsiveSiteFooter__appLinksColumn">
# <div class="responsiveSiteFooter__appLinksColumnContents">
# <div class="responsiveSiteFooter__appLinksColumnBadges">
# <a href="https://itunes.apple.com/app/apple-store/id355833469?pt=325668&amp;ct=mw_footer&amp;mt=8"><img alt="Download app for iOS" src="https://s.gr-assets.com/assets/app/badge-ios-desktop-homepage-6ac7ae16eabce57f6c855361656a7540.svg"/>
# </a><a href="https://play.google.com/store/apps/details?id=com.goodreads&amp;utm_source=mw_footer&amp;pcampaignid=MKT-Other-global-all-co-prtnr-py-PartBadge-Mar2515-1"><img alt="Download app for Android" src="https://s.gr-assets.com/assets/app/badge-android-desktop-home-0f517cbae4d56c88a128d27a7bea1118.png" srcset="https://s.gr-assets.com/assets/app/badge-android-desktop-home-2x-e31514e1fb4dddecf9293aa526a64cfe.png 2x"/>
# </a></div>
# <ul class="responsiveSiteFooter__linkList">
# <li class="responsiveSiteFooter__linkListItem">
# ©
# 2021
# Goodreads, Inc.
# </li>
# <li class="responsiveSiteFooter__linkListItem">
# <a class="responsiveSiteFooter__link" href="/toggle_mobile">Mobile version
# </a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </footer>
# <script>
# //<![CDATA[
# if (typeof window.uet == 'function') { window.uet('be'); }
# //]]>
# </script>
# </div>
# <!--
# This partial loads on almost every page view.  The associated React component makes
# a call to SignInPromptController#get to determine if the user should see the sign in interstial.
# This is determined by how many signed out pagehits the user has executed an how recently they have
# last seen the insterstitial.  If the controller responds indicating the popup should appear, the
# React component will render its content.
# -->
# <div data-react-class="ReactComponents.LoginInterstitial" data-react-props='{"allowFacebookSignIn":true,"allowAmazonSignIn":true,"overrideSignedOutPageCount":false,"path":{"signInUrl":"/user/sign_in","signUpUrl":"/user/sign_up","privacyUrl":"/about/privacy","termsUrl":"/about/terms","thirdPartyRedirectUrl":"/user/new?connect_prompt=true"}}'><noscript data-react-checksum="-1165291151" data-reactid=".1nkpbz78ifc"></noscript></div>
# <div id="overlay" onclick="Lightbox.hideBox()" style="display:none"></div>
# <div id="box" style="display:none">
# <div class="xBackground js-closeModalIcon" id="close" onclick="Lightbox.hideBox()" title="Close this window"></div>
# <div id="boxContents"></div>
# <div id="boxContentsLeftovers" style="display:none"></div>
# <div class="clear"></div>
# </div>
# <div id="fbSigninNotification" style="display:none;">
# <p>Welcome back. Just a moment while we sign you in to your Goodreads account.</p>
# <img alt="Login animation" src="https://s.gr-assets.com/assets/facebook/login_animation-085464711e6c1ed5ba287a2f40ba3343.gif"/>
# </div>
# <script>
#   //<![CDATA[
#     qcdata = {} || qcdata;
#       (function(){
#         var elem = document.createElement('script');
#         elem.src = (document.location.protocol == "https:" ? "https://secure" : "http://pixel") + ".quantserve.com/aquant.js?a=p-0dUe_kJAjvkoY";
#         elem.async = true;
#         elem.type = "text/javascript";
#         var scpt = document.getElementsByTagName('script')[0];
#         scpt.parentNode.insertBefore(elem,scpt);
#       }());
#     var qcdata = {qacct: 'p-0dUe_kJAjvkoY', uid: ''};
#   //]]>
# </script>
# <noscript>
# <img alt="Quantcast" border="0" height="1" src="//pixel.quantserve.com/pixel/p-0dUe_kJAjvkoY.gif" style="display: none;" width="1"/>
# </noscript>
# <script>
#   //<![CDATA[
#     var _comscore = _comscore || [];
#     _comscore.push({ c1: "2", c2: "6035830", c3: "", c4: "", c5: "", c6: "", c15: ""});
#     (function() {
#     var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#     s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#     el.parentNode.insertBefore(s, el);
#     })();
#   //]]>
# </script>
# <noscript>
# <img alt="" height="0" src="https://sb.scorecardresearch.com/p?c1=2&amp;amp;c2=6035830&amp;amp;c3=&amp;amp;c4=&amp;amp;c5=&amp;amp;c6=&amp;amp;c15=&amp;amp;cv=2.0&amp;amp;cj=1" style="display: none" width="0">
# </img></noscript>
# <script>
#   //<![CDATA[
#     window.addEventListener("DOMContentLoaded", function() {
#       ReactStores.GoogleAdsStore.initializeWith({"targeting":{"sid":"osid.8690af1847e5967fef790e12756d1da8","grsession":"osid.8690af1847e5967fef790e12756d1da8","surface":"desktop","signedin":"false","gr_author":"false","author":[],"shelf":["adaptation","booktofilm","booktomovie","books","movie","movies"],"tags":["31785","17670","4401","2386","1471","1372"],"gtargeting":"1","resource":"List_252"},"ads":{},"nativeAds":{}});  ReactStores.NotificationsStore.updateWith({});
#       ReactStores.CurrentUserStore.initializeWith({"currentUser":null});
#       ReactStores.FavoriteGenresStore.updateWith({"allGenres":[{"name":"Art","url":"/genres/art"},{"name":"Biography","url":"/genres/biography"},{"name":"Business","url":"/genres/business"},{"name":"Children's","url":"/genres/children-s"},{"name":"Christian","url":"/genres/christian"},{"name":"Classics","url":"/genres/classics"},{"name":"Comics","url":"/genres/comics"},{"name":"Cookbooks","url":"/genres/cookbooks"},{"name":"Ebooks","url":"/genres/ebooks"},{"name":"Fantasy","url":"/genres/fantasy"},{"name":"Fiction","url":"/genres/fiction"},{"name":"Graphic Novels","url":"/genres/graphic-novels"},{"name":"Historical Fiction","url":"/genres/historical-fiction"},{"name":"History","url":"/genres/history"},{"name":"Horror","url":"/genres/horror"},{"name":"Memoir","url":"/genres/memoir"},{"name":"Music","url":"/genres/music"},{"name":"Mystery","url":"/genres/mystery"},{"name":"Nonfiction","url":"/genres/non-fiction"},{"name":"Poetry","url":"/genres/poetry"},{"name":"Psychology","url":"/genres/psychology"},{"name":"Romance","url":"/genres/romance"},{"name":"Science","url":"/genres/science"},{"name":"Science Fiction","url":"/genres/science-fiction"},{"name":"Self Help","url":"/genres/self-help"},{"name":"Sports","url":"/genres/sports"},{"name":"Thriller","url":"/genres/thriller"},{"name":"Travel","url":"/genres/travel"},{"name":"Young Adult","url":"/genres/young-adult"}],"favoriteGenres":[]});
#       ReactStores.TabsStore.updateWith({"communitySpotlight":"groups"});
#
#     });
#   //]]>
# </script>
# </body>
# </html>
# <!-- This is a random-length HTML comment: ... -->

# %%
# css-selector for book title -> css selector: .tableList > tbody:nth-child(1) > tr:nth-child(4) > td:nth-child(3) > a:nth-child(1) > span:nth-child(1)
soup3.select("td:nth-child(3) > a:nth-child(1) > span:nth-child(1)")[0].text
# Out:
# 'The Lord of the Rings'

# %%
# css selector for authors -> css selector: .tableList > tbody:nth-child(1) > tr:nth-child(1) > td:nth-child(3) > span:nth-child(4) > div:nth-child(1) > a:nth-child(1) > span:nth-child(1)
soup3.select("td:nth-child(3) > span:nth-child(4) > div:nth-child(1) > a:nth-child(1) > span:nth-child(1)")[0].text
# Out:
# 'C.S. Lewis'

# %%
# On the list are 818 books / 100 books per page -> 9 pages
iterations3 = range(1, 10)

# %%
pages3 = []
url_lst3 = []

for i in iterations3:
    url3 = f"https://www.goodreads.com/list/show/252.Books_Made_into_Movies?page={i}"
    url_lst3.append(url3)
    
    # download the url
    response3 = requests.get(url3)
    
    # print the status code
    print("Status code: " + str(response3.status_code))
    
    pages3.append(response3)
    
    # respectful nap
    wait_time = uniform(0.3, 2)
    sleep(wait_time)
# Out:
# Status code: 200
# Status code: 200
# Status code: 200
# Status code: 200
# Status code: 200
# Status code: 200
# Status code: 200
# Status code: 200
# Status code: 200

# %%
len(pages3)
# Out:
# 9

# %%
Book3 = []
# book into movie -> yes = 1
Book_into_Movie3 = []
pages_parsed3 = []


# looping through all pages
for i in range(len(pages3)):
    # a soup for ever search result page
    pages_parsed3.append(BeautifulSoup(pages3[i].content, "html.parser"))
 
    # books
    book_html3 = pages_parsed3[i].select("td:nth-child(3)")
    
    # loop through the html content of the movies of the current page (i)
    for j in range(len(book_html3)):
        
        # extract and append titles to title list
        Book3.append(book_html3[j].select("td:nth-child(3) > a:nth-child(1) > span:nth-child(1)")[0].text)
        Book_into_Movie3.append("1")

# %%
Book3
# Out:
# ['The Lord of the Rings',
#  'The Lion, the Witch and the Wardrobe (Chronicles of Narnia, #1)',
#  'Harry Potter Series Box Set (Harry Potter, #1-7)',
#  'To Kill a Mockingbird',
#  'Charlie and the Chocolate Factory (Charlie Bucket, #1)',
#  'The Princess Bride',
#  'Pride and Prejudice',
#  'Twilight (Twilight, #1)',
#  'Memoirs of a Geisha',
#  'Harry Potter and the Prisoner of Azkaban (Harry Potter, #3)',
#  'The Hobbit, or There and Back Again',
#  'Different Seasons',
#  'Little Women',
#  "Charlotte's Web",
#  "Harry Potter and the Sorcerer's Stone (Harry Potter, #1)",
#  'Gone with the Wind',
#  'Romeo and Juliet',
#  'Interview with the Vampire (The Vampire Chronicles, #1)',
#  'The Hunger Games (The Hunger Games, #1)',
#  'The Green Mile',
#  'Jurassic Park (Jurassic Park, #1)',
#  'Stardust',
#  'The Wonderful Wizard of Oz (Oz, #1)',
#  'The Secret Garden',
#  "Bridget Jones's Diary (Bridget Jones, #1)",
#  'Holes (Holes, #1)',
#  'The Great Gatsby',
#  'Fried Green Tomatoes at the Whistle Stop Cafe',
#  'Harry Potter and the Chamber of Secrets (Harry Potter, #2)',
#  'The Color Purple',
#  'The Notebook (The Notebook, #1)',
#  'Bridge to Terabithia',
#  'The Da Vinci Code (Robert Langdon, #2)',
#  'The Help',
#  'Harry Potter and the Goblet of Fire (Harry Potter, #4)',
#  'Anne of Green Gables (Anne of Green Gables, #1)',
#  'The Joy Luck Club',
#  'Peter Pan',
#  'Carrie',
#  'The Devil Wears Prada (The Devil Wears Prada, #1)',
#  "One Flew Over the Cuckoo's Nest",
#  'The Diary of a Young Girl',
#  'Harry Potter and the Order of the Phoenix (Harry Potter, #5)',
#  'Atonement',
#  'The Golden Compass (His Dark Materials, #1)',
#  'Sense and Sensibility',
#  'The Neverending Story',
#  'The Shining',
#  'The Outsiders',
#  'Fahrenheit 451',
#  'A Christmas Carol',
#  'Angels & Demons (Robert Langdon, #1)',
#  'New Moon (Twilight, #2)',
#  'Jane Eyre',
#  'Matilda',
#  'Emma',
#  'Lord of the Flies',
#  'A Little Princess',
#  'How the Grinch Stole Christmas!',
#  'Catching Fire (The Hunger Games, #2)',
#  'Much Ado About Nothing',
#  'The Stand',
#  'Prince Caspian (Chronicles of Narnia, #2)',
#  'Eclipse (The Twilight Saga, #3)',
#  'Midnight in the Garden of Good and Evil',
#  'The Girl with the Dragon Tattoo (Millennium, #1)',
#  'The Bad Beginning (A Series of Unfortunate Events, #1)',
#  "Breakfast at Tiffany's and Three Stories",
#  'The Count of Monte Cristo',
#  'Mockingjay (The Hunger Games, #3)',
#  'V for Vendetta',
#  'The Lovely Bones',
#  'Divergent (Divergent, #1)',
#  'Wuthering Heights',
#  'Watership Down (Watership Down, #1)',
#  'White Oleander',
#  'Doctor Zhivago',
#  'Dune (Dune Chronicles, #1)',
#  'Lolita',
#  'Rebecca',
#  "'Salem's Lot",
#  'The Fault in Our Stars',
#  'Jaws (Jaws #1)',
#  'Divine Secrets of the Ya-Ya Sisterhood',
#  'Howl’s Moving Castle (Howl’s Moving Castle, #1)',
#  "The Hitchhiker's Guide to the Galaxy (Hitchhiker's Guide to the Galaxy, #1)",
#  'The Exorcist',
#  "The Ultimate Hitchhiker's Guide to the Galaxy (Hitchhiker's Guide to the Galaxy, #1-5)",
#  'Frankenstein: The 1818 Text',
#  'Coraline',
#  'I Am Legend and Other Stories',
#  'Alice in Wonderland',
#  'Of Mice and Men',
#  'Persuasion',
#  'The Silence of the Lambs  (Hannibal Lecter, #2)',
#  'City of Bones (The Mortal Instruments, #1)',
#  'The Godfather (The Godfather, #1)',
#  'The Perks of Being a Wallflower',
#  'The Age of Innocence',
#  'A Time to Kill (Jake Brigance, #1)',
#  'The Adventures of Huckleberry Finn',
#  'Dracula',
#  "The Time Traveler's Wife",
#  'Chitty Chitty Bang Bang (Chitty Chitty Bang Bang, #1)',
#  'Breaking Dawn (The Twilight Saga, #4)',
#  'Snow Falling on Cedars',
#  'The Bridges of Madison County',
#  'And Then There Were None',
#  'The Secret Life of Bees',
#  'Seabiscuit: An American Legend',
#  'The Kite Runner',
#  'Catch-22',
#  'The Book Thief',
#  'Gone Girl',
#  'Girl with a Pearl Earring',
#  'In Her Shoes',
#  'The Pelican Brief',
#  "Sophie's Choice",
#  'The Witches',
#  'In Cold Blood',
#  "The Pianist: The Extraordinary Story of One Man's Survival in Warsaw, 1939–45",
#  'The Andromeda Strain (Andromeda, #1)',
#  'Madeline',
#  'No Country for Old Men',
#  'The City of Ember (Book of Ember, #1)',
#  'Insurgent (Divergent, #2)',
#  'Journey to the Center of the Earth',
#  'Vampire Academy (Vampire Academy, #1)',
#  'Girl, Interrupted',
#  "My Sister's Keeper",
#  "Alice's Adventures in Wonderland / Through the Looking-Glass",
#  '1984',
#  'A Tree Grows in Brooklyn',
#  'James and the Giant Peach',
#  'The Polar Express',
#  'Practical Magic (Practical Magic, #1)',
#  'Water for Elephants',
#  'The Giver (The Giver, #1)',
#  'The Autobiography of Malcolm X',
#  'The Maze Runner (The Maze Runner, #1)',
#  "Miss Peregrine's Home for Peculiar Children (Miss Peregrine's Peculiar Children, #1)",
#  'The Firm',
#  'Macbeth',
#  'Cold Mountain',
#  'The Host',
#  'Ella Enchanted (Ella Enchanted #1)',
#  'Paper Towns',
#  'The Voyage of the Dawn Treader (Chronicles of Narnia, #3)',
#  'The Tale of Despereaux',
#  'The Girl on the Train',
#  'Old Yeller',
#  'A Room with a View',
#  'The Prestige',
#  'Oliver Twist',
#  'Mary Poppins (Mary Poppins, #1)',
#  'Where the Red Fern Grows',
#  'Timeline',
#  'Tuck Everlasting',
#  'High Fidelity',
#  'Dear John',
#  'Fight Club',
#  'The Amityville Horror',
#  'Eat, Pray, Love',
#  'A Clockwork Orange',
#  'Tinker, Tailor, Soldier, Spy',
#  'Delirium (Delirium, #1)',
#  'Contact',
#  'Waiting to Exhale (Waiting To Exhale #1)',
#  'Hamlet',
#  "Schindler's List",
#  'Message in a Bottle',
#  'Stuart Little',
#  'Where the Heart Is',
#  'The Hunt for Red October (Jack Ryan, #3)',
#  'The Twilight Saga (Twilight, #1-4)',
#  'The Martian',
#  'Life of Pi',
#  'Brideshead Revisited',
#  'Mansfield Park',
#  'Harry Potter and the Deathly Hallows (Harry Potter, #7)',
#  'Allegiant (Divergent, #3)',
#  'The Curious Case of Benjamin Button',
#  'Fifty Shades of Grey (Fifty Shades, #1)',
#  'Me Before You (Me Before You, #1)',
#  'A Tale of Two Cities',
#  'The Picture of Dorian Gray',
#  'The Fellowship of the Ring (The Lord of the Rings, #1)',
#  'War and Peace',
#  'Great Expectations',
#  'Animal Farm',
#  'Vanity Fair',
#  'Where the Wild Things Are',
#  'Do Androids Dream of Electric Sheep? (Blade Runner, #1)',
#  "Angela's Ashes (Frank McCourt, #1)",
#  'Along Came a Spider (Alex Cross, #1)',
#  'The Virgin Suicides',
#  'The Two Towers (The Lord of the Rings, #2)',
#  'World War Z: An Oral History of the Zombie War',
#  "Ender's Game (Ender's Saga, #1)",
#  'The Namesake',
#  'The Gunslinger',
#  'Starship Troopers',
#  'The Big Sleep (Philip Marlowe #1)',
#  '2001: A Space Odyssey (Space Odyssey, #1)',
#  'The Name of the Rose',
#  'Forrest Gump (Forrest Gump, #1)',
#  'The Strange Case of Dr. Jekyll and Mr. Hyde',
#  "Rosemary's Baby (Rosemary's Baby, #1)",
#  'The Reader',
#  'A Monster Calls',
#  'Gone, Baby, Gone (Kenzie & Gennaro, #4)',
#  'The Cider House Rules',
#  "A Midsummer Night's Dream",
#  'Northanger Abbey',
#  'Twelve Years a Slave',
#  'The Lorax',
#  'Bridget Jones: The Edge of Reason (Bridget Jones, #2)',
#  'American Psycho',
#  'The Day of the Jackal',
#  'The African Queen',
#  'Sybil: The Classic True Story of a Woman Possessed by Sixteen Personalities',
#  'The Moonstone',
#  'Persepolis: The Story of a Childhood (Persepolis, #1)',
#  'Gorky Park (Arkady Renko, #1)',
#  'The Last Olympian (Percy Jackson and the Olympians, #5)',
#  'Amadeus',
#  'Out of Africa',
#  'A Wrinkle in Time (A Wrinkle in Time Quintet, #1)',
#  'The Witches of Eastwick (Eastwick #1)',
#  'The Lost World (Jurassic Park #2)',
#  "Marley and Me: Life and Love With the World's Worst Dog",
#  'The Talented Mr. Ripley (Ripley, #1)',
#  'The First Wives Club',
#  'Pet Sematary',
#  'Annie',
#  'Auntie Mame: An Irreverent Escapade (Auntie Mame, #1)',
#  'The End of the Affair',
#  'Ordinary People',
#  'Abraham Lincoln: Vampire Hunter',
#  'Everything Is Illuminated',
#  'Murder on the Orient Express (Hercule Poirot, #10)',
#  'Cheaper by the Dozen',
#  'The Unbearable Lightness of Being',
#  'The Woman in White',
#  'The Other Boleyn Girl (The Plantagenet and Tudor Novels, #9)',
#  'Bambi',
#  'Looking for Mr. Goodbar',
#  'Fallen (Fallen, #1)',
#  'The Borrowers (The Borrowers, #1)',
#  'I Am Legend',
#  'Red Dragon (Hannibal Lecter, #1)',
#  'Death of a Salesman',
#  'Picnic at Hanging Rock',
#  'Henry V',
#  'Fifty Shades Darker (Fifty Shades, #2)',
#  'White Fang',
#  "Nick & Norah's Infinite Playlist",
#  'Fantastic Beasts and Where to Find Them',
#  'Awakenings',
#  'Invasion of the Body Snatchers',
#  'A Streetcar Named Desire',
#  'The Remains of the Day',
#  'Elegy for Iris',
#  'The Time Machine',
#  'The Black Dahlia (L.A. Quartet, #1)',
#  'Left Behind (Left Behind, #1)',
#  'The Last Song',
#  'Horton Hears a Who!',
#  'Private Parts',
#  'The Running Man',
#  'The Mist',
#  'Howards End',
#  'Tomorrow, When the War Began (Tomorrow, #1)',
#  'Coma',
#  'Psycho (Psycho #1)',
#  'The Lincoln Lawyer (Mickey Haller, #1; Harry Bosch Universe, #15)',
#  'The House of the Spirits',
#  'Fantastic Mr. Fox',
#  'The Invention of Hugo Cabret',
#  'If I Stay (If I Stay, #1)',
#  'Planet of the Apes',
#  'I, Claudius (Claudius, #1)',
#  'Ready Player One (Ready Player One, #1)',
#  'The Snowman',
#  "Who's Afraid of Virginia Woolf?",
#  'Equus',
#  "Jarhead: A Marine's Chronicle Of The Gulf War And Other Battles",
#  'Mrs. Frisby and the Rats of NIMH (Rats of NIMH, #1)',
#  'John Adams',
#  'A Passage to India',
#  'Witness for the Prosecution and Selected Plays',
#  'Solaris',
#  'North and South',
#  'The Accidental Tourist',
#  'Lassie Come-Home',
#  'The Other',
#  'The Adventures of Tom Sawyer',
#  'Little Big Man',
#  'Love in the Time of Cholera',
#  'Harriet the Spy (Harriet the Spy #1)',
#  'Love Story (Love Story, #1)',
#  'Warm Bodies (Warm Bodies, #1)',
#  'The Hound of the Baskervilles (Sherlock Holmes, #5)',
#  'The Story of the Trapp Family Singers',
#  'Looking for Alaska',
#  'The Prince of Tides',
#  'The Odessa File',
#  'The Importance of Being Earnest',
#  'Ivanhoe',
#  'The Sea of Monsters (Percy Jackson and the Olympians, #2)',
#  'The Day of the Triffids',
#  "It's Kind of a Funny Story",
#  'Eaters of the Dead',
#  'Far From the Madding Crowd',
#  'My Family and Other Animals (Corfu Trilogy, #1)',
#  'The 5th Wave (The 5th Wave, #1)',
#  'The Maltese Falcon',
#  'Nausicaä of the Valley of the Wind, Vol. 1 (Nausicaä of the Valley of the Wind, #1)',
#  'Eragon (The Inheritance Cycle, #1)',
#  'Kim',
#  'Never Let Me Go',
#  'The Inheritance',
#  'MASH: A Novel About Three Army Doctors (M*A*S*H, #1)',
#  'Sarah, Plain and Tall (Sarah, Plain and Tall, #1)',
#  'Hush, Hush (Hush, Hush, #1)',
#  'I, Robot (Robot, #0.1)',
#  'Legends of the Fall',
#  'The Legend of Sleepy Hollow',
#  'The Road',
#  'Like Water for Chocolate',
#  'The Lathe of Heaven',
#  'Oil!',
#  "Carrie / 'Salem's Lot / The Shining",
#  'The Phantom of the Opera',
#  'The Jungle Book',
#  'The Hellbound Heart',
#  'Nights in Rodanthe',
#  'Seven Years in Tibet',
#  'Farewell, My Lovely (Philip Marlowe #2)',
#  'About Schmidt (Schmidt, #1)',
#  'The Thirteenth Tale',
#  'Absolute Power',
#  'All You Need Is Kill',
#  'We Need to Talk About Kevin',
#  'The Postman Always Rings Twice',
#  'Born Free: A Lioness of Two Worlds (Story of Elsa, #1)',
#  'The Beach',
#  'Jonathan Livingston Seagull',
#  'Red Riding Hood',
#  'Pivot Point (Pivot Point, #1)',
#  'The Lightning Thief (Percy Jackson and the Olympians, #1)',
#  'A Beautiful Mind',
#  "Smilla's Sense of Snow",
#  'The Hours',
#  'Fences (The Century Cycle #6)',
#  'Watchmen',
#  'The Old Man and the Sea',
#  'The Quiet American',
#  'The Spiderwick Chronicles Box Set (The Spiderwick Chronicles, #1-5)',
#  'Patriot Games (Jack Ryan, #1; Jack Ryan Universe, #2)',
#  'Death on the Nile (Hercule Poirot, #17)',
#  'Jean de Florette',
#  'The Poseidon Adventure',
#  'Casino Royale',
#  'Jean de Florette & Manon of the Springs (Two Novels)',
#  'A Wonderful Welcome to Oz: The Marvelous Land of Oz, Ozma of Oz, & the Emerald City of Oz',
#  'The Raven',
#  'Disclosure',
#  'The Princess Diaries (The Princess Diaries, #1)',
#  'Kiss the Girls (Alex Cross, #2)',
#  'The Return of the King (The Lord of the Rings, #3)',
#  'This is Where I Leave You',
#  'Carolina Moon',
#  'Heart of Darkness',
#  'The Picture of Dorian Gray and Other Fantastic Tales',
#  "Charlie Wilson's War: The Extraordinary Story of How the Wildest Man in Congress and a Rogue CIA Agent Changed the History of our Times",
#  'The Bad Seed',
#  'A Night to Remember',
#  'Mermaids',
#  'The Twelve Chairs',
#  'The Hunchback of Notre-Dame',
#  'Crash',
#  'A Town Like Alice',
#  'Anywhere But Here (Mayan Stevenson, #1)',
#  'Sphere',
#  'The Red Badge of Courage',
#  'The Great Train Robbery',
#  'The League of Extraordinary Gentlemen, Vol. 1',
#  'One for the Money (Stephanie Plum, #1)',
#  'Breathing Lessons',
#  'Jacob Have I Loved',
#  'Flowers for Algernon',
#  "Corelli's Mandolin",
#  'Robinson Crusoe',
#  'Aquamarine (Water Tales #1)',
#  'Congo',
#  'All Quiet on the Western Front',
#  'The Ice Storm',
#  'Arsenic and Old Lace',
#  'The Sword in the Stone (The Once and Future King, #1)',
#  'Love Comes Softly (Love Comes Softly, #1)',
#  "Love's Long Journey (Love Comes Softly #3)",
#  'Orlando',
#  'The Turn of the Screw',
#  'Miracle on 34th Street',
#  "Love's Enduring Promise (Love Comes Softly #2)",
#  'Tulip Fever',
#  'The Green Mile, Part 6: Coffey on the Mile',
#  'Captains Courageous',
#  "Love's Abiding Joy (Love Comes Softly #4)",
#  'Shutter Island',
#  'Presumed Innocent (Kindle County Legal Thriller #1)',
#  'The Bad Death of Eduard Delacroix',
#  'The Stepford Wives',
#  'Pornografia',
#  'The Mouse on the Mile (The Green Mile #2)',
#  'Night Journey',
#  'Running with Scissors',
#  'Speak',
#  'Wives and Daughters',
#  'Apt Pupil',
#  'Inkheart (Inkworld, #1)',
#  'Christmas Eve at Friday Harbor (Friday Harbor, #1)',
#  'The Drawing of the Three (The Dark Tower, #2)',
#  'Eugene Onegin',
#  'Misery',
#  'The 19th Wife',
#  'The Scorch Trials (Maze Runner, #2)',
#  'Yentl: Movie Selections',
#  'The Last Unicorn (The Last Unicorn, #1)',
#  "Coffey's Hands",
#  'Hannibal (Hannibal Lecter, #3)',
#  '2010: Odyssey Two (Space Odyssey, #2)',
#  'The Death Cure (The Maze Runner, #3)',
#  'The Painted Veil',
#  'Postcards from the Edge',
#  "Mr. Popper's Penguins",
#  'Cranford',
#  'The Mayor of Casterbridge',
#  "All the King's Men",
#  'The Body',
#  'The Color of Magic (Discworld, #1; Rincewind, #1)',
#  '20,000 Leagues Under the Sea',
#  'The Velveteen Rabbit',
#  'True Grit',
#  'Cujo',
#  'Ben-Hur: A Tale of the Christ',
#  'The Two Dead Girls',
#  'The Bonfire of the Vanities',
#  'The BFG',
#  'Skeleton Crew',
#  'Rising Sun',
#  'Daisy Miller',
#  'Fluke',
#  'The Plague Dogs',
#  'Sounder',
#  'Mother',
#  'Winged Creatures',
#  'Aunt Julia and the Scriptwriter',
#  'Pieces of Eight: A Story of Sex & Love, Trust & Betrayal',
#  'Good Dreams',
#  "This Boy's Life",
#  'Prinsesse af Blodet',
#  'Grace',
#  'The Pillars of the Earth (Kingsbridge, #1)',
#  'Trainspotting (Mark Renton #2)',
#  'Skins',
#  'The Squaw Man',
#  'Green Light',
#  "Winter's Tale",
#  'Whispers',
#  'Ruby Red (Precious Stone Trilogy, #1)',
#  'Damselfly',
#  'Ophelia',
#  'The Love Letter',
#  'Sanctuary',
#  'Beezus and Ramona (Ramona, #1)',
#  'House of Sand and Fog',
#  'Green Mansions',
#  'Just Mercy: A Story of Justice and Redemption',
#  'The Frog Princess (Tales of the Frog Princess Book 1)',
#  'Disgrace',
#  'The Demonologist: The Extraordinary Career of Ed & Lorraine Warren',
#  'The Adjustment Bureau and Other Classic Stories',
#  'Shopgirl',
#  'Big Red (Big Red, #1)',
#  'Blue Smoke',
#  'Simon vs. the Homo Sapiens Agenda (Simonverse, #1)',
#  'After the Quake',
#  "After Hours (Basis for the film Carlito's Way starring Al Pacino)",
#  'A Dream Like Mine',
#  'The Island of Adventure (Adventure, #1)',
#  'Rogue One - A Star Wars Story',
#  'Carnal Innocence',
#  'Dead Poets Society',
#  'Room',
#  'Good Night, Mr. Tom',
#  'Treasure Island',
#  'Laughing Boy: A Navajo Love Story',
#  'The Black Cauldron (The Chronicles of Prydain, #2)',
#  'The Mysterious Affair at Styles',
#  'Tribute',
#  'Confessions of a Shopaholic (Shopaholic, #1)',
#  'Upside-Down Magic (Upside-Down Magic, #1)',
#  'The Minority Report',
#  'House Made of Dawn',
#  'Midnight Bayou',
#  'The Basketball Diaries',
#  'Fat Kid Rules the World',
#  'Medicine River',
#  'The Dangerous Lives of Altar Boys',
#  'In the Heart of the Sea: The Tragedy of the Whaleship Essex',
#  'Northern Lights',
#  'Something Borrowed (Darcy & Rachel, #1)',
#  'The Feast of All Saints',
#  'The Dark Wind (Leaphorn & Chee, #5)',
#  'The Cat in the Hat (The Cat in the Hat, #1)',
#  'The Glass Castle',
#  "All the President's Men",
#  'A Thief of Time (Leaphorn & Chee, #8)',
#  'Intensity',
#  'Angels Fall',
#  'Harry Potter and the Half-Blood Prince (Harry Potter, #6)',
#  'The Perfect Storm: A True Story of Men Against the Sea',
#  'The Natural',
#  'The League of Extraordinary Gentlemen: Black Dossier',
#  'Hideaway',
#  'Montana Sky',
#  'The Taming of the Shrew',
#  'Watchers',
#  'Crazy Rich Asians (Crazy Rich Asians, #1)',
#  'Master and Commander (Aubrey & Maturin, #1)',
#  '58 Minutes (Die Hard, #2)',
#  'The Virginian: A Horseman of the Plains',
#  'The Hate U Give (The Hate U Give, #1)',
#  'The Wide Window (A Series of Unfortunate Events, #3)',
#  'Norwegian Wood',
#  'Nothing Lasts Forever (Die Hard, #1)',
#  'The Firm',
#  'Quo Vadis',
#  'Deadly, Unna?',
#  'Primal Fear',
#  'The Reptile Room (A Series of Unfortunate Events, #2)',
#  'Phantoms',
#  'Queen Margot, or Marguerite de Valois (The Last Valois, #1)',
#  'The History of Tom Jones, a Foundling',
#  'Relic (Pendergast, #1)',
#  'Helter Skelter: The True Story of the Manson Murders',
#  'Revolutionary Road',
#  'Manon des sources',
#  'Shane',
#  'The Servants of Twilight',
#  'Rita Hayworth and Shawshank Redemption',
#  'Falling Angel',
#  'A Stir of Echoes',
#  "Captain Corelli's Mandolin (Piano Solo)",
#  'K-PAX',
#  'Little Children',
#  "King Solomon's Mines",
#  'Appaloosa (Virgil Cole & Everett Hitch, #1)',
#  'The Searchers',
#  'The Client',
#  'The Nanny Diaries (Nanny, #1)',
#  'The Monster Club',
#  'Le Petit Prince',
#  'The Shootist',
#  'Sardonicus and Other Stories',
#  'The Life Before Her Eyes',
#  'Hoot',
#  'A Farewell to Arms',
#  'The Metamorphosis',
#  'Devil in a Blue Dress (Easy Rawlins, #1)',
#  "Donovan's Brain",
#  'Anne Frank: The Diary of a Young Girl',
#  'Seize the Day',
#  'The Long Goodbye (Philip Marlowe #6)',
#  'Foxfire: Confessions of a Girl Gang',
#  'The Year of Living Dangerously',
#  'The Howling',
#  'Because of Winn-Dixie',
#  'The Magus',
#  'Freak the Mighty (Freak The Mighty, #1)',
#  'A Dog Named Christmas (A Dog Named Christmas #1)',
#  'The Power of One (The Power of One, #1)',
#  'Cloudstreet',
#  'Red Dog',
#  'The Scapegoat',
#  'Carnosaur',
#  'The Water Horse',
#  "Mackenna's Gold",
#  'Captain Blood: His Odyssey',
#  'Hell Hound',
#  "Prizzi's Honor",
#  'Born on the 4th of July',
#  'Incendiary',
#  'The Diviners',
#  'Black Sunday',
#  'Burnt Offerings',
#  'Waking the Dead',
#  'The Bears and I: Raising Three Cubs in the North Woods',
#  'Women in Love',
#  'Lion',
#  'Odd Thomas (Odd Thomas, #1)',
#  'Song of Susannah (The Dark Tower, #6)',
#  'The Nest',
#  "Terry Jones' Medieval Lives",
#  'For Whom the Bell Tolls',
#  'The Christmas Shoes (Christmas Hope, #1)',
#  "The Englishman's Boy",
#  'Wolves of the Calla (The Dark Tower, #5)',
#  "The Bird's Nest",
#  'Reality and Dream: Psychotherapy of a Plains Indian',
#  'The Lady in the Van',
#  'The Red and the Black',
#  'Wizard and Glass (The Dark Tower, #4)',
#  'The Dunwich Horror: Seven Stories',
#  'The Dogs of War',
#  'The Postman',
#  'Winter in the Blood',
#  'Hidden Figures',
#  'The Bourne Identity (Jason Bourne, #1)',
#  'The Waste Lands (The Dark Tower, #3)',
#  'Ligeia',
#  'Driving Miss Daisy',
#  'Here on Earth',
#  'The Christmas Hope (Christmas Hope, #3)',
#  'The Ghost and Mrs. Muir',
#  'The Piano Teacher',
#  'The Dark Fields (Limitless, #1)',
#  'Pin',
#  'All the Bright Places',
#  'Out Of My Head',
#  'The Manitou (Manitou #1)',
#  'Captain Alatriste (Adventures of Captain Alatriste, #1)',
#  'Golden Calf',
#  'The Gods Hate Kansas',
#  'Arthur and the Minimoys',
#  'The Circle',
#  'The Werewolf of Paris',
#  'GoodFellas',
#  'The Lucifer Effect: Understanding How Good People Turn Evil',
#  'Cycle of the Werewolf',
#  'Patton',
#  'Summer in February',
#  'American Pastoral (The American Trilogy, #1)',
#  'Boy Erased: A Memoir',
#  'Twins',
#  'The Descendants',
#  'My Friend Flicka (Flicka, #1)',
#  'Make Room! Make Room!',
#  'The Rats (Rats, #1)',
#  'The Christmas Blessing (Christmas Hope, #2)',
#  'The Wings of the Dove',
#  'National Velvet',
#  'The Skull of the Marquis de Sade',
#  'Salem Falls',
#  'Hideous Kinky',
#  'The Portrait of a Lady',
#  'The Uninvited',
#  'The Soloist: A Lost Dream, an Unlikely Friendship, and the Redemptive Power of Music',
#  'We Were Soldiers Once... and Young: Ia Drang - The Battle that Changed the War in Vietnam',
#  'The Fury',
#  'The Man From Snowy River',
#  'Dreamcatcher',
#  'Cabal',
#  'Let it Snow',
#  'The Danish Girl',
#  'The Runaway Jury',
#  'Hell House',
#  'The Fall of the House of Usher and Other Tales',
#  'Fast Food Nation: The Dark Side of the All-American Meal',
#  'Trucks',
#  'Shardik',
#  'The Bridge Over the River Kwai',
#  'The Edge of Running Water',
#  'The Light Between Oceans',
#  'We Bought a Zoo',
#  'Willard',
#  'Pillar of Light (The Work and the Glory, #1)',
#  'Studs Lonigan',
#  'Brooklyn',
#  'Skipping Christmas',
#  'The Rainmaker',
#  'Eye of the Devil',
#  "Alice's Adventures in Wonderland (Alice's Adventures in Wonderland, #1)",
#  'Like a Fire Burning (The Work and the Glory, #2)',
#  'The Christmas Box (The Christmas Box, #1)',
#  'The Chamber',
#  "Gerald's Game",
#  'The Pyx',
#  'Before I Go To Sleep',
#  'Kidnapped (David Balfour, #1)',
#  'The Women of Brewster Place',
#  'Alone in Berlin',
#  'Choke',
#  'The Visitor',
#  'Oscar et la dame rose',
#  'The Railway Children',
#  'Exodus',
#  'Jumper (Jumper, #1)',
#  'The Ruins',
#  'Return of the Living Dead',
#  'The Survivor',
#  'Jasper Jones',
#  'The Little Mermaid',
#  'The Wolfen',
#  'Blue Dog',
#  'Pygmalion',
#  'Slugs (Slugs, #1)',
#  'Less Than Zero',
#  'The Good Earth (House of Earth, #1)',
#  'Birdsong',
#  'Benighted',
#  'Puppet on a Chain',
#  'Eldest (The Inheritance Cycle, #2)',
#  'The Two Faces of January',
#  'The Influence',
#  'Breakheart Pass',
#  'The Man Who Knew Too Much',
#  'Ghost Story',
#  'The Fourth Protocol',
#  'Nightwing',
#  'The Fixer',
#  'Q & A',
#  'The Sentinel',
#  'The Septembers of Shiraz',
#  'Father Christmas Goes on Holiday',
#  'The Mephisto Waltz',
#  'The Treasure of the Sierra Madre',
#  'Wonderstruck',
#  'Nicholas and Alexandra',
#  'When the Wind Blows',
#  'When Michael Calls',
#  "Uncle Tom's Cabin",
#  'Wild Pork and Watercress',
#  'Father Christmas',
#  'Cold Moon Over Babylon',
#  'Where Eagles Dare',
#  'Riders of the Purple Sage (Riders of the Purple Sage #1)',
#  'Doctor No (James Bond, #6)',
#  'Playing Beatie Bow',
#  'The Year of the Angry Rabbit',
#  'Scarface',
#  'Live and Let Die (James Bond, #2)',
#  'The Women in Black',
#  'The Hephaestus Plague',
#  'Three Comrades',
#  'Josey Wales: Two Westerns',
#  'For Your Eyes Only (James Bond, #8)',
#  'The Delinquents',
#  'The Swarm',
#  'Mountain Man',
#  'Seven Footprints to Satan',
#  'Brighton Rock',
#  'Conjure Wife',
#  'The Bone Collector (Lincoln Rhyme, #1)',
#  'The Ox-Bow Incident',
#  'Something Wicked This Way Comes (Green Town, #2)',
#  'Destry Rides Again',
#  'Ritual',
#  'The Loved One',
#  'The Assassination of Jesse James by the Coward Robert Ford',
#  'The Lair Of The White Worm',
#  'The Dig',
#  'Tarka the Otter',
#  'Dances with Wolves (Dances with Wolves, #1)',
#  'The Border Trilogy: All the Pretty Horses, The Crossing, Cities of the Plain',
#  'Nothing But the Night',
#  'Julia',
#  'Slimer',
#  'How the West Was Won',
#  'The Entity',
#  'The Shrinking Man',
#  'Full Dark, No Stars',
#  'The Illustrated Man',
#  'Something Evil',
#  'The Snows of Kilimanjaro and Other Stories',
#  'Terms of Endearment',
#  'The Hunger (Hunger, #1)',
#  'Audrey Rose',
#  'The Possession of Joel Delaney',
#  'The Night of the Hunter',
#  'One Day in the Life of Ivan Denisovich',
#  'The Godsend',
#  'The Midnight Meat Train',
#  'Crazy Heart',
#  'The House Next Door',
#  'Run Silent Run Deep',
#  "Let's Kill Uncle",
#  'Harvest Home',
#  "The French Lieutenant's Woman",
#  'Let the Right One In',
#  'Children of the Corn',
#  'David Copperfield',
#  'The Lottery',
#  'Seven Pillars of Wisdom: A Triumph',
#  'The EC Archives: Tales from the Crypt Volume 1',
#  'The Mutiny on the Bounty Trilogy',
#  'From Here to Eternity',
#  "Where'd You Go, Bernadette",
#  'Raging Bull: My Story',
#  'The Last Temptation of Christ',
#  'In the Woods (Dublin Murder Squad, #1)',
#  'The Likeness (Dublin Murder Squad, #2)',
#  'Shadowlands',
#  'A Taste for Honey',
#  'The Cold Dish (Walt Longmire, #1)',
#  'Bad Ronald',
#  'The Little Girl Who Lives Down the Lane',
#  'The Immigrants (Lavette Family, #1)',
#  'Casting the Runes and Other Ghost Stories',
#  'Novels by Howard Fast',
#  "A Connecticut Yankee in King Arthur's Court",
#  'The Space Vampires',
#  "Lizard's Tail",
#  'The Detective',
#  'Night Of The Big Heat',
#  'The Untouchables',
#  'Witchfinder General',
#  'Vertigo',
#  'Midnight: A Novel of Terror',
#  'Incubus',
#  'Scream and Scream Again',
#  'The Bat']

# %%
len(Book3), len(Book_into_Movie3)
# Out:
# (824, 824)

# %%
book3 = pd.DataFrame({"Name": Book3, "Book_into_Movie": Book_into_Movie3})

# %%
book3.to_excel("Book_into_movie_3.xlsx")

# %% [markdown]
# ### 5.4. Web Scraping which books will be filmed in 2021

# %%
url4= "https://www.popsugar.com.au/entertainment/books-becoming-movies-in-2021-47933926/"

# %%
response4 = requests.get(url4)
response4.status_code
# Out:
# 200

# %%
soup4 = BeautifulSoup(response4.content, "html.parser")
soup4
# Out:
#  <!DOCTYPE html>
#
# <!--[if lt IE 9]><html class="no-js no-svg ie lt-ie9 lt-ie8 lt-ie7" lang="en-AU"> <![endif]-->
# <!--[if IE 9]><html class="no-js no-svg ie ie9 lt-ie9 lt-ie8" lang="en-AU"> <![endif]-->
# <!--[if gt IE 9]><!-->
# <html class="no-js no-svg" lang="en-AU"> <!--<![endif]-->
# <head>
# <noscript>
# <style>
# 					body {
# 						visibility: visible !important;
# 					}
# 				</style>
# </noscript>
# <meta content="35 movies based on books coming to theaters in 2021, including the delayed 2020 film releases." name="description"/>
# <script type="application/ld+json">
# 		{
# 							"@context": "https://schema.org",
# 							"@type": "NewsArticle",
# 							"mainEntityOfPage": "https://www.popsugar.com.au/entertainment/books-becoming-movies-in-2021-47933926",
# 							"headline": "The Complete List of Books Becoming Movies in 2021",
# 					"image": [
# 										"https://www.popsugar.com.au/wp-content/uploads/sites/2/2021/03/4853c969604bbeaf3c2801.88800318_.jpg",
# 							"https://www.popsugar.com.au/wp-content/uploads/sites/2/2021/03/3691d2ad8f01b6c4_81TQpJPgUtL-672x1024.jpg"
# 				,								"https://www.popsugar.com.au/wp-content/uploads/sites/2/2021/03/1bd46639604bbcf682f7e2.45954751_all-things-c-664x1024.jpg"
# 				,								"https://www.popsugar.com.au/wp-content/uploads/sites/2/2021/03/29e86032fdd1fb24_71PVUM-ZRbL-666x1024.jpg"
# 				,								"https://www.popsugar.com.au/wp-content/uploads/sites/2/2021/03/aeccd52cdf764dd8_71rrX1CZRlL-672x1024.jpg"
# 				,								"https://www.popsugar.com.au/wp-content/uploads/sites/2/2021/03/a83bd06ed174b425_91Zgy7oKyqL-640x1024.jpg"
# 				,								"https://www.popsugar.com.au/wp-content/uploads/sites/2/2021/03/2930277960df9f5c_81zp2_DZs3L-659x1024.jpg"
# 				,								"https://www.popsugar.com.au/wp-content/uploads/sites/2/2021/03/686e14390e5ba47b_PS20_12_4_DS_Pinterest_Books_Collage_BooksBecomingMoviesin2021-520x1024.jpg"
# 												],
# 						"datePublished": "19 May 2021",
# 									"dateModified": "23 April 2021",
# 									"author": {
# 										"@type": "Person",
# 										"name": "sabienna bowman"
# 									},
# 									"publisher": {
# 											"@id" : "#POPSUGAROrg"
# 									}
# 								}
# 		</script>
# <script type="text/javascript">
# 			window._taboola = window._taboola || [];
# _taboola.push({article: 'auto'});
# !function (e, f, u, i) {
# if (!document.getElementById(i)) {
# e.async = 1;
# e.src = u;
# e.id = i;
# f.parentNode.insertBefore(e, f);
# }
# }(document.createElement('script'), document.getElementsByTagName('script')[0], '//cdn.taboola.com/libtrc/alluremedia-popsugarau/loader.js', 'tb_loader_script');
# if (window.performance && typeof window.performance.mark == 'function') {
# window.performance.mark('tbl_ic');
# }
# 		</script>
# <meta charset="utf-8">
# <link href="/wp-content/themes/popsugar/dist/main.css" media="screen" rel="stylesheet" type="text/css"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="/wp-content/themes/popsugar/humans.txt" rel="author"/>
# <link href="https://www.popsugar.com.au/xmlrpc.php" rel="pingback"/>
# <link href="https://gmpg.org/xfn/11" rel="profile"/>
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-188637038-1"></script>
# <script>
# 		window.dataLayer = window.dataLayer || [];
# 		function gtag() {
# 		dataLayer.push(arguments);
# 		}
# 		gtag('js', new Date());
# 		gtag('config', 'UA-188637038-1');
# 	</script>
# <script type="application/ld+json">
# 	{
# 		    "@id": "#POPSUGAROrg",
# 		    "@context": "http://schema.org/",
# 		    "@type": "Organization",
# 		    "url": "https://www.popsugar.com.au",
# 		    "logo": {
# 		        "@type": "ImageObject",
# 		        "url": "https://media1.popsugar-assets.com/v4652/themes/onsugar_themes/lightspeed/imgs/logo-new-600.png",
# 		        "width": 600,
# 		        "height": 49
# 		    },
# 		    "name": "POPSUGAR AUSTRALIA",
# 		    "sameAs": [
# 		            "https://twitter.com/popsugarau",
# 		                "https://www.facebook.com/PopSugarAustralia",
# 		                "https://instagram.com/popsugarau",
# 		                "https://www.pinterest.com/popsugarau",
# 		            "https://www.alluremedia.com.au"     ],
# 		    "contactPoint": [
# 		        {
# 		            "@type": "ContactPoint",
# 		            "telephone": "+1-415-391-7576",
# 		            "contactType": "customer service"
# 		        }
# 		    ]
# 		}
# </script>
# <title>The Complete List of Books Becoming Movies in 2021 | POPSUGAR Australia</title>
# <meta content="https://www.popsugar.com.au/entertainment/books-becoming-movies-in-2021-47933926/" property="og:url">
# <meta content="Popsugar" property="og:site_name">
# <meta content="en_AU" property="og:locale"/>
# <meta content="article" property="og:type"/>
# <meta content="https://www.facebook.com/PopSugarAustralia/" property="article:author"/>
# <meta content="https://www.facebook.com/PopSugarAustralia/" property="article:publisher"/>
# <meta content="Celebrity" property="article:section"/>
# <meta content="Books" property="article:tag"/>
# <meta content="Entertainment" property="article:tag"/>
# <meta content="Movies" property="article:tag"/>
# <meta content="The Complete List of Books Becoming Movies in 2021" property="og:title"/>
# <meta content="There’s no denying that 2020 was a difficult year for the movie industry (and everyone else). With theatres closed, a number of films were pushed from their scheduled release dates all the way into the new year. As a result, there’s a huge number of books becoming movies in 2021.…" property="og:description"/>
# <meta content="/wp-content/uploads/sites/2/2021/03/POPSUGAR-SOCIAL-9-3.jpg" property="og:image"/>
# <meta content="/wp-content/uploads/sites/2/2021/03/POPSUGAR-SOCIAL-9-3.jpg" property="og:image:secure_url"/>
# <meta content="1920" property="og:image:width"/>
# <meta content="1080" property="og:image:height"/>
# <meta content="Gal Gadot" property="og:image:alt"/>
# <meta content="142908532409859" property="fb:pages"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="https://twitter.com/POPSUGARau" name="twitter:site"/>
# <meta content="https://twitter.com/POPSUGARau" name="twitter:creator"/>
# <meta content="The Complete List of Books Becoming Movies in 2021" name="twitter:title"/>
# <meta content="There’s no denying that 2020 was a difficult year for the movie industry (and everyone else). With theatres closed, a number of films were pushed from their scheduled release dates all the way into the new year. As a result, there’s a huge number of books becoming movies in 2021.…" name="twitter:description"/>
# <meta content="/wp-content/uploads/sites/2/2021/03/POPSUGAR-SOCIAL-9-3.jpg" name="twitter:image"/>
# <link href="//s.w.org" rel="dns-prefetch">
# <link href="https://www.popsugar.com.au/feed/" rel="alternate" title="Popsugar » Feed" type="application/rss+xml"/>
# <link href="https://www.popsugar.com.au/comments/feed/" rel="alternate" title="Popsugar » Comments Feed" type="application/rss+xml"/>
# <link href="https://www.popsugar.com.au/entertainment/books-becoming-movies-in-2021-47933926/feed/" rel="alternate" title="Popsugar » The Complete List of Books Becoming Movies in 2021 Comments Feed" type="application/rss+xml"/>
# <script type="text/javascript">
# 			window._wpemojiSettings = {"baseUrl":"https:\/\/s.w.org\/images\/core\/emoji\/13.0.0\/72x72\/","ext":".png","svgUrl":"https:\/\/s.w.org\/images\/core\/emoji\/13.0.0\/svg\/","svgExt":".svg","source":{"concatemoji":"https:\/\/www.popsugar.com.au\/wp-includes\/js\/wp-emoji-release.min.js?ver=5.5.3"}};
# 			!function(e,a,t){var r,n,o,i,p=a.createElement("canvas"),s=p.getContext&&p.getContext("2d");function c(e,t){var a=String.fromCharCode;s.clearRect(0,0,p.width,p.height),s.fillText(a.apply(this,e),0,0);var r=p.toDataURL();return s.clearRect(0,0,p.width,p.height),s.fillText(a.apply(this,t),0,0),r===p.toDataURL()}function l(e){if(!s||!s.fillText)return!1;switch(s.textBaseline="top",s.font="600 32px Arial",e){case"flag":return!c([127987,65039,8205,9895,65039],[127987,65039,8203,9895,65039])&&(!c([55356,56826,55356,56819],[55356,56826,8203,55356,56819])&&!c([55356,57332,56128,56423,56128,56418,56128,56421,56128,56430,56128,56423,56128,56447],[55356,57332,8203,56128,56423,8203,56128,56418,8203,56128,56421,8203,56128,56430,8203,56128,56423,8203,56128,56447]));case"emoji":return!c([55357,56424,8205,55356,57212],[55357,56424,8203,55356,57212])}return!1}function d(e){var t=a.createElement("script");t.src=e,t.defer=t.type="text/javascript",a.getElementsByTagName("head")[0].appendChild(t)}for(i=Array("flag","emoji"),t.supports={everything:!0,everythingExceptFlag:!0},o=0;o<i.length;o++)t.supports[i[o]]=l(i[o]),t.supports.everything=t.supports.everything&&t.supports[i[o]],"flag"!==i[o]&&(t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&t.supports[i[o]]);t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&!t.supports.flag,t.DOMReady=!1,t.readyCallback=function(){t.DOMReady=!0},t.supports.everything||(n=function(){t.readyCallback()},a.addEventListener?(a.addEventListener("DOMContentLoaded",n,!1),e.addEventListener("load",n,!1)):(e.attachEvent("onload",n),a.attachEvent("onreadystatechange",function(){"complete"===a.readyState&&t.readyCallback()})),(r=t.source||{}).concatemoji?d(r.concatemoji):r.wpemoji&&r.twemoji&&(d(r.twemoji),d(r.wpemoji)))}(window,document,window._wpemojiSettings);
# 		</script>
# <style type="text/css">
# img.wp-smiley,
# img.emoji {
# 	display: inline !important;
# 	border: none !important;
# 	box-shadow: none !important;
# 	height: 1em !important;
# 	width: 1em !important;
# 	margin: 0 .07em !important;
# 	vertical-align: -0.1em !important;
# 	background: none !important;
# 	padding: 0 !important;
# }
# </style>
# <link href="https://www.popsugar.com.au/wp-includes/css/dist/block-library/style.min.css?ver=5.5.3" id="wp-block-library-css" media="all" rel="stylesheet" type="text/css"/>
# <script id="jquery-core-js" src="https://www.popsugar.com.au/wp-includes/js/jquery/jquery.js?ver=1.12.4-wp" type="text/javascript"></script>
# <link href="https://www.popsugar.com.au/wp-json/" rel="https://api.w.org/"/><link href="https://www.popsugar.com.au/wp-json/wp/v2/posts/62585" rel="alternate" type="application/json"/><link href="https://www.popsugar.com.au/xmlrpc.php?rsd" rel="EditURI" title="RSD" type="application/rsd+xml"/>
# <link href="https://www.popsugar.com.au/wp-includes/wlwmanifest.xml" rel="wlwmanifest" type="application/wlwmanifest+xml"/>
# <link href="https://www.popsugar.com.au/celebrity/how-to-apply-for-sas-australia/" rel="prev" title="Have You Got What It Takes? Here’s How to Apply for SAS Australia"/>
# <link href="https://www.popsugar.com.au/beauty/aceology-hydra-dermabrasion-facial-device-review/" rel="next" title="The Hydra-Dermabrasion Device That Gives You a Spa Experience At Home"/>
# <meta content="WordPress 5.5.3" name="generator"/>
# <link href="https://www.popsugar.com.au/?p=62585" rel="shortlink"/>
# <link href="https://www.popsugar.com.au/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fwww.popsugar.com.au%2Fentertainment%2Fbooks-becoming-movies-in-2021-47933926" rel="alternate" type="application/json+oembed"/>
# <link href="https://www.popsugar.com.au/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fwww.popsugar.com.au%2Fentertainment%2Fbooks-becoming-movies-in-2021-47933926&amp;format=xml" rel="alternate" type="text/xml+oembed"/>
# <link href="https://www.popsugar.com.au/entertainment/books-becoming-movies-in-2021-47933926" rel="canonical"/><link href="https://www.popsugar.com/entertainment/books-becoming-movies-in-2021-47933926" hreflang="en-us" rel="alternate"/><link href="https://www.popsugar.com.au/entertainment/books-becoming-movies-in-2021-47933926" hreflang="en-au" rel="alternate"/><link href="https://www.popsugar.co.uk/celebrity/books-becoming-films-in-2021-47968488" hreflang="en-gb" rel="alternate"/><link href="https://www.popsugar.com.au/entertainment/books-becoming-movies-in-2021-47933926" hreflang="x-default" rel="alternate"/><meta content="Feed to Post 3.13.4" name="generator"/>
# <meta content="wordpress-plugin" name="onesignal"/>
# <script>
#
#       window.OneSignal = window.OneSignal || [];
#
#       OneSignal.push( function() {
#         OneSignal.SERVICE_WORKER_UPDATER_PATH = "OneSignalSDKUpdaterWorker.js.php";
#         OneSignal.SERVICE_WORKER_PATH = "OneSignalSDKWorker.js.php";
#         OneSignal.SERVICE_WORKER_PARAM = { scope: '/' };
#
#         OneSignal.setDefaultNotificationUrl("https://www.popsugar.com.au");
#         var oneSignal_options = {};
#         window._oneSignalInitOptions = oneSignal_options;
#
#         oneSignal_options['wordpress'] = true;
# oneSignal_options['appId'] = 'f810fb33-4938-457e-ac38-8c3843b54b04';
# oneSignal_options['welcomeNotification'] = { };
# oneSignal_options['welcomeNotification']['title'] = "";
# oneSignal_options['welcomeNotification']['message'] = "";
# oneSignal_options['path'] = "/wp-content/plugins/onesignal-free-web-push-notifications/sdk_files/";
# oneSignal_options['safari_web_id'] = "web.onesignal.auto.3fd215f3-eebf-45ec-a840-b342bc8d8df9";
# oneSignal_options['promptOptions'] = { };
# oneSignal_options['notifyButton'] = { };
# oneSignal_options['notifyButton']['enable'] = true;
# oneSignal_options['notifyButton']['position'] = 'bottom-right';
# oneSignal_options['notifyButton']['theme'] = 'inverse';
# oneSignal_options['notifyButton']['size'] = 'medium';
# oneSignal_options['notifyButton']['showCredit'] = true;
# oneSignal_options['notifyButton']['text'] = {};
#                 OneSignal.init(window._oneSignalInitOptions);
#                 OneSignal.showSlidedownPrompt();      });
#
#       function documentInitOneSignal() {
#         var oneSignal_elements = document.getElementsByClassName("OneSignal-prompt");
#
#         var oneSignalLinkClickHandler = function(event) { OneSignal.push(['registerForPushNotifications']); event.preventDefault(); };        for(var i = 0; i < oneSignal_elements.length; i++)
#           oneSignal_elements[i].addEventListener('click', oneSignalLinkClickHandler, false);
#       }
#
#       if (document.readyState === 'complete') {
#            documentInitOneSignal();
#       }
#       else {
#            window.addEventListener("load", function(event){
#                documentInitOneSignal();
#           });
#       }
#     </script>
# <!-- There is no amphtml version available for this URL. --><link href="/wp-content/uploads/sites/2/2021/01/favicon.png" rel="icon" sizes="32x32">
# <link href="/wp-content/uploads/sites/2/2021/01/favicon.png" rel="icon" sizes="192x192">
# <link href="/wp-content/uploads/sites/2/2021/01/favicon.png" rel="apple-touch-icon">
# <meta content="/wp-content/uploads/sites/2/2021/01/favicon.png" name="msapplication-TileImage"/>
# <style id="wp-custom-css" type="text/css">
# 			.postid-82675 #taboola-below-article-thumbnails, .postid-74495 #taboola-below-article-thumbnails, .postid-72524 #taboola-below-article-thumbnails, .postid-67360 #taboola-below-article-thumbnails { display: none; }
#
# .postid-82675 .section-heading.centered.mt-md.mb-md, .postid-74495 .section-heading.centered.mt-md.mb-md, .postid-72524 .section-heading.centered.mt-md.mb-md, .postid-67360 .section-heading.centered.mt-md.mb-md { display: none; }		</style>
# <style>
# .ai-viewports                 {--ai: 1;}
# .ai-viewport-3                { display: none !important;}
# .ai-viewport-2                { display: none !important;}
# .ai-viewport-1                { display: inherit !important;}
# .ai-viewport-0                { display: none !important;}
# @media (min-width: 768px) and (max-width: 979px) {
# .ai-viewport-1                { display: none !important;}
# .ai-viewport-2                { display: inherit !important;}
# }
# @media (max-width: 767px) {
# .ai-viewport-1                { display: none !important;}
# .ai-viewport-3                { display: inherit !important;}
# }
# </style>
# <!-- Start: GPT header script -->
# <!-- GAM targeting variables -->
# <script type="text/javascript"> window.gamData = {
# "gamKV": {
# "pagetype": "article",
# "site": "popsugar",
# "section": "celebrity",
# "tags" : "Books, Entertainment, Movies",
# "sponsored" : "no",
# "brand" : "NULL",
# "safecontent" : "yes"
# }
# }
# 	</script>
# <script async="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js?1254580013"></script>
# <script>
# 		window.googletag = window.googletag || {
# cmd: []
# };
# googletag.cmd.push(function () { // Extract article title from url
# getPageURL = window.location.pathname;
# pageURLArray = getPageURL.split('/');
# pageURL = '';
# while (pageURLArray.length > 0 && pageURL == '') {
# pageURL = pageURLArray.pop();
# }
#
# // Set page-level key-values and GPT settings
# googletag.pubads().setTargeting('title', [pageURL]);
# if (window.gamData.gamKV) {
# Object.keys(window.gamData.gamKV).forEach(function (key) {
# googletag.pubads().setTargeting(key, window.gamData.gamKV[key]);
# });
# }
# googletag.pubads().setCentering(true);
# googletag.pubads().collapseEmptyDivs();
# googletag.pubads().enableLazyLoad({fetchMarginPercent: 50, renderMarginPercent: 0, mobileScaling: 2.0});
# googletag.enableServices();
# });
# 	</script>
# <!-- End: GPT header script -->
# </link></link></link></link></meta></meta></meta></head>
# <body class="post-template-default single single-post postid-62585 single-format-standard" data-rsssl="1" data-template="base.twig" style="visibility: hidden;">
# <main>
# <div class="network-navigation-wrapper">
# <div class="network-nav-cta js-network-nav-cta">
# <img alt="valmorgan Logo" class="valmorgan-custom-logo" src="/wp-content/themes/popsugar/src/images/valmorgan-logo.png" width="160"/>
# <span class="arrow-down"></span>
# </div>
# <div class="network-nav-menu-wrapper js-network-nav-menu-wrapper">
# <ul class="network-nav-menu js-network-nav-menu">
# <li class="link-item">
# <a class="link menu-item menu-item-type-custom menu-item-object-custom menu-item-home menu-item-56447" href="https://www.popsugar.com.au/" target="_blank">Popsugar</a>
# </li>
# <li class="link-item">
# <a class="link menu-item menu-item-type-custom menu-item-object-custom menu-item-56448" href="https://thelatch.com.au/" target="_blank">The Latch</a>
# </li>
# <li class="link-item">
# <a class="link menu-item menu-item-type-custom menu-item-object-custom menu-item-56449" href="https://www.thrillist.com.au/" target="_blank">Thrillist</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="overlay"></div>
# <div class="main-nav compact">
# <div class="top">
# <div class="container">
# <div class="bottom">
# <div class="left">
# <div class="desktop-side-menu-btn js-desktop-side-menu-btn">
# <div class="lines">
# <div class="line"></div>
# <div class="line"></div>
# <div class="line"></div>
# </div>
# </div>
# <div class="logo">
# <a href="/">
# <img alt="popsugar logo" src="/wp-content/themes/popsugar/src/images/logo.svg">
# </img></a>
# </div>
# <div class="category">
# <a href="https://www.popsugar.com.au/celebrity/">
# 								Celebrity
# 							</a>
# </div>
# </div>
# <div class="right">
# <div class="social-icons">
# <a class="icon-facebook" href="https://www.facebook.com/PopSugarAustralia" target="_blank"></a>
# <a class="icon-instagram" href="https://www.instagram.com/POPSUGARau" target="_blank"></a>
# </div>
# <div class="search-wrapper">
# <button class="btn-search js-btn-search"></button>
# <div class="search-box js-search-box">
# <form action="search" class="js-search-submit" method="post">
# <i class="icon icon-search"></i>
# <input autocomplete="off" class="js-input-search" name="query" placeholder="Search..." spellcheck="false" type="search"/>
# <span class="btn-close small js-btn-close-search"></span>
# </form>
# <div class="suggestions js-suggestions"></div>
# </div>
# </div>
# <div class="mobile-menu-btn js-mobile-menu-btn">
# <div class="lines">
# <div class="line"></div>
# <div class="line"></div>
# <div class="line"></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="post-info js-post-info">
# <div class="left">
# <div class="icon-popsugar"></div>
# <div class="title">
# 				The Complete List of Books Becoming Movies in 2021
# 			</div>
# </div>
# <div class="right">
# <div class="social-icons">
# <a class="icon-facebook social-icon with-background js-facebook-share" data-url="https://www.popsugar.com.au/entertainment/books-becoming-movies-in-2021-47933926" href="#" target="_blank"></a>
# <a class="icon-pinterest social-icon with-background" data-pin-custom="true" data-pin-do="buttonBookmark" href="https://www.pinterest.com/pin/create/button/" target="_blank"></a>
# <a class="icon-envelope-o social-icon with-background" href="mailto:?body=https%3A%2F%2Fwww.popsugar.com.au%2Fentertainment%2Fbooks-becoming-movies-in-2021-47933926%3Futm_campaign%3Ddesktop_share%26utm_medium%3Demail%26utm_source%3Daupop&amp;subject=The Complete List of Books Becoming Movies in 2021" target="_blank"></a>
# <a class="js-flipboard-share icon-flipboard social-icon with-background" data-flip-widget="shareflip" data-title="The Complete List of Books Becoming Movies in 2021" data-url="https%3A%2F%2Fwww.popsugar.com.au%2Fentertainment%2Fbooks-becoming-movies-in-2021-47933926" href="#" target="_blank"></a>
# <a class="icon-twitter social-icon with-background js-twitter-share" data-url="https://www.popsugar.com.au/entertainment/books-becoming-movies-in-2021-47933926" href="#" target="_blank"></a>
# </div>
# </div>
# </div>
# </div>
# <section class="content-wrapper" id="content" role="main">
# <div class="wrapper">
# <div class="code-block code-block-7" style="margin: 8px 0; clear: both;">
# <div id="gam_banner_pos1">
# <script type="text/javascript">
#     googletag.cmd.push(function() {
#       var map_banner = googletag.sizeMapping()
#           .addSize([1000, 0], [[970, 250],[728, 90],[970, 90]])
#           .addSize([768, 0], [728, 90])
#           .addSize([0, 0], [[300, 250],[320, 50]]).build();
#      googletag.defineSlot('/22219324693/popsugar/banner1', [[970, 250],[728, 90],[970, 90],[300, 250],[320, 50]],'gam_banner_pos1')
#           .defineSizeMapping(map_banner)
#           .setTargeting('pos', 'banner1')
#           .addService(googletag.pubads());
#      googletag.display('gam_banner_pos1');
#     });
#    </script>
# </div></div>
# <div class="container">
# <div class="article-detail">
# <div class="two-col-section">
# <div class="left">
# <article class="article--content">
# <div class="breadcrumbs">
# <ul>
# <li class="site-title">
# <a href="/">Popsugar</a>
# </li>
# <li>
# <a href="https://www.popsugar.com.au/celebrity/">
# 											Celebrity
# 										</a>
# </li>
# <li>
# 										The Complete List of Books Becoming Movies in 2021
# 									</li>
# </ul>
# </div>
# <h1 class="title">
# 								The Complete List of Books Becoming Movies in 2021
# 							</h1>
# <div class="post-meta">
# <div class="author-wrapper">
# <div class="author-image">
# <img alt="Image of sabienna bowman" src="https://www.popsugar.com.au/wp-content/uploads/sites/2/2021/02/user-placeholder-150x150.png"/>
# </div>
# <div class="details">
# <time class="published-date">
# 											25 March, 2021
# 										</time>
# <div class="article--author">
# <span class="by">by</span>
# <a href="https://www.popsugar.com.au/author/sabienna-bowman/">sabienna bowman</a>
# </div>
# </div>
# </div>
# <!-- Go to www.addthis.com/dashboard to customize your tools -->
# <div class="addthis_inline_share_toolbox"></div>
# </div>
# <div class="one-page-view">
# <div class="slideshow-wrapper js-post-slideshow">
# <div class="article-content--image js-hide-on-slideshow">
# <img alt="" src="/wp-content/uploads/sites/2/2021/03/4853c969604bbeaf3c2801.88800318_.jpg"/>
# <div class="social-icons-row">
# <a class="icon-facebook social-icon with-background js-facebook-share" data-url="https://www.popsugar.com.au/entertainment/books-becoming-movies-in-2021-47933926" href="#" target="_blank"></a>
# <a class="icon-pinterest social-icon with-background" data-pin-custom="true" data-pin-do="buttonBookmark" data-pin-media="/wp-content/uploads/sites/2/2021/03/4853c969604bbeaf3c2801.88800318_.jpg" href="https://www.pinterest.com/pin/create/button/" target="_blank"></a>
# </div>
# </div>
# <div class="bottom-slideshow-controls js-hide-on-slideshow">
# <span class="credit">
# 					Everett Collection / 20th Century Studios/Courtesy Everett Collection
# 				</span>
# </div>
# <div class="slide-wrapper">
# <div class="slide hidden js-slideshow-slide js-show-on-slideshow" data-iteration="1">
# <div class="slideshow-image-wrapper">
# <img alt="Everett" class="js-slideshow-image" collection="" src="/wp-content/uploads/sites/2/2021/03/3691d2ad8f01b6c4_81TQpJPgUtL-672x1024.jpg">
# <div class="social-icons-row">
# <a class="icon-facebook social-icon with-background js-facebook-share" data-url="https://www.popsugar.com.au/entertainment/books-becoming-movies-in-2021-47933926" href="#" target="_blank"></a>
# <a class="icon-pinterest social-icon with-background" data-pin-custom="true" data-pin-do="buttonBookmark" data-pin-media="Array" href="https://www.pinterest.com/pin/create/button/" target="_blank"></a>
# </div>
# </img></div>
# <div class="bottom-slideshow-controls">
# <span class="credit">
# 							Everett Collection
# 						</span>
# </div>
# <div class="slide-details-wrapper">
# <h2 class="slide-title">
# 							The White Tiger by Aravind Adiga
# 						</h2>
# <div class="body-wrap">
# <div class="slide-body">
# <ul>
# <li><strong>What it’s about:</strong> Aravind Adiga is a sweeping tale that explores class and privilege in India through the eyes of a poor villager who becomes a savvy businessman.</li>
# <li><strong>Who’s starring:</strong> Adarsh Gourav, Rajkummar Rao, and Priyanka Chopra</li>
# <li>Watch the trailer for <a class="ga-track" data-ga-action="body text link" data-ga-category="internal click" data-ga-label="https://www.youtube.com/watch?v=35jJNyFuYKQ" href="https://www.youtube.com/watch?v=35jJNyFuYKQ" rel="noopener" target="_blank"><strong>The White Tiger</strong></a>.</li>
# <li>Read <a class="ga-track" data-ga-action="body text link" data-ga-category="internal click" data-ga-label="https://www.amazon.com/White-Tiger-Novel-Aravind-Adiga/dp/1416562605/" href="https://www.amazon.com/White-Tiger-Novel-Aravind-Adiga/dp/1416562605/" rel="noopener" target="_blank"><strong>The White Tiger</strong></a>.</li>
# <li><strong>Release date:</strong> Jan. 22</li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="slide hidden js-slideshow-slide js-show-on-slideshow" data-iteration="2">
# <div class="slideshow-image-wrapper">
# <img alt="Everett" class="js-slideshow-image" collection="" src="/wp-content/uploads/sites/2/2021/03/1bd46639604bbcf682f7e2.45954751_all-things-c-664x1024.jpg">
# <div class="social-icons-row">
# <a class="icon-facebook social-icon with-background js-facebook-share" data-url="https://www.popsugar.com.au/entertainment/books-becoming-movies-in-2021-47933926" href="#" target="_blank"></a>
# <a class="icon-pinterest social-icon with-background" data-pin-custom="true" data-pin-do="buttonBookmark" data-pin-media="Array" href="https://www.pinterest.com/pin/create/button/" target="_blank"></a>
# </div>
# </img></div>
# <div class="bottom-slideshow-controls">
# <span class="credit">
# 							Everett Collection
# 						</span>
# </div>
# <div class="slide-details-wrapper">
# <h2 class="slide-title">
# 							All Things Cease to Appear by Elizabeth Brundage
# 						</h2>
# <div class="body-wrap">
# <div class="slide-body">
# <ul>
# <li><strong>What it’s about:</strong> A professor finds his wife slain, his young daughter untouched across the hall. Set in a small town in New York, <strong>All Things Cease to Appear</strong> (movie title: <strong>Things Heard &amp; Seen</strong>) is a murder mystery, a marriage thriller, and a character study all wrapped in one.</li>
# <li><strong>Who’s starring:</strong> <a class="sugar-inline-link ga-track" data-ga-action="body text link" data-ga-category="internal click" data-ga-label="https://www.popsugar.com/Amanda-Seyfried" href="https://www.popsugar.com/Amanda-Seyfried" rel="noopener" target="_blank" title="Latest photos and news for Amanda Seyfried">Amanda Seyfried</a>, Natalia Dyer, and Karen Allen</li>
# <li>Read <a class="ga-track" data-ga-action="body text link" data-ga-category="internal click" data-ga-label="https://www.amazon.com/Things-Cease-Appear-Elizabeth-Brundage/dp/1101911484/" href="https://www.amazon.com/Things-Cease-Appear-Elizabeth-Brundage/dp/1101911484/" rel="noopener" target="_blank"><strong>All Things Cease to Appear</strong></a>.</li>
# <li><strong>Release date:</strong> April 30</li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="slide hidden js-slideshow-slide js-show-on-slideshow" data-iteration="3">
# <div class="slideshow-image-wrapper">
# <img alt="Everett" class="js-slideshow-image" collection="" src="/wp-content/uploads/sites/2/2021/03/29e86032fdd1fb24_71PVUM-ZRbL-666x1024.jpg"/>
# <div class="social-icons-row">
# <a class="icon-facebook social-icon with-background js-facebook-share" data-url="https://www.popsugar.com.au/entertainment/books-becoming-movies-in-2021-47933926" href="#" target="_blank"></a>
# <a class="icon-pinterest social-icon with-background" data-pin-custom="true" data-pin-do="buttonBookmark" data-pin-media="Array" href="https://www.pinterest.com/pin/create/button/" target="_blank"></a>
# </div>
# </div>
# <div class="bottom-slideshow-controls">
# <span class="credit">
# 							Everett Collection
# 						</span>
# </div>
# <div class="slide-details-wrapper">
# <h2 class="slide-title">
# 							Those Who Wish Me Dead by Michael Koryta
# 						</h2>
# <div class="body-wrap">
# <div class="slide-body">
# <ul>
# <li><strong>What it’s about:</strong> This tense thriller opens with a young man witnessing a murder. He must run for his life while a forest fire rages, threatening his safety at every turn.</li>
# <li><strong>Who’s starring:</strong> <a class="sugar-inline-link ga-track" data-ga-action="body text link" data-ga-category="internal click" data-ga-label="https://www.popsugar.com/Angelina-Jolie" href="https://www.popsugar.com/Angelina-Jolie" rel="noopener" target="_blank" title="Latest photos and news for Angelina Jolie">Angelina Jolie</a>, Nicholas Hoult, and Jon Bernthal</li>
# <li>Read <a class="ga-track" data-ga-action="body text link" data-ga-category="internal click" data-ga-label="https://www.amazon.com/Those-Who-Wish-Me-Dead-ebook/dp/B00FPQA76Q/" href="https://www.amazon.com/Those-Who-Wish-Me-Dead-ebook/dp/B00FPQA76Q/" rel="noopener" target="_blank"><strong>Those Who Wish Me Dead</strong></a>.</li>
# <li><strong>Release date:</strong> May 14</li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="slide hidden js-slideshow-slide js-show-on-slideshow" data-iteration="4">
# <div class="slideshow-image-wrapper">
# <img alt="Everett" class="js-slideshow-image" collection="" src="/wp-content/uploads/sites/2/2021/03/aeccd52cdf764dd8_71rrX1CZRlL-672x1024.jpg"/>
# <div class="social-icons-row">
# <a class="icon-facebook social-icon with-background js-facebook-share" data-url="https://www.popsugar.com.au/entertainment/books-becoming-movies-in-2021-47933926" href="#" target="_blank"></a>
# <a class="icon-pinterest social-icon with-background" data-pin-custom="true" data-pin-do="buttonBookmark" data-pin-media="Array" href="https://www.pinterest.com/pin/create/button/" target="_blank"></a>
# </div>
# </div>
# <div class="bottom-slideshow-controls">
# <span class="credit">
# 							Everett Collection
# 						</span>
# </div>
# <div class="slide-details-wrapper">
# <h2 class="slide-title">
# 							Death on the Nile by Agatha Christie
# 						</h2>
# <div class="body-wrap">
# <div class="slide-body">
# <ul>
# <li><strong>What it’s about:</strong> Detective Hercule Poirot is back on the case when a woman is murdered on a luxurious cruise down the Nile River.</li>
# <li><strong>Who’s starring:</strong> Gal Gadot, Rose Leslie, Emma Mackey</li>
# <li>Watch the trailer for <a class="ga-track" data-ga-action="body text link" data-ga-category="internal click" data-ga-label="https://www.youtube.com/watch?v=JM1U-Whb-P0" href="https://www.youtube.com/watch?v=JM1U-Whb-P0" rel="noopener" target="_blank"><strong>Death on the Nile</strong></a>.</li>
# <li>Read <a class="ga-track" data-ga-action="body text link" data-ga-category="internal click" data-ga-label="https://www.amazon.com/Death-Nile-Hercule-Mystery-Mysteries/dp/0062073559/" href="https://www.amazon.com/Death-Nile-Hercule-Mystery-Mysteries/dp/0062073559/" rel="noopener" target="_blank"><strong>Death on the Nile</strong></a>.</li>
# <li><strong>Release date:</strong> Sept 17</li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="slide hidden js-slideshow-slide js-show-on-slideshow" data-iteration="5">
# <div class="slideshow-image-wrapper">
# <img alt="Everett" class="js-slideshow-image" collection="" src="/wp-content/uploads/sites/2/2021/03/a83bd06ed174b425_91Zgy7oKyqL-640x1024.jpg"/>
# <div class="social-icons-row">
# <a class="icon-facebook social-icon with-background js-facebook-share" data-url="https://www.popsugar.com.au/entertainment/books-becoming-movies-in-2021-47933926" href="#" target="_blank"></a>
# <a class="icon-pinterest social-icon with-background" data-pin-custom="true" data-pin-do="buttonBookmark" data-pin-media="Array" href="https://www.pinterest.com/pin/create/button/" target="_blank"></a>
# </div>
# </div>
# <div class="bottom-slideshow-controls">
# <span class="credit">
# 							Everett Collection
# 						</span>
# </div>
# <div class="slide-details-wrapper">
# <h2 class="slide-title">
# 							Nightmare Alley by William Lindsay Gresham
# 						</h2>
# <div class="body-wrap">
# <div class="slide-body">
# <ul>
# <li><strong>What it’s about:</strong> This dark novel takes place in the world of sideshows. One young carnival worker has a penchant for manipulation and when he meets his match, the two use their talents to swindle those who have come to pity and laugh at them.</li>
# <li><strong>Who’s starring:</strong> <a class="sugar-inline-link ga-track" data-ga-action="body text link" data-ga-category="internal click" data-ga-label="https://www.popsugar.com/Bradley-Cooper" href="https://www.popsugar.com/Bradley-Cooper" rel="noopener" target="_blank" title="Latest photos and news for Bradley Cooper">Bradley Cooper</a>, <a class="sugar-inline-link ga-track" data-ga-action="body text link" data-ga-category="internal click" data-ga-label="https://www.popsugar.com/Cate-Blanchett" href="https://www.popsugar.com/Cate-Blanchett" rel="noopener" target="_blank" title="Latest photos and news for Cate Blanchett">Cate Blanchett</a>, and Rooney Mara</li>
# <li>Read <a class="ga-track" data-ga-action="body text link" data-ga-category="internal click" data-ga-label="https://www.amazon.com/Nightmare-Alley-Review-Books-Classics/dp/1590173481/" href="https://www.amazon.com/Nightmare-Alley-Review-Books-Classics/dp/1590173481/" rel="noopener" target="_blank"><strong>Nightmare Alley</strong></a>.</li>
# <li><strong>Release date:</strong> Dec 3</li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="slide hidden js-slideshow-slide js-show-on-slideshow" data-iteration="6">
# <div class="slideshow-image-wrapper">
# <img alt="Everett" class="js-slideshow-image" collection="" src="/wp-content/uploads/sites/2/2021/03/2930277960df9f5c_81zp2_DZs3L-659x1024.jpg"/>
# <div class="social-icons-row">
# <a class="icon-facebook social-icon with-background js-facebook-share" data-url="https://www.popsugar.com.au/entertainment/books-becoming-movies-in-2021-47933926" href="#" target="_blank"></a>
# <a class="icon-pinterest social-icon with-background" data-pin-custom="true" data-pin-do="buttonBookmark" data-pin-media="Array" href="https://www.pinterest.com/pin/create/button/" target="_blank"></a>
# </div>
# </div>
# <div class="bottom-slideshow-controls">
# <span class="credit">
# 							Everett Collection
# 						</span>
# </div>
# <div class="slide-details-wrapper">
# <h2 class="slide-title">
# 							After We Fell by Anna Todd
# 						</h2>
# <div class="body-wrap">
# <div class="slide-body">
# <ul>
# <li><strong>What it’s about:</strong> Tessa and Hardin just cannot get it together in the third book of Anna Todd’s After series. If you enjoyed <strong>Fifty Shades of Grey</strong> and haven’t dipped into this sexy franchise, it’s time.</li>
# <li><strong>Who’s starring:</strong> Josephine Langford and Hero Fiennes Tiffin</li>
# <li>Watch the trailer for <a class="ga-track" data-ga-action="body text link" data-ga-category="internal click" data-ga-label="https://www.youtube.com/watch?v=HXziHr0QfFQ" href="https://www.youtube.com/watch?v=HXziHr0QfFQ" rel="noopener" target="_blank">After We Fell</a>.</li>
# <li>Read <a class="ga-track" data-ga-action="body text link" data-ga-category="internal click" data-ga-label="https://www.amazon.com/After-We-Fell-Anna-Todd/dp/147679250X" href="https://www.amazon.com/After-We-Fell-Anna-Todd/dp/147679250X" rel="noopener" target="_blank"><strong>After We Fell</strong></a>.</li>
# <li><strong>Release date:</strong> TBA</li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="slide hidden js-slideshow-slide js-show-on-slideshow" data-iteration="7">
# <div class="slideshow-image-wrapper">
# <img alt="Everett" class="js-slideshow-image" collection="" src="/wp-content/uploads/sites/2/2021/03/686e14390e5ba47b_PS20_12_4_DS_Pinterest_Books_Collage_BooksBecomingMoviesin2021-520x1024.jpg"/>
# <div class="social-icons-row">
# <a class="icon-facebook social-icon with-background js-facebook-share" data-url="https://www.popsugar.com.au/entertainment/books-becoming-movies-in-2021-47933926" href="#" target="_blank"></a>
# <a class="icon-pinterest social-icon with-background" data-pin-custom="true" data-pin-do="buttonBookmark" data-pin-media="Array" href="https://www.pinterest.com/pin/create/button/" target="_blank"></a>
# </div>
# </div>
# <div class="bottom-slideshow-controls">
# <span class="credit">
# 							Everett Collection
# 						</span>
# </div>
# <div class="slide-details-wrapper">
# <h2 class="slide-title">
# </h2>
# <div class="body-wrap">
# <div class="slide-body">
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="js-hide-on-slideshow">
# <p>There’s no denying that 2020 was a difficult year for the movie industry (and everyone else). With theatres closed, a number of films were pushed from their scheduled release dates all the way into the new year. As a result, there’s a huge number of books becoming movies in 2021. (Then again, a few adaptations that were scheduled for release this year – <strong>Marry Me</strong>, <strong>The Nightingale</strong>, <strong>The Stars at Noon</strong> have sadly been pushed to 2022.) From the long-awaited release of director Denis Villeneuve’s take on Frank Herbert’s <strong>Dune</strong> to the highly anticipated conclusion of Hannah Todd’s After series, readers have an exciting year ahead of them.</p><div class="code-block code-block-11 ai-viewport-2 ai-viewport-3" style="">
# <div id="gam_inarticle_mrec5">
# <script type="text/javascript">
#   googletag.cmd.push(function() {
#                 var map_banner = googletag.sizeMapping()
#           		.addSize([1006, 0], [0,0])
# 				.addSize([0, 0], [[300, 250],[320, 50]]).build();
#    googletag.defineSlot('/22219324693/popsugar/inarticlemrec', [[300, 250],[320, 50]],'gam_inarticle_mrec5')
#    			  .defineSizeMapping(map_banner)
# 			  .setTargeting('pos', 'inarticlemrec')
# 			  .addService(googletag.pubads());
#    googletag.display('gam_inarticle_mrec5');
#   });
#  </script>
# </div>
# </div>
# <p align="right">– <em>Additional reporting by Maggie Panos</em></p>
# <!-- AI CONTENT END 5 -->
# </div>
# </div>
# </div>
# <div class="social-bar">
# <a class="popsugar-icon-wrapper" href="javascript:history.back()">
# <i class="icon icon-ps-icon-dot"></i>
# </a>
# <a class="js-open-facebook-comments join-the-convo-cta" href="#comments">
# <span>
# <i class="icon-comments"></i>
# 											Join the conversation
# 										</span>
# </a>
# <div class="social-icons-row">
# <a class="icon-facebook social-icon with-background js-facebook-share" data-url="https://www.popsugar.com.au/entertainment/books-becoming-movies-in-2021-47933926" href="#" target="_blank"></a>
# <a class="icon-pinterest social-icon with-background" data-pin-custom="true" data-pin-do="buttonBookmark" href="https://www.pinterest.com/pin/create/button/" target="_blank"></a>
# <a class="icon-envelope-o social-icon with-background" href="mailto:?body=https%3A%2F%2Fwww.popsugar.com.au%2Fentertainment%2Fbooks-becoming-movies-in-2021-47933926%3Futm_campaign%3Ddesktop_share%26utm_medium%3Demail%26utm_source%3Daupop&amp;subject=The Complete List of Books Becoming Movies in 2021" target="_blank"></a>
# <a class="icon-flipboard social-icon with-background js-flipboard-share" data-title="The Complete List of Books Becoming Movies in 2021" data-url="https%3A%2F%2Fwww.popsugar.com.au%2Fentertainment%2Fbooks-becoming-movies-in-2021-47933926" href="#" target="_blank"></a>
# <a class="icon-twitter social-icon with-background js-twitter-share" data-url="https://www.popsugar.com.au/entertainment/books-becoming-movies-in-2021-47933926" href="#" target="_blank"></a>
# </div>
# </div>
# <div class="tags">
# <a href="https://www.popsugar.com.au/tag/books/">Books</a>
# <a href="https://www.popsugar.com.au/tag/entertainment/">Entertainment</a>
# <a href="https://www.popsugar.com.au/tag/movies/">Movies</a>
# </div>
# </article>
# </div>
# <div class="sidebar">
# <div class="sidebar-social-widget">
# <!-- Begin Mailchimp Signup Form -->
# <div class="mailchimp-newsletter-form-wrapper" id="mc_embed_signup">
# <span class="btn-close small js-btn-close-newsletter-form"></span>
# <form action="https://popsugar.us5.list-manage.com/subscribe/post?u=e8e187589fa726aac28fe1fa5&amp;id=bdebf57f23" class="validate" id="mc-embedded-subscribe-form" method="post" name="mc-embedded-subscribe-form" novalidate="" target="_blank">
# <input name="u" type="hidden" value="e8e187589fa726aac28fe1fa5"/>
# <input name="id" type="hidden" value="bdebf57f23"/>
# <div id="mc_embed_signup_scroll">
# <h2>Want More?</h2>
# <h3>POPSUGAR AUSTRALIA RIGHT IN YOUR INBOX</h3>
# <div class="mc-field-group">
# <input class="required email" id="mce-EMAIL" name="EMAIL" placeholder="Enter Email..." type="email" value=""/>
# </div>
# <div class="clear" id="mce-responses">
# <div class="response" id="mce-error-response" style="display:none"></div>
# <div class="response" id="mce-success-response" style="display:none"></div>
# </div>
# <!-- real people should not fill this in and expect good things - do not remove this or risk form bot signups-->
# <div aria-hidden="true" style="position: absolute; left: -5000px;">
# <input name="b_35c7ba5b4da1779b7fdf38202_cf1a36547d" tabindex="-1" type="text" value=""/>
# </div>
# <p class="legal-text">
# 				By signing up, I agree to the
# 				<a class="terms-link" href="https://www.alluremedia.com.au/terms-privacy-policy" target="_blank">Terms</a>
# 				&amp; to receive emails from POPSUGAR.
# 			</p>
# <div class="clear">
# <input class="button" id="mc-embedded-subscribe" name="subscribe" type="submit" value="Subscribe"/>
# </div>
# <div class="social-wrapper">
# <h3>FOLLOW. LIKE. LOVE.</h3>
# <div class="social-icons">
# <a class="icon-facebook social-icon" href="https://www.facebook.com/PopSugarAustralia" target="_blank"></a>
# <a class="icon-instagram social-icon" href="https://www.instagram.com/POPSUGARau" target="_blank"></a>
# <a class="icon-flipboard social-icon" href="https://flipboard.com/@popsugarau" target="_blank"></a>
# <a class="icon-pinterest social-icon" href="https://www.pinterest.com.au/popsugarau" target="_blank"></a>
# <a class="icon-twitter social-icon" href="https://twitter.com/POPSUGARau" target="_blank"></a>
# </div>
# </div>
# <div class="clear" id="mce-responses">
# <div class="response" id="mce-error-response" style="display:none"></div>
# <div class="response" id="mce-success-response" style="display:none"></div>
# </div>
# <!-- real people should not fill this in and expect good things - do not remove this or risk form bot signups-->
# <div aria-hidden="true" style="position: absolute; left: -5000px;"><input name="b_e8e187589fa726aac28fe1fa5_bdebf57f23" tabindex="-1" type="text" value=""/></div>
# </div>
# </form>
# </div>
# <script src="//s3.amazonaws.com/downloads.mailchimp.com/js/mc-validate.js" type="text/javascript"></script>
# <script type="text/javascript">
# 	(function ($) {
# window.fnames = new Array();
# window.ftypes = new Array();
# fnames[0] = 'EMAIL';
# ftypes[0] = 'email';
# }(jQuery));
# var $mcj = jQuery.noConflict(true);
# </script>
# <!--End mc_embed_signup-->
# </div>
# <div class="sidebar-ad-container">
# <div class="code-block code-block-8" style="margin: 8px 0; clear: both;">
# <div id="gam_mrec_pos1">
# <script type="text/javascript">
#     googletag.cmd.push(function() {
#                 var map_banner = googletag.sizeMapping()
#                   .addSize([768, 0], [[300, 250],[300, 600]])
#                   .addSize([0, 0], [320, 50]).build();
#      googletag.defineSlot('/22219324693/popsugar/mrec1', [[300, 250],[300, 600],[320, 50]],'gam_mrec_pos1')
#      			  .defineSizeMapping(map_banner)
# 				  .setTargeting('pos', 'mrec1')
# 				  .addService(googletag.pubads());
#      googletag.display('gam_mrec_pos1');
#     });
#    </script>
# </div></div>
# </div>
# </div>
# </div>
# <div class="section-heading centered mt-md mb-md">
# 					From Our Partners
# 				</div>
# <div id="taboola-below-article-thumbnails"></div>
# <script type="text/javascript">
# 					window._taboola = window._taboola || [];
# _taboola.push({mode: 'thumbs-feed-01', container: 'taboola-below-article-thumbnails', placement: 'Below Article Thumbnails', target_type: 'mix'});
# 				</script>
# <div class="section comments" id="comments">
# <div class="fb-comments" data-href="https://www.popsugar.com.au/entertainment/books-becoming-movies-in-2021-47933926" data-numposts="5" data-width=""></div>
# </div>
# <div class="two-col-section">
# <div class="left">
# <div class="article-grid-wrapper related-posts">
# <div class="section-heading centered mt-md mb-md">
# 								Related Posts
# 							</div>
# <div class="article-grid related-posts" data-id="62585"></div>
# </div>
# <div class="latest-category-section">
# <div class="section-heading mb-sm">
# 								Latest
# 								Celebrity
# 							</div>
# <div class="article-grid-wrapper style-2">
# <div class="article-grid style-2" data-category="Celebrity" data-id="62585"></div>
# <div class="article-grid--load-more js-article-grid--load-more mb-sm mt-sm">
# <div class="loading-image js-loading-image">
# <i class="icon-ps-icon-dot"></i>
# </div>
# <div class="the-end js-the-end">
# 										The End.
# 									</div>
# </div>
# </div>
# </div>
# </div>
# <div class="sidebar">
# <div class="sidebar-ad-container">
# <div class="code-block code-block-9" style="margin: 8px 0; clear: both;">
# <div id="gam_mrec_pos2">
# <script type="text/javascript">
#     googletag.cmd.push(function() {
#                   var map_banner = googletag.sizeMapping()
#             		.addSize([768, 0], [[300, 250],[300, 600]])
# 					.addSize([0, 0], [320, 50]).build();
#      googletag.defineSlot('/22219324693/popsugar/mrec2', [[300, 250],[300, 600],[320, 50]],'gam_mrec_pos2')
#      			  .defineSizeMapping(map_banner)
# 				  .setTargeting('pos', 'mrec2')
# 				  .addService(googletag.pubads());
#      googletag.display('gam_mrec_pos2');
#     });
#    </script>
# </div></div>
# </div>
# </div>
# </div>
# <div class="loading-image end-of-post js-next-post-loading-image">
# <i class="icon-ps-icon-dot"></i>
# <p>The next story, coming up!</p>
# </div>
# </div>
# </div>
# <script src="https://www.instagram.com/embed.js"></script>
# </div>
# </section>
# <footer id="footer">
# <footer class="site-footer">
# <div class="columns">
# <div class="column">
# <strong></strong>
# <a class="footer-link" href="https://www.valmorgan.com.au/" target="_blank" title="Advertisement link">
# 						Advertise With Us
# 					</a>
# <a class="footer-link" href="https://www.popsugar.com.au/about-us/" title="About Us Link">
# 						About Us
# 					</a>
# <a class="footer-link" href="https://www.popsugar.com.au/terms/" title="">
# 						Terms
# 					</a>
# <a class="footer-link" href="https://www.popsugar.com.au/privacy-policy/" title="">
# 						Privacy Policy
# 					</a>
# <a class="footer-link" href="https://www.popsugar.com.au/contact/" title="">
# 						Contact
# 					</a>
# </div>
# <div class="column">
# <strong>More POPSUGAR:</strong>
# <a class="footer-link" href="https://www.poweryourhappy.com/" target="_blank" title="Power link">
# 						Power Your Happy
# 					</a>
# </div>
# <div class="column">
# <strong>POPSUGAR International:</strong>
# <a class="footer-link" href="https://www.popsugar.com/?cancel_au_redir=1" title="">
# 						US
# 					</a>
# <a class="footer-link" href="https://www.popsugar.co.uk/?cancel_au_redir=1" target="_blank" title="UK">
# 						UK
# 					</a>
# <a class="footer-link" href="https://me.popsugar.com/?cancel_au_redir=1" title="">
# 						Middle East
# 					</a>
# <a class="footer-link" href="https://ar.popsugar.com/?cancel_au_redir=1" title="">
# 						الشرق الأوسط
# 					</a>
# </div>
# <div class="column follow-column">
# <strong>Follow Us</strong>
# <div class="social-icons-row">
# <a class="icon-facebook social-icon with-background" href="https://www.facebook.com/PopSugarAustralia" target="_blank"></a>
# <a class="icon-instagram social-icon with-background" href="https://www.instagram.com/POPSUGARau" target="_blank"></a>
# <a class="icon-flipboard social-icon with-background" href="https://flipboard.com/@popsugarau" target="_blank"></a>
# <a class="icon-pinterest social-icon with-background" href="https://www.pinterest.com.au/popsugarau" target="_blank"></a>
# <a class="icon-twitter social-icon with-background" href="https://twitter.com/POPSUGARau" target="_blank"></a>
# </div>
# </div>
# </div>
# <div class="copy">
# <span class="copyright">
#     		©2021
# 		</span>
# <p>Val Morgan Digital</p>
# </div>
# </footer>
# </footer>
# <script id="main-js" src="/wp-content/themes/popsugar/dist/main.bundle.js?ver=5.5.3" type="text/javascript"></script>
# <script id="components-js" src="/wp-content/themes/popsugar/dist/components.bundle.js?ver=5.5.3" type="text/javascript"></script>
# <script id="wp-embed-js" src="https://www.popsugar.com.au/wp-includes/js/wp-embed.min.js?ver=5.5.3" type="text/javascript"></script>
# <script async="async" id="remote_sdk-js" src="https://cdn.onesignal.com/sdks/OneSignalSDK.js?ver=5.5.3" type="text/javascript"></script>
# </main>
# <div class="desktop-side-menu js-desktop-side-menu">
# <div class="header">
# <div class="logo">
# <a href="/">
# <img alt="popsugar logo" src="/wp-content/themes/popsugar/src/images/logo.svg"/>
# </a>
# </div>
# <button class="btn-close js-btn-close"></button>
# </div>
# <div class="links-wrapper">
# <ul class="links">
# <li class="link-item">
# <div class="link-wrapper">
# <a class="link js-link" href="https://www.popsugar.com.au/celebrity/">
# <span class="link-title">
# 									Celebrity
# 								</span>
# </a>
# <button class="link-button js-link-button">
# <span class="circle"></span>
# <span class="circle"></span>
# <span class="circle"></span>
# </button>
# </div>
# <div class="sub-menu">
# <a class="link sub-menu--link" href="https://www.popsugar.com.au/celebrity/">Latest Celebrity</a>
# <a class="link sub-menu--link" href="https://www.popsugar.com.au/tag/movies/">Movies</a>
# <a class="link sub-menu--link" href="https://www.popsugar.com.au/tag/tv/">TV</a>
# </div>
# </li>
# <li class="link-item">
# <div class="link-wrapper">
# <a class="link js-link" href="https://www.popsugar.com.au/fashion/">
# <span class="link-title">
# 									Fashion
# 								</span>
# </a>
# <button class="link-button js-link-button">
# <span class="circle"></span>
# <span class="circle"></span>
# <span class="circle"></span>
# </button>
# </div>
# <div class="sub-menu">
# <a class="link sub-menu--link" href="https://www.popsugar.com.au/fashion/">Latest Fashion</a>
# <a class="link sub-menu--link" href="https://www.popsugar.com.au/tag/fashion-news/">Fashion News</a>
# <a class="link sub-menu--link" href="https://www.popsugar.com.au/tag/street-style/">Street Style</a>
# </div>
# </li>
# <li class="link-item">
# <div class="link-wrapper">
# <a class="link js-link" href="https://www.popsugar.com.au/beauty/">
# <span class="link-title">
# 									Beauty
# 								</span>
# </a>
# <button class="link-button js-link-button">
# <span class="circle"></span>
# <span class="circle"></span>
# <span class="circle"></span>
# </button>
# </div>
# <div class="sub-menu">
# <a class="link sub-menu--link" href="https://www.popsugar.com.au/beauty/">Latest Beauty</a>
# <a class="link sub-menu--link" href="https://www.popsugar.com.au/tag/celebrity-beauty/">Celebrity Beauty</a>
# <a class="link sub-menu--link" href="https://www.popsugar.com.au/tag/beauty-news/">Beauty News</a>
# </div>
# </li>
# <li class="link-item">
# <div class="link-wrapper">
# <a class="link js-link" href="https://www.popsugar.com.au/fitness/">
# <span class="link-title">
# 									Health &amp; Fitness
# 								</span>
# </a>
# <button class="link-button js-link-button">
# <span class="circle"></span>
# <span class="circle"></span>
# <span class="circle"></span>
# </button>
# </div>
# <div class="sub-menu">
# <a class="link sub-menu--link" href="https://www.popsugar.com.au/fitness/">Latest Health &amp; Fitness</a>
# <a class="link sub-menu--link" href="https://www.popsugar.com.au/tag/healthy-recipes/">Healthy Recipes</a>
# </div>
# </li>
# <li class="link-item">
# <div class="link-wrapper">
# <a class="link js-link" href="https://www.popsugar.com.au/living/">
# <span class="link-title">
# 									Living
# 								</span>
# </a>
# </div>
# </li>
# </ul>
# </div>
# <div class="secondary-links-wrapper">
# <ul class="links">
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-1924">
# <a href="https://www.valmorgan.com.au/">Advertise With Us</a>
# </li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-48170">
# <a href="https://www.popsugar.com.au/about-us/">About Us</a>
# </li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-48171">
# <a href="https://www.popsugar.com.au/contact/">Contact</a>
# </li>
# <li class="spacer-link menu-item menu-item-type-custom menu-item-object-custom menu-item-1926">
# <a href="https://www.poweryourhappy.com/?utm_source=popsugar.com&amp;utm_medium=ad&amp;utm_campaign=homepage_popsugarinfo">Power Your Happy</a>
# </li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-48172">
# <a href="https://www.popsugar.com.au/terms/">Terms</a>
# </li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-48173">
# <a href="https://www.popsugar.com.au/privacy-policy/">Privacy Policy</a>
# </li>
# <li class="copyright">
# 					©2021
# 					<small>Val Morgan Digital</small>
# </li>
# </ul>
# </div>
# </div>
# <div class="mobile-nav js-mobile-nav">
# <div class="header">
# <div class="logo">
# <a href="/">
# <img alt="popsugar logo" src="/wp-content/themes/popsugar/src/images/logo.svg"/>
# </a>
# </div>
# <button class="btn-close js-mobile-menu-btn"></button>
# </div>
# <div class="search-wrapper">
# <form action="/search">
# <i class="icon icon-search"></i>
# <input autocomplete="off" class="js-input-search" name="query" placeholder="Search" spellcheck="false" type="search"/>
# </form>
# <div class="suggestions js-suggestions">
# </div>
# </div>
# <div class="links-wrapper">
# <ul class="links">
# <li class="link-item">
# <a class="link" href="https://popsugar.com.au/">POPSUGAR Australia</a>
# </li>
# <li class="link-item">
# <a class="link" href="https://www.popsugar.com.au/celebrity/">Celebrity</a>
# <div class="sub-menu">
# <a class="link sub-menu--link" href="https://www.popsugar.com.au/celebrity/">Latest Celebrity</a>
# <a class="link sub-menu--link" href="https://www.popsugar.com.au/tag/movies/">Movies</a>
# <a class="link sub-menu--link" href="https://www.popsugar.com.au/tag/tv/">TV</a>
# </div>
# </li>
# <li class="link-item">
# <a class="link" href="https://www.popsugar.com.au/fashion/">Fashion</a>
# <div class="sub-menu">
# <a class="link sub-menu--link" href="https://www.popsugar.com.au/fashion/">Latest Fashion</a>
# <a class="link sub-menu--link" href="https://www.popsugar.com.au/tag/fashion-news/">Fashion News</a>
# <a class="link sub-menu--link" href="https://www.popsugar.com.au/tag/street-style/">Street Style</a>
# </div>
# </li>
# <li class="link-item">
# <a class="link" href="https://www.popsugar.com.au/beauty/">Beauty</a>
# <div class="sub-menu">
# <a class="link sub-menu--link" href="https://www.popsugar.com.au/beauty/">Latest Beauty</a>
# <a class="link sub-menu--link" href="https://www.popsugar.com.au/tag/celebrity-beauty/">Celebrity Beauty</a>
# <a class="link sub-menu--link" href="https://www.popsugar.com.au/tag/beauty-news/">Beauty News</a>
# </div>
# </li>
# <li class="link-item">
# <a class="link" href="https://www.popsugar.com.au/fitness/">Health &amp; Fitness</a>
# <div class="sub-menu">
# <a class="link sub-menu--link" href="https://www.popsugar.com.au/fitness/">Latest Health &amp; Fitness</a>
# <a class="link sub-menu--link" href="https://www.popsugar.com.au/tag/healthy-recipes/">Healthy Recipes</a>
# </div>
# </li>
# <li class="link-item">
# <a class="link" href="https://www.popsugar.com.au/living/">Living</a>
# <div class="sub-menu">
# <a class="link sub-menu--link" href="https://www.popsugar.com.au/living/">Latest Living</a>
# <a class="link sub-menu--link" href="https://www.popsugar.com.au/tag/home/">Home</a>
# <a class="link sub-menu--link" href="https://www.popsugar.com.au/tag/tech/">Tech</a>
# <a class="link sub-menu--link" href="https://www.popsugar.com.au/tag/love-life/">Love &amp; Sex</a>
# </div>
# </li>
# </ul>
# <div class="separator"></div>
# <ul class="links">
# <li class="link-item">
# <a class="link menu-item menu-item-type-post_type menu-item-object-page menu-item-48162" href="https://www.popsugar.com.au/about-us/">About Us</a>
# </li>
# <li class="link-item">
# <a class="link menu-item menu-item-type-custom menu-item-object-custom menu-item-1939" href="https://www.poweryourhappy.com/?utm_source=popsugar.com&amp;utm_medium=ad&amp;utm_campaign=mobilenav_popsugar">Power Your Happy</a>
# </li>
# </ul>
# <div class="separator"></div>
# <ul class="links">
# <li class="link-item">
# <a class="link menu-item menu-item-type-custom menu-item-object-custom menu-item-1933" href="https://www.valmorgan.com.au">Advertise With Us</a>
# </li>
# <li class="link-item">
# <a class="link menu-item menu-item-type-custom menu-item-object-custom menu-item-home menu-item-1934" href="https://www.popsugar.com.au">Full Site</a>
# </li>
# <li class="link-item">
# <a class="link menu-item menu-item-type-post_type menu-item-object-page menu-item-48174" href="https://www.popsugar.com.au/contact/">Contact</a>
# </li>
# <li class="link-item">
# <a class="link menu-item menu-item-type-post_type menu-item-object-page menu-item-48175" href="https://www.popsugar.com.au/privacy-policy/">Privacy Policy – POPSUGAR AND THRILLIST</a>
# </li>
# <li class="link-item">
# <a class="link menu-item menu-item-type-post_type menu-item-object-page menu-item-48176" href="https://www.popsugar.com.au/terms/">Terms of Use – POPSUGAR Australia and New Zealand</a>
# </li>
# </ul>
# <div class="separator"></div>
# <ul class="links">
# <li class="link-item">
# <a class="link menu-item menu-item-type-post_type menu-item-object-page menu-item-48169" href="https://www.popsugar.com.au/subscribe/">Subscribe</a>
# </li>
# </ul>
# <div class="separator"></div>
# <div class="footer">
#             ©2021 Val Morgan Digital
#         </div>
# </div>
# </div></body>
# </html> <div id="fb-root"></div>
# <script async="" crossorigin="anonymous" defer="" nonce="Bn94it8Z" src="https://connect.facebook.net/en_GB/sdk.js#xfbml=1&amp;version=v9.0&amp;appId=241865759213877&amp;autoLogAppEvents=1"></script>
# <script>
# 				window.fbAsyncInit = function () {
# FB.init({appId: 241865759213877, autoLogAppEvents: true, xfbml: true, version: 'v5.0'});
# };
# 			</script>
# <script async="" defer="" src="//assets.pinterest.com/js/pinit.js" type="text/javascript"></script>
# <script src="https://cdn.flipboard.com/web/buttons/js/flbuttons.min.js" type="text/javascript"></script>
# <!-- Go to www.addthis.com/dashboard to customize your tools -->
# <script src="//s7.addthis.com/js/300/addthis_widget.js#pubid=ra-54bef9574e2bafdf" type="text/javascript"></script>
# <script type="text/javascript">
# 			window._taboola = window._taboola || [];
# _taboola.push({flush: true});
# 		</script>

# %%
# find the css-selector for one book title
soup4.select("div:nth-child(3) > h2:nth-child(1)")[0].get_text()
# Out:
# '\n\t\t\t\t\t\t\tThe White Tiger by Aravind Adiga\n\t\t\t\t\t\t'

# %%
book_list4=soup4.select("div:nth-child(3) > h2:nth-child(1)")

# %%
from tqdm.notebook import tqdm
Book4 = []
# Yes = 1
Book_into_Movie4 = []

len_book4 = len(book_list4)

for i in tqdm(range(len_book4)):
    Book4.append(soup4.select("div:nth-child(3) > h2:nth-child(1)")[i].text)
    Book_into_Movie4.append("1")
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]

# %%
len(Book4), len(Book_into_Movie4)
# Out:
# (8, 8)

# %%
book4 = pd.DataFrame({"Name": Book4, "Book_into_Movie": Book_into_Movie4})

# %%
book4.to_excel("Book_into_movie_2021.xlsx")

# %% [markdown]
# ### 5.5. Create one file for all  (incl. first data wrangeling for book_into_movie)

# %%
file1 = pd.read_excel("Book_into_movie_1.xlsx")

# %%
file2 = pd.read_excel("Book_into_movie_2.xlsx")

# %%
file3 = pd.read_excel("Book_into_movie_3.xlsx")

# %%
file4 = pd.read_excel("Book_into_movie_2021.xlsx")

# %%
file5 = pd.read_csv("Books into Movies_From_Kaggle.csv")

# %%
file6 = pd.read_csv("augmented_from_kaggle.csv")

# %% [markdown]
# - show the head of the tables

# %% [markdown]
# *file1*

# %%
file1.head()
# Out:
#    Unnamed: 0                                        Name  Book_into_Movie
# 0           0                      The Fault in Our Stars                1
# 1           1                   Divergent (Divergent, #1)                1
# 2           2       The Maze Runner (The Maze Runner, #1)                1
# 3           3  City of Bones (The Mortal Instruments, #1)                1
# 4           4                                   Gone Girl                1

# %% [markdown]
# - file1 columns -> ok

# %% [markdown]
# *file2*

# %%
file2.head()
# Out:
#    Unnamed: 0                                               Name  \
# 0           0  Harry Potter and the Half-Blood Prince (Harry ...
# 1           1                            Twilight (Twilight, #1)
# 2           2                The Hobbit, or There and Back Again
# 3           3                                           Watchmen
# 4           4  The Lightning Thief (Percy Jackson and the Oly...
#
#    Book_into_Movie
# 0                1
# 1                1
# 2                1
# 3                1
# 4                1

# %% [markdown]
# - file2 columns -> ok

# %% [markdown]
# *file3*

# %%
file3.head()
# Out:
#    Unnamed: 0                                               Name  \
# 0           0                              The Lord of the Rings
# 1           1  The Lion, the Witch and the Wardrobe (Chronicl...
# 2           2   Harry Potter Series Box Set (Harry Potter, #1-7)
# 3           3                              To Kill a Mockingbird
# 4           4  Charlie and the Chocolate Factory (Charlie Buc...
#
#    Book_into_Movie
# 0                1
# 1                1
# 2                1
# 3                1
# 4                1

# %% [markdown]
# -> file3 columns -> ok

# %% [markdown]
# *file4*

# %%
file4.head()
# Out:
#    Unnamed: 0                                               Name  \
# 0           0  \n\t\t\t\t\t\t\tThe White Tiger by Aravind Adi...
# 1           1  \n\t\t\t\t\t\t\tAll Things Cease to Appear by ...
# 2           2  \n\t\t\t\t\t\t\tThose Who Wish Me Dead by Mich...
# 3           3  \n\t\t\t\t\t\t\tDeath on the Nile by Agatha Ch...
# 4           4  \n\t\t\t\t\t\t\tNightmare Alley by William Lin...
#
#    Book_into_Movie
# 0                1
# 1                1
# 2                1
# 3                1
# 4                1

# %% [markdown]
# - a little data wrangling

# %%
file4['Name']=file4['Name'].str.lstrip()

# %%
file4['Name']=file4['Name'].str.rstrip()

# %%
file4 = file4.drop(file4[file4.Name == " "].index)

# %%
file4 = file4.drop(file4[file4.Name == "Want More?"].index)

# %% [markdown]
# - file 4 columns -> ok

# %% [markdown]
# *file5*

# %%
file5.head()
# Out:
#               Author            Movie Title Movie Release Date Book Title
# 0       Doug Stanton              12 Strong          1/19/2018        NaN
# 1   W. Bruce Cameron        A Dog's Purpose          1/27/2017        NaN
# 2  Madeleine L'Engle     A Wrinkle in Time            3/9/2018        NaN
# 3     Jennifer Niven  All the Bright Places                NaN        NaN
# 4    Jeff Vandermeer           Annihilation          2/23/2018        NaN

# %% [markdown]
# - some data wrangling necessary before concat the files

# %%
file5["Book Title"].value_counts()
# Out:
# Mary Poppins                                                                                1
# The 15:17 to Paris: The True Story of a Terrorist, a Train, and Three American Soldiers�    1
# First Man: The Life of Neil A. Armstrong                                                    1
# Valerian & Laureline�                                                                       1
# My Heart is My Own: The Life of Mary Queen of Scots                                         1
# The Jungle Book                                                                             1
# Fantastic Beasts and Where to Find Them�                                                    1
# How the Grinch Stole Christmas                                                              1
# Simon vs. the Homo Sapiens Agenda                                                           1
# The Death Cure                                                                              1
# The Tale of Peter Rabbit                                                                    1
# Between Shades of Gray�                                                                     1
# Name: Book Title, dtype: int64

# %%
file5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Author              70 non-null     object
#  1   Movie Title         70 non-null     object
#  2   Movie Release Date  58 non-null     object
#  3   Book Title          12 non-null     object
# dtypes: object(4)
# memory usage: 2.3+ KB

# %%
# delete the missing values, because the movie title must not be book title, there erae enoug book titles to compare with the bestseller list
file5 = file5.dropna()

# %%
# Create a column with 1 (yes the book was filmed into movie)
file5['Book_into_Movie'] = np.nan
file5['Book_into_Movie'] = file5['Book_into_Movie'].fillna("1")

# %%
# delete all columns which are not necessary
file5_new = file5.drop(columns=["Movie Release Date", "Movie Title", "Author"])

# %%
file5_new.rename(columns = {'Book Title' : 'Name'}, inplace = True)

# %%
file5_new.head()
# Out:
#                                                  Name Book_into_Movie
# 15           Fantastic Beasts and Where to Find Them�               1
# 18           First Man: The Life of Neil A. Armstrong               1
# 24                  Simon vs. the Homo Sapiens Agenda               1
# 25                                       Mary Poppins               1
# 26  My Heart is My Own: The Life of Mary Queen of ...               1

# %% [markdown]
# *file6*

# %%
file6.head()
# Out:
#    Unnamed: 0                                  title            author  \
# 0           0  The Sword and The Prophet (Syren, #1)       Missy LaRae
# 1           1          Ruins (Partials Sequence, #3)         Dan Wells
# 2           2               Breathe (Sea Breeze, #1)       Abbi Glines
# 3           3                    The Knife-Edge Path  Patrick T. Leahy
# 4           4                        The Lock Artist    Steve Hamilton
#
#                                           author_url  rating  voters_count  \
# 0  https://www.goodreads.com/author/show/5805389....    3.80            50
# 1  https://www.goodreads.com/author/show/2740668....    4.05         14673
# 2  https://www.goodreads.com/author/show/4872191....    3.86         77770
# 3  https://www.goodreads.com/author/show/6552972....    4.00             5
# 4  https://www.goodreads.com/author/show/9891.Ste...    3.97         10967
#
#                                                  url  into_movie  gender  \
# 0  https://goodreads.com/book/show/13575987-the-s...           0  female
# 1     https://goodreads.com/book/show/17607716-ruins           0    male
# 2   https://goodreads.com/book/show/11479285-breathe           0  female
# 3  https://goodreads.com/book/show/49085715-the-k...           0     NaN
# 4  https://goodreads.com/book/show/6811221-the-lo...           0    male
#
#               hometown  books-num     born-at  works-count publication-date  \
# 0     Portland, Oregon        2.0  1979/12/17          2.0        3/29/2012
# 1                  NaN       10.0         NaN         45.0        3/11/2014
# 2  Birmingham, Alabama       10.0         NaN         88.0        5/16/2011
# 3                  NaN        3.0         NaN          3.0              NaN
# 4          Detroit, MI       10.0         NaN         35.0              NaN
#
#    num-pages                                    popular-shelves  \
# 0      150.0  [to-read, young-adult, fantasy, library, kindl...
# 1      464.0  [to-read, young-adult, dystopian, currently-re...
# 2      164.0  [to-read, romance, currently-reading, young-ad...
# 3        NaN  [to-read, currently-reading, kindle-unlimited,...
# 4        NaN  [to-read, currently-reading, mystery, fiction,...
#
#                                          rating-dist              publisher  \
# 0                     5:19|4:13|3:9|2:7|1:2|total:50  Pretty Wycked Designs
# 1       5:5367|4:5621|3:2954|2:587|1:150|total:14679          Balzer + Bray
# 2  5:26825|4:24784|3:17639|2:5881|1:2655|total:77784  Wild Child Publishing
# 3                        5:1|4:3|3:1|2:0|1:0|total:5                    NaN
# 4       5:3307|4:4786|3:2239|2:494|1:148|total:10974                    NaN
#
#                                     book-description
# 0  “Why'd Mama hate us so much, Tyler?" My head r...
# 1  Kira, Samm, and Marcus fight to prevent a fina...
# 2  Sadie White's summer job isn't going to be on ...
# 3                                                NaN
# 4  <i>"I was the Miracle Boy, once upon a time. L...

# %%
# coilumn into_movie -> yes = 1
file6["into_movie"].value_counts()
# Out:
# 0    28245
# 1     1760
# Name: into_movie, dtype: int64

# %%
file6 = file6.drop(columns=["Unnamed: 0", "author", "author_url", "rating", "voters_count", "url", "gender","hometown","books-num","born-at","works-count","publication-date","num-pages","popular-shelves","rating-dist","publisher","book-description"])

# %%
file6
# Out:
#                                        title  into_movie
# 0      The Sword and The Prophet (Syren, #1)           0
# 1              Ruins (Partials Sequence, #3)           0
# 2                   Breathe (Sea Breeze, #1)           0
# 3                        The Knife-Edge Path           0
# 4                            The Lock Artist           0
# ...                                      ...         ...
# 30000                             Rogue Male           1
# 30001                                   Room           1
# 30002                            Fingersmith           1
# 30003                     The Fallen Sparrow           1
# 30004                     A Gentleman's Game           1
#
# [30005 rows x 2 columns]

# %%
file6.rename(columns = {'title' : 'Name', "into_movie": "Book_into_Movie"}, inplace = True)

# %%
# only the books which are filmed are important -> 0 will be dropped
file6 = file6.drop(file6[file6.Book_into_Movie == 0].index)

# %%
file6.head()
# Out:
#                                                     Name  Book_into_Movie
# 28245                                          Elizabeth                1
# 28246                        Hier kommt Lola! (Lola, #1)                1
# 28247                              A Very British Murder                1
# 28248                        Bartosz Beda: Hear my voice                1
# 28249  Call Me Mrs. Miracle - Keajaiban Natal (Angeli...                1

# %% [markdown]
# - *One file for all*

# %%
Book_into_Movie = pd.concat([file1, file2, file3, file5_new, file6], axis=0)

# %%
Book_into_Movie.to_excel("Book_into_Movie.xlsx")
