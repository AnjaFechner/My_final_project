# %% [markdown]
# # Step 1: Web Scraping New_York_Times_Bestseller_Books (Source: Wikipedia)

# %% [markdown]
# ## 0. Libraries

# %%
import requests
import lxml.html as lh
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
from time import sleep
from random import uniform
import glob

# %% [markdown]
# ## 1. Web Scraping
# - web scraping the table on the website

# %% [markdown]
# 1.1. Try one page

# %%
page = requests.get("https://en.wikipedia.org/wiki/The_New_York_Times_Fiction_Best_Sellers_of_1998").text
df = pd.read_html(page, flavor="bs4")[0]
df['Year']=np.nan
df['Year'] = df['Year'].fillna("1998")
df
#df.to_csv("nyt.csv", index=False)
#df
# Out:
#             Date                      Book              Author  Year
# 0      January 4             Cold Mountain     Charles Frazier  1998
# 1     January 11             Cold Mountain     Charles Frazier  1998
# 2     January 18             Cold Mountain     Charles Frazier  1998
# 3     January 25             Cold Mountain     Charles Frazier  1998
# 4     February 1                  Paradise       Toni Morrison  1998
# 5     February 8                  Paradise       Toni Morrison  1998
# 6    February 15                  Paradise       Toni Morrison  1998
# 7    February 22         The Street Lawyer        John Grisham  1998
# 8        March 1         The Street Lawyer        John Grisham  1998
# 9        March 8         The Street Lawyer        John Grisham  1998
# 10      March 15         The Street Lawyer        John Grisham  1998
# 11      March 22         The Street Lawyer        John Grisham  1998
# 12      March 29         The Street Lawyer        John Grisham  1998
# 13       April 5         The Street Lawyer        John Grisham  1998
# 14      April 12         The Street Lawyer        John Grisham  1998
# 15      April 19         The Street Lawyer        John Grisham  1998
# 16      April 26        The Long Road Home      Danielle Steel  1998
# 17         May 3        The Long Road Home      Danielle Steel  1998
# 18        May 10          You Belong to Me  Mary Higgins Clark  1998
# 19        May 17          You Belong to Me  Mary Higgins Clark  1998
# 20        May 24          You Belong to Me  Mary Higgins Clark  1998
# 21        May 31          "N" Is for Noose         Sue Grafton  1998
# 22        June 7          You Belong to Me  Mary Higgins Clark  1998
# 23       June 14      A Widow for One Year         John Irving  1998
# 24       June 21      A Widow for One Year         John Irving  1998
# 25       June 28      A Widow for One Year         John Irving  1998
# 26        July 5  I Know This Much Is True          Wally Lamb  1998
# 27       July 12           The Klone and I      Danielle Steel  1998
# 28       July 19  I Know This Much is True          Wally Lamb  1998
# 29       July 26           Point of Origin   Patricia Cornwell  1998
# 30      August 2           Point of Origin   Patricia Cornwell  1998
# 31      August 9  I Know This Much is True          Wally Lamb  1998
# 32     August 16           Point of Origin   Patricia Cornwell  1998
# 33     August 23               Rainbow Six          Tom Clancy  1998
# 34     August 30               Rainbow Six          Tom Clancy  1998
# 35   September 6               Rainbow Six          Tom Clancy  1998
# 36  September 13               Rainbow Six          Tom Clancy  1998
# 37  September 20               Rainbow Six          Tom Clancy  1998
# 38  September 27               Rainbow Six          Tom Clancy  1998
# 39     October 4               Rainbow Six          Tom Clancy  1998
# 40    October 11              Bag of Bones        Stephen King  1998
# 41    October 18              Bag of Bones        Stephen King  1998
# 42    October 25              Bag of Bones        Stephen King  1998
# 43    November 1              Bag of Bones        Stephen King  1998
# 44    November 8       The Path of Daggers       Robert Jordan  1998
# 45   November 15       The Path of Daggers       Robert Jordan  1998
# 46   November 22             A Man in Full           Tom Wolfe  1998
# 47   November 29             A Man in Full           Tom Wolfe  1998
# 48    December 6             A Man in Full           Tom Wolfe  1998
# 49   December 13             A Man in Full           Tom Wolfe  1998
# 50   December 20             A Man in Full           Tom Wolfe  1998
# 51   December 27             A Man in Full           Tom Wolfe  1998

# %% [markdown]
# 1.2. Web Scraping all bestseller list - genre: fiction (New York Times bestseller - years 1931 to 2021

# %%
iterations_fiction = range(1931, 2022)

# %%
for i in iterations_fiction:
    #get the page in text_format
    page_fiction = requests.get(f"https://en.wikipedia.org/wiki/The_New_York_Times_Fiction_Best_Sellers_of_{i}").text
       
    #crerate the DF only with the table
    df_fiction = pd.read_html(page_fiction, flavor="bs4")[0]
    
    #create a new column with the year of the bestseller list
    df_fiction['Year']=np.nan
    df_fiction['Year'] = df_fiction['Year'].fillna(f"{i}")
    df_fiction['Genre']=np.nan
    df_fiction['Genre'] = df_fiction['Genre'].fillna("fiction")
    
    # build a csv-file
    df_fiction.to_csv(f"nyt_fiction_{i}.csv", index=False)
    
    # respectfull scraping
    wait_time = uniform(1.0, 2)
    sleep(wait_time)

# %% [markdown]
# 1.3. Web Scraping all bestseller list - genre: non-fiction (New York Times bestseller - years 1931 to 2021

# %%
iterations_nonfiction = range(1931, 2022)

# %%
for i in iterations_nonfiction:
    #get the page in text_format
    page_nonfiction = requests.get(f"https://en.wikipedia.org/wiki/The_New_York_Times_Nonfiction_Best_Sellers_of_{i}").text
       
    #crerate the DF only with the table
    df_nonfiction = pd.read_html(page_nonfiction, flavor="bs4")[0]
    
    #create a new column with the year of the bestseller list
    df_nonfiction['Year']=np.nan
    df_nonfiction['Year'] = df_nonfiction['Year'].fillna(f"{i}")
    df_nonfiction['Genre']=np.nan
    df_nonfiction['Genre'] = df_nonfiction['Genre'].fillna("nonfiction")
    
    # build a csv-file
    df_nonfiction.to_csv(f"nyt_nonfiction_{i}.csv", index=False)
    
    # respectfull scraping
    wait_time = uniform(3.0, 2)
    sleep(wait_time)

# %% [markdown]
# 1.3 Create a DataFrame and concat all files, but with steps between to check the rsults

# %%
# leads the jupyter notebook to the folder with the files
path = r''

# find all file names with the end 'csv'
all_files = glob.glob("*.csv")

# generate a list with all file_names
li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

# %%
# check the results (because not all files are considered)
all_files
# Out:
# ['nyt_fiction_1931.csv',
#  'nyt_fiction_1932.csv',
#  'nyt_fiction_1933.csv',
#  'nyt_fiction_1934.csv',
#  'nyt_fiction_1935.csv',
#  'nyt_fiction_1936.csv',
#  'nyt_fiction_1937.csv',
#  'nyt_fiction_1938.csv',
#  'nyt_fiction_1939.csv',
#  'nyt_fiction_1940.csv',
#  'nyt_fiction_1941.csv',
#  'nyt_fiction_1942.csv',
#  'nyt_fiction_1943.csv',
#  'nyt_fiction_1944.csv',
#  'nyt_fiction_1945.csv',
#  'nyt_fiction_1946.csv',
#  'nyt_fiction_1947.csv',
#  'nyt_fiction_1948.csv',
#  'nyt_fiction_1949.csv',
#  'nyt_fiction_1950.csv',
#  'nyt_fiction_1951.csv',
#  'nyt_fiction_1952.csv',
#  'nyt_fiction_1953.csv',
#  'nyt_fiction_1954.csv',
#  'nyt_fiction_1955.csv',
#  'nyt_fiction_1956.csv',
#  'nyt_fiction_1957.csv',
#  'nyt_fiction_1958.csv',
#  'nyt_fiction_1959.csv',
#  'nyt_fiction_1960.csv',
#  'nyt_fiction_1961.csv',
#  'nyt_fiction_1962.csv',
#  'nyt_fiction_1963.csv',
#  'nyt_fiction_1964.csv',
#  'nyt_fiction_1965.csv',
#  'nyt_fiction_1966.csv',
#  'nyt_fiction_1967.csv',
#  'nyt_fiction_1968.csv',
#  'nyt_fiction_1969.csv',
#  'nyt_fiction_1970.csv',
#  'nyt_fiction_1971.csv',
#  'nyt_fiction_1972.csv',
#  'nyt_fiction_1973.csv',
#  'nyt_fiction_1974.csv',
#  'nyt_fiction_1975.csv',
#  'nyt_fiction_1976.csv',
#  'nyt_fiction_1977.csv',
#  'nyt_fiction_1978.csv',
#  'nyt_fiction_1979.csv',
#  'nyt_fiction_1980.csv',
#  'nyt_fiction_1981.csv',
#  'nyt_fiction_1982.csv',
#  'nyt_fiction_1983.csv',
#  'nyt_fiction_1984.csv',
#  'nyt_fiction_1985.csv',
#  'nyt_fiction_1986.csv',
#  'nyt_fiction_1987.csv',
#  'nyt_fiction_1988.csv',
#  'nyt_fiction_1989.csv',
#  'nyt_fiction_1990.csv',
#  'nyt_fiction_1991.csv',
#  'nyt_fiction_1992.csv',
#  'nyt_fiction_1993.csv',
#  'nyt_fiction_1994.csv',
#  'nyt_fiction_1995.csv',
#  'nyt_fiction_1996.csv',
#  'nyt_fiction_1997.csv',
#  'nyt_fiction_1998.csv',
#  'nyt_fiction_1999.csv',
#  'nyt_fiction_2000.csv',
#  'nyt_fiction_2001.csv',
#  'nyt_fiction_2002.csv',
#  'nyt_fiction_2003.csv',
#  'nyt_fiction_2004.csv',
#  'nyt_fiction_2005.csv',
#  'nyt_fiction_2006.csv',
#  'nyt_fiction_2007.csv',
#  'nyt_fiction_2008.csv',
#  'nyt_fiction_2009.csv',
#  'nyt_fiction_2010.csv',
#  'nyt_fiction_2011.csv',
#  'nyt_fiction_2012.csv',
#  'nyt_fiction_2013.csv',
#  'nyt_fiction_2014.csv',
#  'nyt_fiction_2015.csv',
#  'nyt_fiction_2016.csv',
#  'nyt_fiction_2017.csv',
#  'nyt_fiction_2018.csv',
#  'nyt_fiction_2019.csv',
#  'nyt_fiction_2020.csv',
#  'nyt_fiction_2021.csv',
#  'nyt_nonfiction_1931.csv',
#  'nyt_nonfiction_1932.csv',
#  'nyt_nonfiction_1933.csv',
#  'nyt_nonfiction_1934.csv',
#  'nyt_nonfiction_1935.csv',
#  'nyt_nonfiction_1936.csv',
#  'nyt_nonfiction_1937.csv',
#  'nyt_nonfiction_1938.csv',
#  'nyt_nonfiction_1939.csv',
#  'nyt_nonfiction_1940.csv',
#  'nyt_nonfiction_1941.csv',
#  'nyt_nonfiction_1942.csv',
#  'nyt_nonfiction_1943.csv',
#  'nyt_nonfiction_1944.csv',
#  'nyt_nonfiction_1945.csv',
#  'nyt_nonfiction_1946.csv',
#  'nyt_nonfiction_1947.csv',
#  'nyt_nonfiction_1948.csv',
#  'nyt_nonfiction_1949.csv',
#  'nyt_nonfiction_1950.csv',
#  'nyt_nonfiction_1951.csv',
#  'nyt_nonfiction_1952.csv',
#  'nyt_nonfiction_1953.csv',
#  'nyt_nonfiction_1954.csv',
#  'nyt_nonfiction_1955.csv',
#  'nyt_nonfiction_1956.csv',
#  'nyt_nonfiction_1957.csv',
#  'nyt_nonfiction_1958.csv',
#  'nyt_nonfiction_1959.csv',
#  'nyt_nonfiction_1960.csv',
#  'nyt_nonfiction_1961.csv',
#  'nyt_nonfiction_1962.csv',
#  'nyt_nonfiction_1963.csv',
#  'nyt_nonfiction_1964.csv',
#  'nyt_nonfiction_1965.csv',
#  'nyt_nonfiction_1966.csv',
#  'nyt_nonfiction_1967.csv',
#  'nyt_nonfiction_1968.csv',
#  'nyt_nonfiction_1969.csv',
#  'nyt_nonfiction_1970.csv',
#  'nyt_nonfiction_1971.csv',
#  'nyt_nonfiction_1972.csv',
#  'nyt_nonfiction_1973.csv',
#  'nyt_nonfiction_1974.csv',
#  'nyt_nonfiction_1975.csv',
#  'nyt_nonfiction_1976.csv',
#  'nyt_nonfiction_1977.csv',
#  'nyt_nonfiction_1978.csv',
#  'nyt_nonfiction_1979.csv',
#  'nyt_nonfiction_1980.csv',
#  'nyt_nonfiction_1981.csv',
#  'nyt_nonfiction_1982.csv',
#  'nyt_nonfiction_1983.csv',
#  'nyt_nonfiction_1984.csv',
#  'nyt_nonfiction_1985.csv',
#  'nyt_nonfiction_1986.csv',
#  'nyt_nonfiction_1987.csv',
#  'nyt_nonfiction_1988.csv',
#  'nyt_nonfiction_1989.csv',
#  'nyt_nonfiction_1990.csv',
#  'nyt_nonfiction_1991.csv',
#  'nyt_nonfiction_1992.csv',
#  'nyt_nonfiction_1993.csv',
#  'nyt_nonfiction_1994.csv',
#  'nyt_nonfiction_1995.csv',
#  'nyt_nonfiction_1996.csv',
#  'nyt_nonfiction_1997.csv',
#  'nyt_nonfiction_1998.csv',
#  'nyt_nonfiction_1999.csv',
#  'nyt_nonfiction_2000.csv',
#  'nyt_nonfiction_2001.csv',
#  'nyt_nonfiction_2002.csv',
#  'nyt_nonfiction_2003.csv',
#  'nyt_nonfiction_2004.csv',
#  'nyt_nonfiction_2005.csv',
#  'nyt_nonfiction_2006.csv',
#  'nyt_nonfiction_2007.csv',
#  'nyt_nonfiction_2008.csv',
#  'nyt_nonfiction_2009.csv',
#  'nyt_nonfiction_2010.csv',
#  'nyt_nonfiction_2011.csv',
#  'nyt_nonfiction_2012.csv',
#  'nyt_nonfiction_2013.csv',
#  'nyt_nonfiction_2014.csv',
#  'nyt_nonfiction_2015.csv',
#  'nyt_nonfiction_2016.csv',
#  'nyt_nonfiction_2017.csv',
#  'nyt_nonfiction_2018.csv',
#  'nyt_nonfiction_2019.csv',
#  'nyt_nonfiction_2020.csv',
#  'nyt_nonfiction_2021.csv']

# %%
# check the results (because not all files are considered)
len(all_files)
# Out:
# 182

# %%
# check the results (because not all files are considered)
len(li)
# Out:
# 182

# %%
# concat all files 
# separate the final step to create a file for all, because to check previous that all files are considered
frame = pd.concat(li, axis=0, ignore_index=True, sort=True)
frame.to_csv('new_york_times_bestseller_1931_2021.csv')
